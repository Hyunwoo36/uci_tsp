# %%
import pandas as pd
import numpy as np
import requests
import time
import json

# %% [markdown]
# # Load Original Data Set and prepare it

# %%
df = pd.read_csv("Address_Point_OCPW___OCFA.csv")
df.head()
# Out:
# /var/folders/4z/5nxj2j413mvcb6fq306y6t6w0000gn/T/ipykernel_13953/662411323.py:1: DtypeWarning: Columns (4,6,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Address_Point_OCPW___OCFA.csv")
#    OBJECTID  AddressPtID     StreetName  AddressNumber Fractional Unit  \
# 0         1   92689299.0    ASHGROVE DR           8172        NaN  NaN
# 1         2   92689094.0  BARRINGTON DR           8101        NaN  NaN
# 2         3   92689097.0  BARRINGTON DR           8122        NaN  NaN
# 3         4   92689155.0    FAIRHOPE DR           4632        NaN  NaN
# 4         5   92689091.0  BARRINGTON DR           8161        NaN  NaN
#
#   Building SubAddressFlag  RouteExternalKey  ZipCode  ...  \
# 0      NaN            NaN       394473602.0    90638  ...
# 1      NaN            NaN               NaN    90638  ...
# 2      NaN            NaN               NaN    90638  ...
# 3      NaN            NaN               NaN    90638  ...
# 4      NaN            NaN               NaN    90638  ...
#
#                   Address FullNumber  UnitID  created_user  \
# 0    8172 ASHGROVE DR            NaN     NaN   ARCGISADMIN
# 1  8101 BARRINGTON DR            NaN     NaN   ARCGISADMIN
# 2  8122 BARRINGTON DR            NaN     NaN   ARCGISADMIN
# 3    4632 FAIRHOPE DR            NaN     NaN   ARCGISADMIN
# 4  8161 BARRINGTON DR            NaN     NaN   ARCGISADMIN
#
#              created_date  last_edited_user        last_edited_date  \
# 0  2024/09/03 13:46:03+00       ARCGISADMIN  2024/09/03 13:46:03+00
# 1  2024/09/03 13:46:03+00       ARCGISADMIN  2024/09/03 13:46:03+00
# 2  2024/09/03 13:46:03+00       ARCGISADMIN  2024/09/03 13:46:03+00
# 3  2024/09/03 13:46:03+00       ARCGISADMIN  2024/09/03 13:46:03+00
# 4  2024/09/03 13:46:03+00       ARCGISADMIN  2024/09/03 13:46:03+00
#
#           County StateAbbr ADD_TYPE
# 0  Orange County        CA      NaN
# 1  Orange County        CA      NaN
# 2  Orange County        CA      NaN
# 3  Orange County        CA      NaN
# 4  Orange County        CA      NaN
#
# [5 rows x 24 columns]

# %%
# Randomly sample 200 rows
sampled_df = df.sample(200, random_state=42)

# Save the sampled data into a new CSV file
sampled_df.to_csv("sampled_data1.csv", index=False)

# %% [markdown]
# # Extract 200 randomly sampled data set

# %%
sampled_df = pd.read_csv("sampled_data1.csv")
sampled_df.head()
# Out:
#    OBJECTID  AddressPtID        StreetName  AddressNumber Fractional Unit  \
# 0    104643   58043498.0     E IVY HILL LN           2003        NaN  NaN
# 1    421143   86029680.0    SHADY CREEK LN           5550        NaN  NaN
# 2    370941   32081918.0       CONNECTICUT              7        NaN  NaN
# 3    692620   30036120.0         KINER AVE           8131        NaN  NaN
# 4    338957   58046828.0  N RIVER TRAIL RD           2395        NaN  NaN
#
#   Building SubAddressFlag  RouteExternalKey  ZipCode  ...  \
# 0      NaN            NaN               NaN    92867  ...
# 1      NaN            NaN               NaN    92887  ...
# 2      NaN            NaN               NaN    92606  ...
# 3      NaN            NaN               NaN    92646  ...
# 4      NaN            NaN               NaN    92865  ...
#
#                      Address FullNumber  UnitID  created_user  \
# 0     2003 E IVY HILL LN            NaN     NaN   ARCGISADMIN
# 1    5550 SHADY CREEK LN            NaN     NaN   ARCGISADMIN
# 2          7 CONNECTICUT            NaN     NaN   ARCGISADMIN
# 3         8131 KINER AVE            NaN     NaN   ARCGISADMIN
# 4  2395 N RIVER TRAIL RD            NaN     NaN   ARCGISADMIN
#
#              created_date  last_edited_user        last_edited_date  \
# 0  2024/09/03 13:46:03+00       ARCGISADMIN  2024/09/03 13:46:03+00
# 1  2024/09/03 13:46:03+00       ARCGISADMIN  2024/09/03 13:46:03+00
# 2  2024/09/03 13:46:03+00       ARCGISADMIN  2024/09/03 13:46:03+00
# 3  2024/09/03 13:46:03+00       ARCGISADMIN  2024/09/03 13:46:03+00
# 4  2024/09/03 13:46:03+00       ARCGISADMIN  2024/09/03 13:46:03+00
#
#           County StateAbbr ADD_TYPE
# 0  Orange County        CA      NaN
# 1  Orange County        CA      NaN
# 2  Orange County        CA      NaN
# 3  Orange County        CA      NaN
# 4  Orange County        CA      NaN
#
# [5 rows x 24 columns]

# %%
sampled_df.loc[1]
# Out:
# OBJECTID                             421143
# AddressPtID                      86029680.0
# StreetName                   SHADY CREEK LN
# AddressNumber                          5550
# Fractional                              NaN
# Unit                                    NaN
# Building                                NaN
# SubAddressFlag                          NaN
# RouteExternalKey                        NaN
# ZipCode                               92887
# City                            YORBA LINDA
# State                            California
# X                               -117.694021
# Y                                 33.879459
# Address             5550 SHADY CREEK LN
# FullNumber                              NaN
# UnitID                                  NaN
# created_user                    ARCGISADMIN
# created_date         2024/09/03 13:46:03+00
# last_edited_user                ARCGISADMIN
# last_edited_date     2024/09/03 13:46:03+00
# County                        Orange County
# StateAbbr                                CA
# ADD_TYPE                                NaN
# Name: 1, dtype: object

# %%
sampled_df.loc[2]
# Out:
# OBJECTID                            370941
# AddressPtID                     32081918.0
# StreetName                     CONNECTICUT
# AddressNumber                            7
# Fractional                             NaN
# Unit                                   NaN
# Building                               NaN
# SubAddressFlag                         NaN
# RouteExternalKey                       NaN
# ZipCode                              92606
# City                                IRVINE
# State                           California
# X                              -117.794305
# Y                                33.710949
# Address                  7 CONNECTICUT
# FullNumber                             NaN
# UnitID                                 NaN
# created_user                   ARCGISADMIN
# created_date        2024/09/03 13:46:03+00
# last_edited_user               ARCGISADMIN
# last_edited_date    2024/09/03 13:46:03+00
# County                       Orange County
# StateAbbr                               CA
# ADD_TYPE                               NaN
# Name: 2, dtype: object

# %% [markdown]
# # Upon checking from google maps, X and Y need to be swapped!

# %%
# Swap X and Y coordinates
# sampled_df['long_temp'] = sampled_df['X']
# sampled_df['X'] = sampled_df['Y']
# sampled_df['Y'] = sampled_df['X_temp']
# sampled_df.drop('X_temp', axis=1, inplace=True)

sampled_df['longitude'] = sampled_df['X']
sampled_df['latitude'] = sampled_df['Y']
sampled_df.drop(['X', 'Y'], axis=1, inplace=True)

# %%
sampled_df
# Out:
#      OBJECTID  AddressPtID        StreetName  AddressNumber Fractional Unit  \
# 0      104643   58043498.0     E IVY HILL LN           2003        NaN  NaN
# 1      421143   86029680.0    SHADY CREEK LN           5550        NaN  NaN
# 2      370941   32081918.0       CONNECTICUT              7        NaN  NaN
# 3      692620   30036120.0         KINER AVE           8131        NaN  NaN
# 4      338957   58046828.0  N RIVER TRAIL RD           2395        NaN  NaN
# ..        ...          ...               ...            ...        ...  ...
# 195    911755   34003987.0      S OAKLAND DR            391        NaN  NaN
# 196    551077   54008504.0          ONYX AVE            112        NaN  NaN
# 197    536477   28066749.0     SAINT MARK ST          12262        NaN  NaN
# 198    137594   74120783.0       N SHERRY LN           1919        NaN   63
# 199    987773   16000068.0        ACADEMY DR           8833        NaN   20
#
#     Building SubAddressFlag  RouteExternalKey  ZipCode  ... UnitID  \
# 0        NaN            NaN               NaN    92867  ...    NaN
# 1        NaN            NaN               NaN    92887  ...    NaN
# 2        NaN            NaN               NaN    92606  ...    NaN
# 3        NaN            NaN               NaN    92646  ...    NaN
# 4        NaN            NaN               NaN    92865  ...    NaN
# ..       ...            ...               ...      ...  ...    ...
# 195      NaN            NaN               NaN    90631  ...    NaN
# 196      NaN            NaN               NaN    92662  ...    NaN
# 197      NaN            NaN               NaN    92845  ...    NaN
# 198      NaN            APT               NaN    92705  ...    NaN
# 199      NaN            APT               NaN    90621  ...    NaN
#
#     created_user            created_date  last_edited_user  \
# 0    ARCGISADMIN  2024/09/03 13:46:03+00       ARCGISADMIN
# 1    ARCGISADMIN  2024/09/03 13:46:03+00       ARCGISADMIN
# 2    ARCGISADMIN  2024/09/03 13:46:03+00       ARCGISADMIN
# 3    ARCGISADMIN  2024/09/03 13:46:03+00       ARCGISADMIN
# 4    ARCGISADMIN  2024/09/03 13:46:03+00       ARCGISADMIN
# ..           ...                     ...               ...
# 195  ARCGISADMIN  2024/09/03 13:46:03+00       ARCGISADMIN
# 196  ARCGISADMIN  2024/09/03 13:46:03+00       ARCGISADMIN
# 197  ARCGISADMIN  2024/09/03 13:46:03+00       ARCGISADMIN
# 198  ARCGISADMIN  2024/09/03 13:46:03+00       ARCGISADMIN
# 199  ARCGISADMIN  2024/09/03 13:46:03+00       ARCGISADMIN
#
#            last_edited_date         County StateAbbr ADD_TYPE   longitude  \
# 0    2024/09/03 13:46:03+00  Orange County        CA      NaN -117.833145
# 1    2024/09/03 13:46:03+00  Orange County        CA      NaN -117.694021
# 2    2024/09/03 13:46:03+00  Orange County        CA      NaN -117.794305
# 3    2024/09/03 13:46:03+00  Orange County        CA      NaN -117.986474
# 4    2024/09/03 13:46:03+00  Orange County        CA      NaN -117.863626
# ..                      ...            ...       ...      ...         ...
# 195  2024/09/03 13:46:03+00  Orange County        CA      NaN -117.975070
# 196  2024/09/03 13:46:03+00  Orange County        CA      NaN -117.890417
# 197  2024/09/03 13:46:03+00  Orange County        CA      NaN -118.029914
# 198  2024/09/03 13:46:03+00  Orange County        CA      NaN -117.841236
# 199  2024/09/03 13:46:03+00  Orange County        CA      NaN -117.979696
#
#       latitude
# 0    33.835846
# 1    33.879459
# 2    33.710949
# 3    33.698070
# 4    33.828042
# ..         ...
# 195  33.929139
# 196  33.604987
# 197  33.784306
# 198  33.763427
# 199  33.861213
#
# [200 rows x 24 columns]

# %% [markdown]
# # Put UCI as WAREHOUSE, add another address

# %%
# Create UCI warehouse data
warehouse_df = pd.DataFrame({
    'latitude': [33.6424],  # Latitude
    'longitude': [-117.8417],  # Longitude
    'Address': ['2006 McGaw Ave'],
    'City': ['Irvine'],
    'State': ['California'],
    'ZipCode': ['92697']
})

# Add missing columns to warehouse_df
for col in sampled_df.columns:
    if col not in warehouse_df.columns:
        warehouse_df[col] = None
        
# Combine warehouse and delivery locations
complete_df = pd.concat([warehouse_df, sampled_df], ignore_index=True)
# Out:
# /var/folders/4z/5nxj2j413mvcb6fq306y6t6w0000gn/T/ipykernel_13953/1691110066.py:17: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   complete_df = pd.concat([warehouse_df, sampled_df], ignore_index=True)

# %%
complete_df
# Out:
#       latitude   longitude                    Address              City  \
# 0    33.642400 -117.841700             2006 McGaw Ave            Irvine
# 1    33.835846 -117.833145     2003 E IVY HILL LN                ORANGE
# 2    33.879459 -117.694021    5550 SHADY CREEK LN           YORBA LINDA
# 3    33.710949 -117.794305          7 CONNECTICUT                IRVINE
# 4    33.698070 -117.986474         8131 KINER AVE      HUNTINGTON BEACH
# ..         ...         ...                        ...               ...
# 196  33.929139 -117.975070       391 S OAKLAND DR              LA HABRA
# 197  33.604987 -117.890417           112 ONYX AVE         NEWPORT BEACH
# 198  33.784306 -118.029914    12262 SAINT MARK ST          GARDEN GROVE
# 199  33.763427 -117.841236  1919 N SHERRY LN  APT  63         SANTA ANA
# 200  33.861213 -117.979696   8833 ACADEMY DR  APT  20        BUENA PARK
#
#           State ZipCode OBJECTID  AddressPtID      StreetName AddressNumber  \
# 0    California   92697     None          NaN            None          None
# 1    California   92867   104643   58043498.0   E IVY HILL LN          2003
# 2    California   92887   421143   86029680.0  SHADY CREEK LN          5550
# 3    California   92606   370941   32081918.0     CONNECTICUT             7
# 4    California   92646   692620   30036120.0       KINER AVE          8131
# ..          ...     ...      ...          ...             ...           ...
# 196  California   90631   911755   34003987.0    S OAKLAND DR           391
# 197  California   92662   551077   54008504.0        ONYX AVE           112
# 198  California   92845   536477   28066749.0   SAINT MARK ST         12262
# 199  California   92705   137594   74120783.0     N SHERRY LN          1919
# 200  California   90621   987773   16000068.0      ACADEMY DR          8833
#
#      ... RouteExternalKey FullNumber UnitID created_user  \
# 0    ...              NaN       None   None         None
# 1    ...              NaN        NaN    NaN  ARCGISADMIN
# 2    ...              NaN        NaN    NaN  ARCGISADMIN
# 3    ...              NaN        NaN    NaN  ARCGISADMIN
# 4    ...              NaN        NaN    NaN  ARCGISADMIN
# ..   ...              ...        ...    ...          ...
# 196  ...              NaN        NaN    NaN  ARCGISADMIN
# 197  ...              NaN        NaN    NaN  ARCGISADMIN
# 198  ...              NaN        NaN    NaN  ARCGISADMIN
# 199  ...              NaN        NaN    NaN  ARCGISADMIN
# 200  ...              NaN        NaN    NaN  ARCGISADMIN
#
#                created_date last_edited_user        last_edited_date  \
# 0                      None             None                    None
# 1    2024/09/03 13:46:03+00      ARCGISADMIN  2024/09/03 13:46:03+00
# 2    2024/09/03 13:46:03+00      ARCGISADMIN  2024/09/03 13:46:03+00
# 3    2024/09/03 13:46:03+00      ARCGISADMIN  2024/09/03 13:46:03+00
# 4    2024/09/03 13:46:03+00      ARCGISADMIN  2024/09/03 13:46:03+00
# ..                      ...              ...                     ...
# 196  2024/09/03 13:46:03+00      ARCGISADMIN  2024/09/03 13:46:03+00
# 197  2024/09/03 13:46:03+00      ARCGISADMIN  2024/09/03 13:46:03+00
# 198  2024/09/03 13:46:03+00      ARCGISADMIN  2024/09/03 13:46:03+00
# 199  2024/09/03 13:46:03+00      ARCGISADMIN  2024/09/03 13:46:03+00
# 200  2024/09/03 13:46:03+00      ARCGISADMIN  2024/09/03 13:46:03+00
#
#             County StateAbbr ADD_TYPE
# 0             None      None     None
# 1    Orange County        CA      NaN
# 2    Orange County        CA      NaN
# 3    Orange County        CA      NaN
# 4    Orange County        CA      NaN
# ..             ...       ...      ...
# 196  Orange County        CA      NaN
# 197  Orange County        CA      NaN
# 198  Orange County        CA      NaN
# 199  Orange County        CA      NaN
# 200  Orange County        CA      NaN
#
# [201 rows x 24 columns]

# %%
def create_distance_matrix(locations_df, api_key, batch_size=25):
    """
    Create a distance matrix using Google Maps API
    """
    # Create locations list
    locations = [f"{row['latitude']},{row['longitude']}" for _, row in locations_df.iterrows()]
    n_locations = len(locations)
    
    # Initialize matrix
    distance_matrix = np.zeros((n_locations, n_locations))
    element_count = 0
    
    # Calculate distances
    for i in range(0, n_locations):
        for j in range(i + 1, n_locations, batch_size):
            batch_end = min(j + batch_size, n_locations)
            destinations = locations[j:batch_end]
            
            # API request
            url = "https://maps.googleapis.com/maps/api/distancematrix/json"
            params = {
                'origins': locations[i],
                'destinations': '|'.join(destinations),
                'mode': 'driving',
                'key': api_key
            }
            
            try:
                response = requests.get(url, params=params)
                data = response.json()
                
                print(f"\nAPI Response for origin {i}:")
                print(f"Status: {data['status']}")
                if 'error_message' in data:
                    print(f"Error: {data['error_message']}")
                    continue
                
                if data['status'] == 'OK' and len(data['rows']) > 0:
                    elements = data['rows'][0]['elements']
                    for col_idx, element in enumerate(elements):
                        matrix_j = j + col_idx
                        if element['status'] == 'OK':
                            distance = element['distance']['value']
                            distance_matrix[i][matrix_j] = distance
                            distance_matrix[matrix_j][i] = distance
                            element_count += 1
                            print(f"Distance from {i} to {matrix_j}: {distance/1000:.2f} km")
                
                print(f"Processed: origin {i}, destinations {j}-{batch_end-1}. Elements: {element_count}")
                # Respect Google Maps API rate limits
                time.sleep(0.2)  # Increased delay to be safe
                
            except Exception as e:
                print(f"Error in batch {i},{j}: {str(e)}")
                time.sleep(1)  # Longer delay after an error
    
    # Create mapping
    locations_mapping = {}
    for idx, row in locations_df.iterrows():
        # Special handling for warehouse (index 0)
        if idx == 0:
            address = "UCI Warehouse: 2006 McGaw Ave, Irvine, CA 92614"
        else:
            address_parts = [str(row['AddressNumber']), row['StreetName']]
            if pd.notna(row['Unit']):
                address_parts.append(f"Unit {row['Unit']}")
            if pd.notna(row['Building']):
                address_parts.append(f"Building {row['Building']}")
            address = f"{' '.join(address_parts)}, {row['City']}, {row['State']} {row['ZipCode']}"
        
        locations_mapping[str(idx)] = {
            'latitude': row['latitude'],
            'longitude': row['longitude'],
            'address': address
        }
    
    # Save results
    np.save('distance_matrix.npy', distance_matrix)
    with open('locations_mapping.json', 'w') as f:
        json.dump(locations_mapping, f)
    
    print(f"\nFinal element count: {element_count}")
    print(f"Matrix filled: {np.count_nonzero(distance_matrix)} elements")
    return distance_matrix, locations_mapping

# %%
def load_cached_distances():
    """Load the cached distance matrix and location mapping"""
    try:
        distance_matrix = np.load('distance_matrix.npy')
        with open('locations_mapping.json', 'r') as f:
            locations_mapping = json.load(f)
        return distance_matrix, locations_mapping
    except:
        return None, None

# %%
# API key
api_key = "NOPE"  # Replace with your actual API key

# Try to load cached data first
distance_matrix, locations_mapping = load_cached_distances()

# If no cached data exists, create new distance matrix
if distance_matrix is None:
    print("Creating new distance matrix...")
    distance_matrix, locations_mapping = create_distance_matrix(complete_df, api_key)
    print("Distance matrix created and cached.")
else:
    print("Loaded cached distance matrix.")

print(f"Distance matrix shape: {distance_matrix.shape}")
# Out:
# Creating new distance matrix...
#
# API Response for origin 0:
# Status: OK
# Distance from 0 to 1: 26.65 km
# Distance from 0 to 2: 42.41 km
# Distance from 0 to 3: 11.01 km
# Distance from 0 to 4: 18.25 km
# Distance from 0 to 5: 31.64 km
# Distance from 0 to 6: 12.91 km
# Distance from 0 to 7: 29.33 km
# Distance from 0 to 8: 29.21 km
# Distance from 0 to 9: 28.09 km
# Distance from 0 to 10: 18.59 km
# Distance from 0 to 11: 18.98 km
# Distance from 0 to 12: 28.11 km
# Distance from 0 to 13: 18.90 km
# Distance from 0 to 14: 21.54 km
# Distance from 0 to 15: 33.19 km
# Distance from 0 to 16: 29.98 km
# Distance from 0 to 17: 15.41 km
# Distance from 0 to 18: 41.31 km
# Distance from 0 to 19: 25.95 km
# Distance from 0 to 20: 32.80 km
# Distance from 0 to 21: 15.93 km
# Distance from 0 to 22: 22.07 km
# Distance from 0 to 23: 13.36 km
# Distance from 0 to 24: 21.66 km
# Distance from 0 to 25: 34.45 km
# Processed: origin 0, destinations 1-25. Elements: 25
#
# API Response for origin 0:
# Status: OK
# Distance from 0 to 26: 28.33 km
# Distance from 0 to 27: 24.03 km
# Distance from 0 to 28: 18.80 km
# Distance from 0 to 29: 27.60 km
# Distance from 0 to 30: 18.61 km
# Distance from 0 to 31: 15.48 km
# Distance from 0 to 32: 15.69 km
# Distance from 0 to 33: 34.06 km
# Distance from 0 to 34: 14.39 km
# Distance from 0 to 35: 14.05 km
# Distance from 0 to 36: 14.22 km
# Distance from 0 to 37: 20.96 km
# Distance from 0 to 38: 24.85 km
# Distance from 0 to 39: 49.14 km
# Distance from 0 to 40: 10.70 km
# Distance from 0 to 41: 32.11 km
# Distance from 0 to 42: 9.37 km
# Distance from 0 to 43: 41.62 km
# Distance from 0 to 44: 31.30 km
# Distance from 0 to 45: 34.15 km
# Distance from 0 to 46: 7.72 km
# Distance from 0 to 47: 42.88 km
# Distance from 0 to 48: 40.21 km
# Distance from 0 to 49: 8.28 km
# Distance from 0 to 50: 38.40 km
# Processed: origin 0, destinations 26-50. Elements: 50
#
# API Response for origin 0:
# Status: OK
# Distance from 0 to 51: 23.96 km
# Distance from 0 to 52: 12.52 km
# Distance from 0 to 53: 41.20 km
# Distance from 0 to 54: 42.28 km
# Distance from 0 to 55: 34.75 km
# Distance from 0 to 56: 18.51 km
# Distance from 0 to 57: 19.93 km
# Distance from 0 to 58: 12.22 km
# Distance from 0 to 59: 25.70 km
# Distance from 0 to 60: 21.47 km
# Distance from 0 to 61: 11.44 km
# Distance from 0 to 62: 17.89 km
# Distance from 0 to 63: 28.05 km
# Distance from 0 to 64: 38.53 km
# Distance from 0 to 65: 24.34 km
# Distance from 0 to 66: 7.85 km
# Distance from 0 to 67: 20.18 km
# Distance from 0 to 68: 19.96 km
# Distance from 0 to 69: 10.94 km
# Distance from 0 to 70: 7.07 km
# Distance from 0 to 71: 38.52 km
# Distance from 0 to 72: 13.44 km
# Distance from 0 to 73: 20.33 km
# Distance from 0 to 74: 12.91 km
# Distance from 0 to 75: 5.29 km
# Processed: origin 0, destinations 51-75. Elements: 75
#
# API Response for origin 0:
# Status: OK
# Distance from 0 to 76: 24.30 km
# Distance from 0 to 77: 19.98 km
# Distance from 0 to 78: 26.35 km
# Distance from 0 to 79: 27.78 km
# Distance from 0 to 80: 29.54 km
# Distance from 0 to 81: 31.29 km
# Distance from 0 to 82: 38.23 km
# Distance from 0 to 83: 23.70 km
# Distance from 0 to 84: 36.58 km
# Distance from 0 to 85: 28.87 km
# Distance from 0 to 86: 35.62 km
# Distance from 0 to 87: 30.01 km
# Distance from 0 to 88: 35.74 km
# Distance from 0 to 89: 42.91 km
# Distance from 0 to 90: 22.81 km
# Distance from 0 to 91: 40.65 km
# Distance from 0 to 92: 40.11 km
# Distance from 0 to 93: 42.94 km
# Distance from 0 to 94: 22.23 km
# Distance from 0 to 95: 13.04 km
# Distance from 0 to 96: 20.16 km
# Distance from 0 to 97: 18.17 km
# Distance from 0 to 98: 19.26 km
# Distance from 0 to 99: 32.86 km
# Distance from 0 to 100: 10.61 km
# Processed: origin 0, destinations 76-100. Elements: 100
#
# API Response for origin 0:
# Status: OK
# Distance from 0 to 101: 39.44 km
# Distance from 0 to 102: 17.06 km
# Distance from 0 to 103: 44.33 km
# Distance from 0 to 104: 27.53 km
# Distance from 0 to 105: 37.26 km
# Distance from 0 to 106: 26.12 km
# Distance from 0 to 107: 31.50 km
# Distance from 0 to 108: 15.81 km
# Distance from 0 to 109: 41.06 km
# Distance from 0 to 110: 21.21 km
# Distance from 0 to 111: 45.32 km
# Distance from 0 to 112: 23.97 km
# Distance from 0 to 113: 11.77 km
# Distance from 0 to 114: 22.45 km
# Distance from 0 to 115: 24.57 km
# Distance from 0 to 116: 11.09 km
# Distance from 0 to 117: 20.28 km
# Distance from 0 to 118: 23.31 km
# Distance from 0 to 119: 20.90 km
# Distance from 0 to 120: 39.76 km
# Distance from 0 to 121: 40.74 km
# Distance from 0 to 122: 35.69 km
# Distance from 0 to 123: 7.05 km
# Distance from 0 to 124: 36.85 km
# Distance from 0 to 125: 39.11 km
# Processed: origin 0, destinations 101-125. Elements: 125
#
# API Response for origin 0:
# Status: OK
# Distance from 0 to 126: 23.92 km
# Distance from 0 to 127: 24.07 km
# Distance from 0 to 128: 28.49 km
# Distance from 0 to 129: 27.32 km
# Distance from 0 to 130: 25.47 km
# Distance from 0 to 131: 32.11 km
# Distance from 0 to 132: 33.17 km
# Distance from 0 to 133: 9.79 km
# Distance from 0 to 134: 41.66 km
# Distance from 0 to 135: 17.97 km
# Distance from 0 to 136: 13.31 km
# Distance from 0 to 137: 39.02 km
# Distance from 0 to 138: 23.36 km
# Distance from 0 to 139: 27.24 km
# Distance from 0 to 140: 16.20 km
# Distance from 0 to 141: 17.60 km
# Distance from 0 to 142: 7.03 km
# Distance from 0 to 143: 9.32 km
# Distance from 0 to 144: 32.59 km
# Distance from 0 to 145: 19.88 km
# Distance from 0 to 146: 13.02 km
# Distance from 0 to 147: 33.88 km
# Distance from 0 to 148: 20.17 km
# Distance from 0 to 149: 31.52 km
# Distance from 0 to 150: 31.21 km
# Processed: origin 0, destinations 126-150. Elements: 150
#
# API Response for origin 0:
# Status: OK
# Distance from 0 to 151: 18.62 km
# Distance from 0 to 152: 7.05 km
# Distance from 0 to 153: 18.48 km
# Distance from 0 to 154: 21.67 km
# Distance from 0 to 155: 17.52 km
# Distance from 0 to 156: 41.61 km
# Distance from 0 to 157: 24.74 km
# Distance from 0 to 158: 39.36 km
# Distance from 0 to 159: 22.76 km
# Distance from 0 to 160: 36.24 km
# Distance from 0 to 161: 22.28 km
# Distance from 0 to 162: 14.23 km
# Distance from 0 to 163: 24.50 km
# Distance from 0 to 164: 32.46 km
# Distance from 0 to 165: 39.96 km
# Distance from 0 to 166: 33.24 km
# Distance from 0 to 167: 6.80 km
# Distance from 0 to 168: 38.86 km
# Distance from 0 to 169: 8.47 km
# Distance from 0 to 170: 36.53 km
# Distance from 0 to 171: 18.89 km
# Distance from 0 to 172: 17.08 km
# Distance from 0 to 173: 43.13 km
# Distance from 0 to 174: 18.01 km
# Distance from 0 to 175: 32.13 km
# Processed: origin 0, destinations 151-175. Elements: 175
#
# API Response for origin 0:
# Status: OK
# Distance from 0 to 176: 18.06 km
# Distance from 0 to 177: 7.55 km
# Distance from 0 to 178: 14.08 km
# Distance from 0 to 179: 4.35 km
# Distance from 0 to 180: 39.68 km
# Distance from 0 to 181: 19.50 km
# Distance from 0 to 182: 38.83 km
# Distance from 0 to 183: 5.42 km
# Distance from 0 to 184: 19.31 km
# Distance from 0 to 185: 47.23 km
# Distance from 0 to 186: 37.84 km
# Distance from 0 to 187: 31.85 km
# Distance from 0 to 188: 20.49 km
# Distance from 0 to 189: 28.53 km
# Distance from 0 to 190: 13.71 km
# Distance from 0 to 191: 13.23 km
# Distance from 0 to 192: 14.86 km
# Distance from 0 to 193: 15.64 km
# Distance from 0 to 194: 11.74 km
# Distance from 0 to 195: 16.95 km
# Distance from 0 to 196: 46.04 km
# Distance from 0 to 197: 7.72 km
# Distance from 0 to 198: 26.96 km
# Distance from 0 to 199: 19.43 km
# Distance from 0 to 200: 35.52 km
# Processed: origin 0, destinations 176-200. Elements: 200
#
# API Response for origin 1:
# Status: OK
# Distance from 1 to 2: 16.81 km
# Distance from 1 to 3: 18.90 km
# Distance from 1 to 4: 30.36 km
# Distance from 1 to 5: 3.94 km
# Distance from 1 to 6: 22.24 km
# Distance from 1 to 7: 18.71 km
# Distance from 1 to 8: 45.95 km
# Distance from 1 to 9: 22.61 km
# Distance from 1 to 10: 20.25 km
# Distance from 1 to 11: 31.59 km
# Distance from 1 to 12: 43.80 km
# Distance from 1 to 13: 22.30 km
# Distance from 1 to 14: 39.83 km
# Distance from 1 to 15: 49.92 km
# Distance from 1 to 16: 43.34 km
# Distance from 1 to 17: 28.73 km
# Distance from 1 to 18: 22.96 km
# Distance from 1 to 19: 15.33 km
# Distance from 1 to 20: 17.21 km
# Distance from 1 to 21: 12.78 km
# Distance from 1 to 22: 34.20 km
# Distance from 1 to 23: 22.69 km
# Distance from 1 to 24: 33.13 km
# Distance from 1 to 25: 58.45 km
# Distance from 1 to 26: 38.93 km
# Processed: origin 1, destinations 2-26. Elements: 225
#
# API Response for origin 1:
# Status: OK
# Distance from 1 to 27: 33.88 km
# Distance from 1 to 28: 14.54 km
# Distance from 1 to 29: 43.01 km
# Distance from 1 to 30: 30.69 km
# Distance from 1 to 31: 15.99 km
# Distance from 1 to 32: 12.90 km
# Distance from 1 to 33: 8.64 km
# Distance from 1 to 34: 24.43 km
# Distance from 1 to 35: 21.68 km
# Distance from 1 to 36: 21.23 km
# Distance from 1 to 37: 33.08 km
# Distance from 1 to 38: 43.50 km
# Distance from 1 to 39: 23.72 km
# Distance from 1 to 40: 22.26 km
# Distance from 1 to 41: 9.20 km
# Distance from 1 to 42: 24.35 km
# Distance from 1 to 43: 16.19 km
# Distance from 1 to 44: 32.98 km
# Distance from 1 to 45: 8.73 km
# Distance from 1 to 46: 29.77 km
# Distance from 1 to 47: 17.45 km
# Distance from 1 to 48: 56.94 km
# Distance from 1 to 49: 20.45 km
# Distance from 1 to 50: 20.05 km
# Distance from 1 to 51: 20.55 km
# Processed: origin 1, destinations 27-51. Elements: 250
#
# API Response for origin 1:
# Status: OK
# Distance from 1 to 52: 24.53 km
# Distance from 1 to 53: 57.93 km
# Distance from 1 to 54: 16.86 km
# Distance from 1 to 55: 51.48 km
# Distance from 1 to 56: 11.17 km
# Distance from 1 to 57: 13.85 km
# Distance from 1 to 58: 20.70 km
# Distance from 1 to 59: 37.81 km
# Distance from 1 to 60: 14.36 km
# Distance from 1 to 61: 18.45 km
# Distance from 1 to 62: 31.21 km
# Distance from 1 to 63: 27.51 km
# Distance from 1 to 64: 28.59 km
# Distance from 1 to 65: 15.54 km
# Distance from 1 to 66: 25.55 km
# Distance from 1 to 67: 15.30 km
# Distance from 1 to 68: 27.75 km
# Distance from 1 to 69: 23.59 km
# Distance from 1 to 70: 21.54 km
# Distance from 1 to 71: 12.92 km
# Distance from 1 to 72: 17.19 km
# Distance from 1 to 73: 8.81 km
# Distance from 1 to 74: 30.02 km
# Distance from 1 to 75: 21.35 km
# Distance from 1 to 76: 30.20 km
# Processed: origin 1, destinations 52-76. Elements: 275
#
# API Response for origin 1:
# Status: OK
# Distance from 1 to 77: 17.97 km
# Distance from 1 to 78: 39.70 km
# Distance from 1 to 79: 41.14 km
# Distance from 1 to 80: 47.46 km
# Distance from 1 to 81: 26.45 km
# Distance from 1 to 82: 19.59 km
# Distance from 1 to 83: 24.84 km
# Distance from 1 to 84: 10.97 km
# Distance from 1 to 85: 42.22 km
# Distance from 1 to 86: 59.44 km
# Distance from 1 to 87: 19.39 km
# Distance from 1 to 88: 7.77 km
# Distance from 1 to 89: 17.49 km
# Distance from 1 to 90: 18.55 km
# Distance from 1 to 91: 15.23 km
# Distance from 1 to 92: 14.69 km
# Distance from 1 to 93: 25.05 km
# Distance from 1 to 94: 17.98 km
# Distance from 1 to 95: 24.99 km
# Distance from 1 to 96: 35.74 km
# Distance from 1 to 97: 12.36 km
# Distance from 1 to 98: 31.35 km
# Distance from 1 to 99: 9.69 km
# Distance from 1 to 100: 27.94 km
# Distance from 1 to 101: 21.09 km
# Processed: origin 1, destinations 77-101. Elements: 300
#
# API Response for origin 1:
# Status: OK
# Distance from 1 to 102: 14.98 km
# Distance from 1 to 103: 61.06 km
# Distance from 1 to 104: 33.55 km
# Distance from 1 to 105: 18.91 km
# Distance from 1 to 106: 37.37 km
# Distance from 1 to 107: 24.82 km
# Distance from 1 to 108: 15.19 km
# Distance from 1 to 109: 57.79 km
# Distance from 1 to 110: 37.35 km
# Distance from 1 to 111: 19.89 km
# Distance from 1 to 112: 35.13 km
# Distance from 1 to 113: 35.26 km
# Distance from 1 to 114: 11.61 km
# Distance from 1 to 115: 21.65 km
# Distance from 1 to 116: 18.22 km
# Distance from 1 to 117: 14.60 km
# Distance from 1 to 118: 4.78 km
# Distance from 1 to 119: 21.69 km
# Distance from 1 to 120: 14.16 km
# Distance from 1 to 121: 15.14 km
# Distance from 1 to 122: 10.27 km
# Distance from 1 to 123: 20.39 km
# Distance from 1 to 124: 11.25 km
# Distance from 1 to 125: 20.83 km
# Distance from 1 to 126: 23.30 km
# Processed: origin 1, destinations 102-126. Elements: 325
#
# API Response for origin 1:
# Status: OK
# Distance from 1 to 127: 6.43 km
# Distance from 1 to 128: 24.06 km
# Distance from 1 to 129: 45.61 km
# Distance from 1 to 130: 29.26 km
# Distance from 1 to 131: 3.39 km
# Distance from 1 to 132: 22.74 km
# Distance from 1 to 133: 33.29 km
# Distance from 1 to 134: 58.39 km
# Distance from 1 to 135: 25.77 km
# Distance from 1 to 136: 26.63 km
# Distance from 1 to 137: 10.01 km
# Distance from 1 to 138: 38.77 km
# Distance from 1 to 139: 4.90 km
# Distance from 1 to 140: 13.41 km
# Distance from 1 to 141: 41.09 km
# Distance from 1 to 142: 24.51 km
# Distance from 1 to 143: 24.08 km
# Distance from 1 to 144: 6.99 km
# Distance from 1 to 145: 38.79 km
# Distance from 1 to 146: 25.15 km
# Distance from 1 to 147: 5.91 km
# Distance from 1 to 148: 9.69 km
# Distance from 1 to 149: 45.82 km
# Distance from 1 to 150: 8.64 km
# Distance from 1 to 151: 30.60 km
# Processed: origin 1, destinations 127-151. Elements: 350
#
# API Response for origin 1:
# Status: OK
# Distance from 1 to 152: 21.27 km
# Distance from 1 to 153: 30.86 km
# Distance from 1 to 154: 44.96 km
# Distance from 1 to 155: 15.61 km
# Distance from 1 to 156: 58.34 km
# Distance from 1 to 157: 24.12 km
# Distance from 1 to 158: 21.01 km
# Distance from 1 to 159: 38.17 km
# Distance from 1 to 160: 8.05 km
# Distance from 1 to 161: 26.13 km
# Distance from 1 to 162: 18.30 km
# Distance from 1 to 163: 23.88 km
# Distance from 1 to 164: 45.81 km
# Distance from 1 to 165: 14.54 km
# Distance from 1 to 166: 34.91 km
# Distance from 1 to 167: 21.42 km
# Distance from 1 to 168: 19.09 km
# Distance from 1 to 169: 25.33 km
# Distance from 1 to 170: 10.27 km
# Distance from 1 to 171: 30.97 km
# Distance from 1 to 172: 18.77 km
# Distance from 1 to 173: 17.53 km
# Distance from 1 to 174: 15.71 km
# Distance from 1 to 175: 23.43 km
# Distance from 1 to 176: 11.24 km
# Processed: origin 1, destinations 152-176. Elements: 375
#
# API Response for origin 1:
# Status: OK
# Distance from 1 to 177: 23.95 km
# Distance from 1 to 178: 24.93 km
# Distance from 1 to 179: 26.40 km
# Distance from 1 to 180: 21.40 km
# Distance from 1 to 181: 12.11 km
# Distance from 1 to 182: 52.18 km
# Distance from 1 to 183: 27.48 km
# Distance from 1 to 184: 34.98 km
# Distance from 1 to 185: 27.76 km
# Distance from 1 to 186: 12.41 km
# Distance from 1 to 187: 28.54 km
# Distance from 1 to 188: 12.11 km
# Distance from 1 to 189: 41.68 km
# Distance from 1 to 190: 27.03 km
# Distance from 1 to 191: 19.24 km
# Distance from 1 to 192: 17.25 km
# Distance from 1 to 193: 12.93 km
# Distance from 1 to 194: 20.43 km
# Distance from 1 to 195: 20.85 km
# Distance from 1 to 196: 27.76 km
# Distance from 1 to 197: 29.77 km
# Distance from 1 to 198: 27.99 km
# Distance from 1 to 199: 10.45 km
# Distance from 1 to 200: 16.98 km
# Processed: origin 1, destinations 177-200. Elements: 399
#
# API Response for origin 2:
# Status: OK
# Distance from 2 to 3: 30.39 km
# Distance from 2 to 4: 45.64 km
# Distance from 2 to 5: 20.94 km
# Distance from 2 to 6: 37.52 km
# Distance from 2 to 7: 33.98 km
# Distance from 2 to 8: 57.91 km
# Distance from 2 to 9: 35.34 km
# Distance from 2 to 10: 35.53 km
# Distance from 2 to 11: 43.55 km
# Distance from 2 to 12: 40.19 km
# Distance from 2 to 13: 32.50 km
# Distance from 2 to 14: 51.80 km
# Distance from 2 to 15: 59.88 km
# Distance from 2 to 16: 39.73 km
# Distance from 2 to 17: 44.01 km
# Distance from 2 to 18: 35.70 km
# Distance from 2 to 19: 30.61 km
# Distance from 2 to 20: 29.94 km
# Distance from 2 to 21: 28.06 km
# Distance from 2 to 22: 49.48 km
# Distance from 2 to 23: 37.97 km
# Distance from 2 to 24: 45.09 km
# Distance from 2 to 25: 54.84 km
# Distance from 2 to 26: 47.88 km
# Distance from 2 to 27: 49.15 km
# Processed: origin 2, destinations 3-27. Elements: 424
#
# API Response for origin 2:
# Status: OK
# Distance from 2 to 28: 29.82 km
# Distance from 2 to 29: 54.24 km
# Distance from 2 to 30: 45.97 km
# Distance from 2 to 31: 31.27 km
# Distance from 2 to 32: 28.18 km
# Distance from 2 to 33: 21.38 km
# Distance from 2 to 34: 32.60 km
# Distance from 2 to 35: 32.78 km
# Distance from 2 to 36: 36.51 km
# Distance from 2 to 37: 48.35 km
# Distance from 2 to 38: 55.47 km
# Distance from 2 to 39: 36.45 km
# Distance from 2 to 40: 37.54 km
# Distance from 2 to 41: 13.41 km
# Distance from 2 to 42: 39.63 km
# Distance from 2 to 43: 28.93 km
# Distance from 2 to 44: 48.26 km
# Distance from 2 to 45: 21.46 km
# Distance from 2 to 46: 45.05 km
# Distance from 2 to 47: 21.66 km
# Distance from 2 to 48: 68.91 km
# Distance from 2 to 49: 35.73 km
# Distance from 2 to 50: 32.79 km
# Distance from 2 to 51: 35.83 km
# Distance from 2 to 52: 36.51 km
# Processed: origin 2, destinations 28-52. Elements: 449
#
# API Response for origin 2:
# Status: OK
# Distance from 2 to 53: 69.89 km
# Distance from 2 to 54: 29.59 km
# Distance from 2 to 55: 63.44 km
# Distance from 2 to 56: 26.45 km
# Distance from 2 to 57: 29.88 km
# Distance from 2 to 58: 35.98 km
# Distance from 2 to 59: 53.09 km
# Distance from 2 to 60: 28.50 km
# Distance from 2 to 61: 33.73 km
# Distance from 2 to 62: 46.49 km
# Distance from 2 to 63: 42.79 km
# Distance from 2 to 64: 41.33 km
# Distance from 2 to 65: 25.72 km
# Distance from 2 to 66: 35.26 km
# Distance from 2 to 67: 31.33 km
# Distance from 2 to 68: 34.10 km
# Distance from 2 to 69: 38.87 km
# Distance from 2 to 70: 34.52 km
# Distance from 2 to 71: 8.84 km
# Distance from 2 to 72: 32.47 km
# Distance from 2 to 73: 24.09 km
# Distance from 2 to 74: 45.30 km
# Distance from 2 to 75: 36.63 km
# Distance from 2 to 76: 45.48 km
# Distance from 2 to 77: 33.25 km
# Processed: origin 2, destinations 53-77. Elements: 474
#
# API Response for origin 2:
# Status: OK
# Distance from 2 to 78: 36.10 km
# Distance from 2 to 79: 37.53 km
# Distance from 2 to 80: 59.42 km
# Distance from 2 to 81: 39.18 km
# Distance from 2 to 82: 32.32 km
# Distance from 2 to 83: 40.12 km
# Distance from 2 to 84: 8.73 km
# Distance from 2 to 85: 38.62 km
# Distance from 2 to 86: 55.84 km
# Distance from 2 to 87: 34.67 km
# Distance from 2 to 88: 13.18 km
# Distance from 2 to 89: 30.22 km
# Distance from 2 to 90: 27.56 km
# Distance from 2 to 91: 27.96 km
# Distance from 2 to 92: 27.43 km
# Distance from 2 to 93: 37.78 km
# Distance from 2 to 94: 27.51 km
# Distance from 2 to 95: 36.95 km
# Distance from 2 to 96: 47.71 km
# Distance from 2 to 97: 27.64 km
# Distance from 2 to 98: 46.62 km
# Distance from 2 to 99: 10.84 km
# Distance from 2 to 100: 39.90 km
# Distance from 2 to 101: 33.83 km
# Distance from 2 to 102: 30.26 km
# Processed: origin 2, destinations 78-102. Elements: 499
#
# API Response for origin 2:
# Status: OK
# Distance from 2 to 103: 73.03 km
# Distance from 2 to 104: 48.83 km
# Distance from 2 to 105: 31.64 km
# Distance from 2 to 106: 49.90 km
# Distance from 2 to 107: 37.56 km
# Distance from 2 to 108: 30.47 km
# Distance from 2 to 109: 69.76 km
# Distance from 2 to 110: 49.31 km
# Distance from 2 to 111: 32.63 km
# Distance from 2 to 112: 47.09 km
# Distance from 2 to 113: 50.54 km
# Distance from 2 to 114: 21.86 km
# Distance from 2 to 115: 36.93 km
# Distance from 2 to 116: 31.45 km
# Distance from 2 to 117: 29.88 km
# Distance from 2 to 118: 20.38 km
# Distance from 2 to 119: 36.97 km
# Distance from 2 to 120: 26.89 km
# Distance from 2 to 121: 27.87 km
# Distance from 2 to 122: 23.00 km
# Distance from 2 to 123: 34.64 km
# Distance from 2 to 124: 23.98 km
# Distance from 2 to 125: 33.57 km
# Distance from 2 to 126: 38.58 km
# Distance from 2 to 127: 22.01 km
# Processed: origin 2, destinations 103-127. Elements: 524
#
# API Response for origin 2:
# Status: OK
# Distance from 2 to 128: 36.79 km
# Distance from 2 to 129: 57.57 km
# Distance from 2 to 130: 44.54 km
# Distance from 2 to 131: 19.24 km
# Distance from 2 to 132: 35.47 km
# Distance from 2 to 133: 48.56 km
# Distance from 2 to 134: 70.35 km
# Distance from 2 to 135: 32.02 km
# Distance from 2 to 136: 41.91 km
# Distance from 2 to 137: 9.34 km
# Distance from 2 to 138: 50.73 km
# Distance from 2 to 139: 16.52 km
# Distance from 2 to 140: 28.69 km
# Distance from 2 to 141: 51.16 km
# Distance from 2 to 142: 36.16 km
# Distance from 2 to 143: 34.83 km
# Distance from 2 to 144: 19.73 km
# Distance from 2 to 145: 50.75 km
# Distance from 2 to 146: 40.43 km
# Distance from 2 to 147: 13.65 km
# Distance from 2 to 148: 24.97 km
# Distance from 2 to 149: 42.21 km
# Distance from 2 to 150: 12.53 km
# Distance from 2 to 151: 42.56 km
# Distance from 2 to 152: 36.55 km
# Processed: origin 2, destinations 128-152. Elements: 549
#
# API Response for origin 2:
# Status: OK
# Distance from 2 to 153: 41.95 km
# Distance from 2 to 154: 41.36 km
# Distance from 2 to 155: 30.89 km
# Distance from 2 to 156: 70.30 km
# Distance from 2 to 157: 39.40 km
# Distance from 2 to 158: 33.75 km
# Distance from 2 to 159: 50.13 km
# Distance from 2 to 160: 20.79 km
# Distance from 2 to 161: 41.41 km
# Distance from 2 to 162: 33.58 km
# Distance from 2 to 163: 39.16 km
# Distance from 2 to 164: 42.20 km
# Distance from 2 to 165: 27.27 km
# Distance from 2 to 166: 50.19 km
# Distance from 2 to 167: 34.39 km
# Distance from 2 to 168: 31.83 km
# Distance from 2 to 169: 40.61 km
# Distance from 2 to 170: 13.41 km
# Distance from 2 to 171: 46.25 km
# Distance from 2 to 172: 34.05 km
# Distance from 2 to 173: 30.26 km
# Distance from 2 to 174: 30.99 km
# Distance from 2 to 175: 36.17 km
# Distance from 2 to 176: 26.52 km
# Distance from 2 to 177: 39.23 km
# Processed: origin 2, destinations 153-177. Elements: 574
#
# API Response for origin 2:
# Status: OK
# Distance from 2 to 178: 36.89 km
# Distance from 2 to 179: 41.68 km
# Distance from 2 to 180: 34.13 km
# Distance from 2 to 181: 27.39 km
# Distance from 2 to 182: 48.58 km
# Distance from 2 to 183: 42.76 km
# Distance from 2 to 184: 46.94 km
# Distance from 2 to 185: 40.50 km
# Distance from 2 to 186: 25.15 km
# Distance from 2 to 187: 41.28 km
# Distance from 2 to 188: 27.39 km
# Distance from 2 to 189: 49.03 km
# Distance from 2 to 190: 42.31 km
# Distance from 2 to 191: 34.52 km
# Distance from 2 to 192: 32.53 km
# Distance from 2 to 193: 28.21 km
# Distance from 2 to 194: 35.71 km
# Distance from 2 to 195: 29.74 km
# Distance from 2 to 196: 40.49 km
# Distance from 2 to 197: 45.05 km
# Distance from 2 to 198: 43.27 km
# Distance from 2 to 199: 25.73 km
# Distance from 2 to 200: 29.71 km
# Processed: origin 2, destinations 178-200. Elements: 597
#
# API Response for origin 3:
# Status: OK
# Distance from 3 to 4: 21.64 km
# Distance from 3 to 5: 21.88 km
# Distance from 3 to 6: 8.31 km
# Distance from 3 to 7: 20.10 km
# Distance from 3 to 8: 32.02 km
# Distance from 3 to 9: 28.87 km
# Distance from 3 to 10: 21.65 km
# Distance from 3 to 11: 17.66 km
# Distance from 3 to 12: 24.31 km
# Distance from 3 to 13: 8.11 km
# Distance from 3 to 14: 25.91 km
# Distance from 3 to 15: 35.99 km
# Distance from 3 to 16: 23.85 km
# Distance from 3 to 17: 20.07 km
# Distance from 3 to 18: 32.09 km
# Distance from 3 to 19: 16.73 km
# Distance from 3 to 20: 23.58 km
# Distance from 3 to 21: 4.98 km
# Distance from 3 to 22: 25.47 km
# Distance from 3 to 23: 8.76 km
# Distance from 3 to 24: 19.20 km
# Distance from 3 to 25: 38.96 km
# Distance from 3 to 26: 25.00 km
# Distance from 3 to 27: 27.42 km
# Distance from 3 to 28: 4.81 km
# Processed: origin 3, destinations 4-28. Elements: 622
#
# API Response for origin 3:
# Status: OK
# Distance from 3 to 29: 29.08 km
# Distance from 3 to 30: 21.97 km
# Distance from 3 to 31: 8.55 km
# Distance from 3 to 32: 5.30 km
# Distance from 3 to 33: 24.31 km
# Distance from 3 to 34: 9.02 km
# Distance from 3 to 35: 8.61 km
# Distance from 3 to 36: 17.62 km
# Distance from 3 to 37: 24.35 km
# Distance from 3 to 38: 29.58 km
# Distance from 3 to 39: 39.38 km
# Distance from 3 to 40: 13.53 km
# Distance from 3 to 41: 22.56 km
# Distance from 3 to 42: 7.44 km
# Distance from 3 to 43: 31.86 km
# Distance from 3 to 44: 34.37 km
# Distance from 3 to 45: 24.39 km
# Distance from 3 to 46: 16.40 km
# Distance from 3 to 47: 33.12 km
# Distance from 3 to 48: 43.02 km
# Distance from 3 to 49: 11.77 km
# Distance from 3 to 50: 29.18 km
# Distance from 3 to 51: 21.95 km
# Distance from 3 to 52: 10.61 km
# Distance from 3 to 53: 44.00 km
# Processed: origin 3, destinations 29-53. Elements: 647
#
# API Response for origin 3:
# Status: OK
# Distance from 3 to 54: 32.53 km
# Distance from 3 to 55: 37.55 km
# Distance from 3 to 56: 9.28 km
# Distance from 3 to 57: 10.71 km
# Distance from 3 to 58: 16.31 km
# Distance from 3 to 59: 29.09 km
# Distance from 3 to 60: 6.26 km
# Distance from 3 to 61: 7.73 km
# Distance from 3 to 62: 22.55 km
# Distance from 3 to 63: 28.91 km
# Distance from 3 to 64: 37.72 km
# Distance from 3 to 65: 7.88 km
# Distance from 3 to 66: 5.96 km
# Distance from 3 to 67: 10.96 km
# Distance from 3 to 68: 13.04 km
# Distance from 3 to 69: 6.17 km
# Distance from 3 to 70: 4.47 km
# Distance from 3 to 71: 26.32 km
# Distance from 3 to 72: 12.80 km
# Distance from 3 to 73: 12.41 km
# Distance from 3 to 74: 21.35 km
# Distance from 3 to 75: 8.87 km
# Distance from 3 to 76: 27.71 km
# Distance from 3 to 77: 19.37 km
# Distance from 3 to 78: 20.21 km
# Processed: origin 3, destinations 54-78. Elements: 672
#
# API Response for origin 3:
# Status: OK
# Distance from 3 to 79: 21.65 km
# Distance from 3 to 80: 33.53 km
# Distance from 3 to 81: 33.72 km
# Distance from 3 to 82: 29.01 km
# Distance from 3 to 83: 26.23 km
# Distance from 3 to 84: 26.17 km
# Distance from 3 to 85: 22.74 km
# Distance from 3 to 86: 39.96 km
# Distance from 3 to 87: 20.78 km
# Distance from 3 to 88: 22.92 km
# Distance from 3 to 89: 33.16 km
# Distance from 3 to 90: 4.52 km
# Distance from 3 to 91: 30.89 km
# Distance from 3 to 92: 30.36 km
# Distance from 3 to 93: 34.17 km
# Distance from 3 to 94: 8.16 km
# Distance from 3 to 95: 11.06 km
# Distance from 3 to 96: 21.82 km
# Distance from 3 to 97: 7.47 km
# Distance from 3 to 98: 22.62 km
# Distance from 3 to 99: 23.31 km
# Distance from 3 to 100: 14.01 km
# Distance from 3 to 101: 30.22 km
# Distance from 3 to 102: 3.74 km
# Distance from 3 to 103: 47.14 km
# Processed: origin 3, destinations 79-103. Elements: 697
#
# API Response for origin 3:
# Status: OK
# Distance from 3 to 104: 34.95 km
# Distance from 3 to 105: 28.03 km
# Distance from 3 to 106: 23.45 km
# Distance from 3 to 107: 31.43 km
# Distance from 3 to 108: 10.40 km
# Distance from 3 to 109: 43.87 km
# Distance from 3 to 110: 23.42 km
# Distance from 3 to 111: 35.56 km
# Distance from 3 to 112: 21.20 km
# Distance from 3 to 113: 19.22 km
# Distance from 3 to 114: 9.87 km
# Distance from 3 to 115: 23.05 km
# Distance from 3 to 116: 1.98 km
# Distance from 3 to 117: 11.05 km
# Distance from 3 to 118: 13.63 km
# Distance from 3 to 119: 23.09 km
# Distance from 3 to 120: 27.03 km
# Distance from 3 to 121: 27.20 km
# Distance from 3 to 122: 25.93 km
# Distance from 3 to 123: 6.12 km
# Distance from 3 to 124: 27.14 km
# Distance from 3 to 125: 29.89 km
# Distance from 3 to 126: 24.70 km
# Distance from 3 to 127: 13.53 km
# Distance from 3 to 128: 29.71 km
# Processed: origin 3, destinations 104-128. Elements: 722
#
# API Response for origin 3:
# Status: OK
# Distance from 3 to 129: 31.68 km
# Distance from 3 to 130: 30.66 km
# Distance from 3 to 131: 23.13 km
# Distance from 3 to 132: 31.86 km
# Distance from 3 to 133: 15.31 km
# Distance from 3 to 134: 44.46 km
# Distance from 3 to 135: 11.84 km
# Distance from 3 to 136: 17.97 km
# Distance from 3 to 137: 26.83 km
# Distance from 3 to 138: 24.84 km
# Distance from 3 to 139: 19.03 km
# Distance from 3 to 140: 5.81 km
# Distance from 3 to 141: 25.27 km
# Distance from 3 to 142: 6.03 km
# Distance from 3 to 143: 5.53 km
# Distance from 3 to 144: 22.92 km
# Distance from 3 to 145: 24.86 km
# Distance from 3 to 146: 16.42 km
# Distance from 3 to 147: 21.71 km
# Distance from 3 to 148: 10.94 km
# Distance from 3 to 149: 26.23 km
# Distance from 3 to 150: 21.66 km
# Distance from 3 to 151: 16.67 km
# Distance from 3 to 152: 12.59 km
# Distance from 3 to 153: 16.94 km
# Processed: origin 3, destinations 129-153. Elements: 747
#
# API Response for origin 3:
# Status: OK
# Distance from 3 to 154: 21.28 km
# Distance from 3 to 155: 2.27 km
# Distance from 3 to 156: 44.41 km
# Distance from 3 to 157: 25.52 km
# Distance from 3 to 158: 30.14 km
# Distance from 3 to 159: 24.25 km
# Distance from 3 to 160: 26.49 km
# Distance from 3 to 161: 25.69 km
# Distance from 3 to 162: 10.87 km
# Distance from 3 to 163: 25.27 km
# Distance from 3 to 164: 26.32 km
# Distance from 3 to 165: 30.21 km
# Distance from 3 to 166: 36.30 km
# Distance from 3 to 167: 5.87 km
# Distance from 3 to 168: 29.63 km
# Distance from 3 to 169: 16.67 km
# Distance from 3 to 170: 30.86 km
# Distance from 3 to 171: 22.25 km
# Distance from 3 to 172: 15.89 km
# Distance from 3 to 173: 27.96 km
# Distance from 3 to 174: 17.10 km
# Distance from 3 to 175: 32.56 km
# Distance from 3 to 176: 8.84 km
# Distance from 3 to 177: 15.29 km
# Distance from 3 to 178: 11.00 km
# Processed: origin 3, destinations 154-178. Elements: 772
#
# API Response for origin 3:
# Status: OK
# Distance from 3 to 179: 13.03 km
# Distance from 3 to 180: 30.45 km
# Distance from 3 to 181: 10.28 km
# Distance from 3 to 182: 32.70 km
# Distance from 3 to 183: 14.10 km
# Distance from 3 to 184: 21.05 km
# Distance from 3 to 185: 38.01 km
# Distance from 3 to 186: 28.08 km
# Distance from 3 to 187: 34.28 km
# Distance from 3 to 188: 8.68 km
# Distance from 3 to 189: 27.76 km
# Distance from 3 to 190: 18.37 km
# Distance from 3 to 191: 4.13 km
# Distance from 3 to 192: 4.60 km
# Distance from 3 to 193: 4.65 km
# Distance from 3 to 194: 16.04 km
# Distance from 3 to 195: 6.07 km
# Distance from 3 to 196: 36.81 km
# Distance from 3 to 197: 16.40 km
# Distance from 3 to 198: 29.39 km
# Distance from 3 to 199: 9.92 km
# Distance from 3 to 200: 26.29 km
# Processed: origin 3, destinations 179-200. Elements: 794
#
# API Response for origin 4:
# Status: OK
# Distance from 4 to 5: 27.96 km
# Distance from 4 to 6: 29.32 km
# Distance from 4 to 7: 15.08 km
# Distance from 4 to 8: 43.05 km
# Distance from 4 to 9: 13.53 km
# Distance from 4 to 10: 10.39 km
# Distance from 4 to 11: 30.85 km
# Distance from 4 to 12: 38.57 km
# Distance from 4 to 13: 30.50 km
# Distance from 4 to 14: 35.37 km
# Distance from 4 to 15: 47.02 km
# Distance from 4 to 16: 41.59 km
# Distance from 4 to 17: 12.45 km
# Distance from 4 to 18: 29.87 km
# Distance from 4 to 19: 18.66 km
# Distance from 4 to 20: 18.22 km
# Distance from 4 to 21: 18.86 km
# Distance from 4 to 22: 7.87 km
# Distance from 4 to 23: 29.77 km
# Distance from 4 to 24: 32.38 km
# Distance from 4 to 25: 46.85 km
# Distance from 4 to 26: 38.18 km
# Distance from 4 to 27: 7.99 km
# Distance from 4 to 28: 21.72 km
# Distance from 4 to 29: 42.27 km
# Processed: origin 4, destinations 5-29. Elements: 819
#
# API Response for origin 4:
# Status: OK
# Distance from 4 to 30: 4.50 km
# Distance from 4 to 31: 18.41 km
# Distance from 4 to 32: 18.62 km
# Distance from 4 to 33: 30.39 km
# Distance from 4 to 34: 29.22 km
# Distance from 4 to 35: 29.40 km
# Distance from 4 to 36: 8.79 km
# Distance from 4 to 37: 2.78 km
# Distance from 4 to 38: 38.68 km
# Distance from 4 to 39: 45.47 km
# Distance from 4 to 40: 9.37 km
# Distance from 4 to 41: 35.04 km
# Distance from 4 to 42: 20.24 km
# Distance from 4 to 43: 37.95 km
# Distance from 4 to 44: 17.10 km
# Distance from 4 to 45: 30.48 km
# Distance from 4 to 46: 20.11 km
# Distance from 4 to 47: 39.20 km
# Distance from 4 to 48: 54.04 km
# Distance from 4 to 49: 12.04 km
# Distance from 4 to 50: 36.95 km
# Distance from 4 to 51: 11.71 km
# Distance from 4 to 52: 24.12 km
# Distance from 4 to 53: 55.03 km
# Distance from 4 to 54: 38.61 km
# Processed: origin 4, destinations 30-54. Elements: 844
#
# API Response for origin 4:
# Status: OK
# Distance from 4 to 55: 48.58 km
# Distance from 4 to 56: 21.43 km
# Distance from 4 to 57: 22.86 km
# Distance from 4 to 58: 9.22 km
# Distance from 4 to 59: 5.55 km
# Distance from 4 to 60: 24.40 km
# Distance from 4 to 61: 14.37 km
# Distance from 4 to 62: 15.42 km
# Distance from 4 to 63: 13.85 km
# Distance from 4 to 64: 24.33 km
# Distance from 4 to 65: 27.27 km
# Distance from 4 to 66: 18.72 km
# Distance from 4 to 67: 23.11 km
# Distance from 4 to 68: 31.56 km
# Distance from 4 to 69: 23.94 km
# Distance from 4 to 70: 17.36 km
# Distance from 4 to 71: 41.45 km
# Distance from 4 to 72: 16.36 km
# Distance from 4 to 73: 23.26 km
# Distance from 4 to 74: 10.14 km
# Distance from 4 to 75: 14.53 km
# Distance from 4 to 76: 10.10 km
# Distance from 4 to 77: 11.79 km
# Distance from 4 to 78: 37.95 km
# Distance from 4 to 79: 39.39 km
# Processed: origin 4, destinations 55-79. Elements: 869
#
# API Response for origin 4:
# Status: OK
# Distance from 4 to 80: 43.37 km
# Distance from 4 to 81: 17.09 km
# Distance from 4 to 82: 19.98 km
# Distance from 4 to 83: 8.55 km
# Distance from 4 to 84: 39.50 km
# Distance from 4 to 85: 40.47 km
# Distance from 4 to 86: 47.85 km
# Distance from 4 to 87: 13.94 km
# Distance from 4 to 88: 38.66 km
# Distance from 4 to 89: 39.24 km
# Distance from 4 to 90: 25.74 km
# Distance from 4 to 91: 36.98 km
# Distance from 4 to 92: 36.44 km
# Distance from 4 to 93: 28.74 km
# Distance from 4 to 94: 25.16 km
# Distance from 4 to 95: 24.64 km
# Distance from 4 to 96: 33.99 km
# Distance from 4 to 97: 21.10 km
# Distance from 4 to 98: 4.27 km
# Distance from 4 to 99: 35.79 km
# Distance from 4 to 100: 22.21 km
# Distance from 4 to 101: 21.44 km
# Distance from 4 to 102: 19.99 km
# Distance from 4 to 103: 58.16 km
# Distance from 4 to 104: 8.61 km
# Processed: origin 4, destinations 80-104. Elements: 894
#
# API Response for origin 4:
# Status: OK
# Distance from 4 to 105: 19.20 km
# Distance from 4 to 106: 36.63 km
# Distance from 4 to 107: 17.30 km
# Distance from 4 to 108: 18.74 km
# Distance from 4 to 109: 54.89 km
# Distance from 4 to 110: 35.04 km
# Distance from 4 to 111: 41.65 km
# Distance from 4 to 112: 34.38 km
# Distance from 4 to 113: 25.60 km
# Distance from 4 to 114: 25.38 km
# Distance from 4 to 115: 10.01 km
# Distance from 4 to 116: 25.40 km
# Distance from 4 to 117: 23.21 km
# Distance from 4 to 118: 26.23 km
# Distance from 4 to 119: 8.17 km
# Distance from 4 to 120: 35.90 km
# Distance from 4 to 121: 36.88 km
# Distance from 4 to 122: 32.02 km
# Distance from 4 to 123: 15.73 km
# Distance from 4 to 124: 39.78 km
# Distance from 4 to 125: 20.95 km
# Distance from 4 to 126: 9.36 km
# Distance from 4 to 127: 27.00 km
# Distance from 4 to 128: 13.93 km
# Distance from 4 to 129: 41.15 km
# Processed: origin 4, destinations 105-129. Elements: 919
#
# API Response for origin 4:
# Status: OK
# Distance from 4 to 130: 11.27 km
# Distance from 4 to 131: 35.04 km
# Distance from 4 to 132: 18.97 km
# Distance from 4 to 133: 23.63 km
# Distance from 4 to 134: 55.49 km
# Distance from 4 to 135: 29.58 km
# Distance from 4 to 136: 13.77 km
# Distance from 4 to 137: 41.95 km
# Distance from 4 to 138: 38.03 km
# Distance from 4 to 139: 30.17 km
# Distance from 4 to 140: 19.13 km
# Distance from 4 to 141: 31.43 km
# Distance from 4 to 142: 17.68 km
# Distance from 4 to 143: 20.19 km
# Distance from 4 to 144: 35.52 km
# Distance from 4 to 145: 33.71 km
# Distance from 4 to 146: 7.40 km
# Distance from 4 to 147: 36.81 km
# Distance from 4 to 148: 23.09 km
# Distance from 4 to 149: 39.41 km
# Distance from 4 to 150: 34.14 km
# Distance from 4 to 151: 29.86 km
# Distance from 4 to 152: 10.94 km
# Distance from 4 to 153: 30.08 km
# Distance from 4 to 154: 33.27 km
# Processed: origin 4, destinations 130-154. Elements: 944
#
# API Response for origin 4:
# Status: OK
# Distance from 4 to 155: 20.45 km
# Distance from 4 to 156: 55.44 km
# Distance from 4 to 157: 10.18 km
# Distance from 4 to 158: 20.78 km
# Distance from 4 to 159: 37.43 km
# Distance from 4 to 160: 32.57 km
# Distance from 4 to 161: 8.08 km
# Distance from 4 to 162: 12.27 km
# Distance from 4 to 163: 9.94 km
# Distance from 4 to 164: 44.06 km
# Distance from 4 to 165: 36.29 km
# Distance from 4 to 166: 15.25 km
# Distance from 4 to 167: 15.49 km
# Distance from 4 to 168: 41.78 km
# Distance from 4 to 169: 15.67 km
# Distance from 4 to 170: 39.46 km
# Distance from 4 to 171: 3.90 km
# Distance from 4 to 172: 12.74 km
# Distance from 4 to 173: 46.06 km
# Distance from 4 to 174: 17.96 km
# Distance from 4 to 175: 15.72 km
# Distance from 4 to 176: 20.99 km
# Distance from 4 to 177: 14.76 km
# Distance from 4 to 178: 25.68 km
# Distance from 4 to 179: 16.74 km
# Processed: origin 4, destinations 155-179. Elements: 969
#
# API Response for origin 4:
# Status: OK
# Distance from 4 to 180: 21.52 km
# Distance from 4 to 181: 22.43 km
# Distance from 4 to 182: 50.43 km
# Distance from 4 to 183: 17.82 km
# Distance from 4 to 184: 33.14 km
# Distance from 4 to 185: 29.07 km
# Distance from 4 to 186: 34.17 km
# Distance from 4 to 187: 17.65 km
# Distance from 4 to 188: 23.41 km
# Distance from 4 to 189: 40.94 km
# Distance from 4 to 190: 10.85 km
# Distance from 4 to 191: 26.43 km
# Distance from 4 to 192: 17.79 km
# Distance from 4 to 193: 18.57 km
# Distance from 4 to 194: 10.02 km
# Distance from 4 to 195: 28.04 km
# Distance from 4 to 196: 27.87 km
# Distance from 4 to 197: 20.11 km
# Distance from 4 to 198: 12.76 km
# Distance from 4 to 199: 22.36 km
# Distance from 4 to 200: 19.74 km
# Processed: origin 4, destinations 180-200. Elements: 990
#
# API Response for origin 5:
# Status: OK
# Distance from 5 to 6: 25.28 km
# Distance from 5 to 7: 14.96 km
# Distance from 5 to 8: 48.99 km
# Distance from 5 to 9: 19.72 km
# Distance from 5 to 10: 16.51 km
# Distance from 5 to 11: 34.63 km
# Distance from 5 to 12: 41.27 km
# Distance from 5 to 13: 25.34 km
# Distance from 5 to 14: 42.87 km
# Distance from 5 to 15: 52.96 km
# Distance from 5 to 16: 40.81 km
# Distance from 5 to 17: 31.70 km
# Distance from 5 to 18: 20.08 km
# Distance from 5 to 19: 11.59 km
# Distance from 5 to 20: 10.01 km
# Distance from 5 to 21: 15.83 km
# Distance from 5 to 22: 24.40 km
# Distance from 5 to 23: 25.73 km
# Distance from 5 to 24: 36.17 km
# Distance from 5 to 25: 55.93 km
# Distance from 5 to 26: 41.97 km
# Distance from 5 to 27: 30.13 km
# Distance from 5 to 28: 17.58 km
# Distance from 5 to 29: 46.05 km
# Distance from 5 to 30: 33.66 km
# Processed: origin 5, destinations 6-30. Elements: 1015
#
# API Response for origin 5:
# Status: OK
# Distance from 5 to 31: 14.11 km
# Distance from 5 to 32: 15.87 km
# Distance from 5 to 33: 5.53 km
# Distance from 5 to 34: 27.47 km
# Distance from 5 to 35: 24.72 km
# Distance from 5 to 36: 17.48 km
# Distance from 5 to 37: 30.06 km
# Distance from 5 to 38: 46.54 km
# Distance from 5 to 39: 20.61 km
# Distance from 5 to 40: 25.23 km
# Distance from 5 to 41: 12.39 km
# Distance from 5 to 42: 27.39 km
# Distance from 5 to 43: 13.09 km
# Distance from 5 to 44: 29.23 km
# Distance from 5 to 45: 5.62 km
# Distance from 5 to 46: 32.74 km
# Distance from 5 to 47: 14.34 km
# Distance from 5 to 48: 59.98 km
# Distance from 5 to 49: 23.41 km
# Distance from 5 to 50: 17.17 km
# Distance from 5 to 51: 16.80 km
# Distance from 5 to 52: 27.57 km
# Distance from 5 to 53: 60.97 km
# Distance from 5 to 54: 13.75 km
# Distance from 5 to 55: 54.52 km
# Processed: origin 5, destinations 31-55. Elements: 1040
#
# API Response for origin 5:
# Status: OK
# Distance from 5 to 56: 14.50 km
# Distance from 5 to 57: 10.50 km
# Distance from 5 to 58: 23.67 km
# Distance from 5 to 59: 32.50 km
# Distance from 5 to 60: 20.25 km
# Distance from 5 to 61: 21.41 km
# Distance from 5 to 62: 34.18 km
# Distance from 5 to 63: 23.76 km
# Distance from 5 to 64: 25.71 km
# Distance from 5 to 65: 17.91 km
# Distance from 5 to 66: 25.89 km
# Distance from 5 to 67: 11.95 km
# Distance from 5 to 68: 30.79 km
# Distance from 5 to 69: 26.63 km
# Distance from 5 to 70: 24.58 km
# Distance from 5 to 71: 17.06 km
# Distance from 5 to 72: 20.16 km
# Distance from 5 to 73: 12.79 km
# Distance from 5 to 74: 32.99 km
# Distance from 5 to 75: 24.32 km
# Distance from 5 to 76: 26.45 km
# Distance from 5 to 77: 14.22 km
# Distance from 5 to 78: 37.18 km
# Distance from 5 to 79: 38.62 km
# Distance from 5 to 80: 50.50 km
# Processed: origin 5, destinations 56-80. Elements: 1065
#
# API Response for origin 5:
# Status: OK
# Distance from 5 to 81: 23.56 km
# Distance from 5 to 82: 16.70 km
# Distance from 5 to 83: 21.09 km
# Distance from 5 to 84: 15.12 km
# Distance from 5 to 85: 39.70 km
# Distance from 5 to 86: 56.92 km
# Distance from 5 to 87: 15.64 km
# Distance from 5 to 88: 11.40 km
# Distance from 5 to 89: 14.38 km
# Distance from 5 to 90: 21.59 km
# Distance from 5 to 91: 12.12 km
# Distance from 5 to 92: 11.58 km
# Distance from 5 to 93: 22.16 km
# Distance from 5 to 94: 21.02 km
# Distance from 5 to 95: 28.03 km
# Distance from 5 to 96: 38.79 km
# Distance from 5 to 97: 17.67 km
# Distance from 5 to 98: 30.75 km
# Distance from 5 to 99: 13.32 km
# Distance from 5 to 100: 30.98 km
# Distance from 5 to 101: 18.21 km
# Distance from 5 to 102: 18.25 km
# Distance from 5 to 103: 64.10 km
# Distance from 5 to 104: 29.80 km
# Distance from 5 to 105: 16.02 km
# Processed: origin 5, destinations 81-105. Elements: 1090
#
# API Response for origin 5:
# Status: OK
# Distance from 5 to 106: 40.41 km
# Distance from 5 to 107: 21.94 km
# Distance from 5 to 108: 14.17 km
# Distance from 5 to 109: 60.83 km
# Distance from 5 to 110: 40.39 km
# Distance from 5 to 111: 16.78 km
# Distance from 5 to 112: 38.17 km
# Distance from 5 to 113: 38.23 km
# Distance from 5 to 114: 17.84 km
# Distance from 5 to 115: 17.91 km
# Distance from 5 to 116: 21.26 km
# Distance from 5 to 117: 12.36 km
# Distance from 5 to 118: 6.37 km
# Distance from 5 to 119: 17.94 km
# Distance from 5 to 120: 11.04 km
# Distance from 5 to 121: 12.02 km
# Distance from 5 to 122: 7.16 km
# Distance from 5 to 123: 24.70 km
# Distance from 5 to 124: 8.36 km
# Distance from 5 to 125: 17.95 km
# Distance from 5 to 126: 19.55 km
# Distance from 5 to 127: 5.38 km
# Distance from 5 to 128: 21.17 km
# Distance from 5 to 129: 48.65 km
# Distance from 5 to 130: 25.52 km
# Processed: origin 5, destinations 106-130. Elements: 1115
#
# API Response for origin 5:
# Status: OK
# Distance from 5 to 131: 1.87 km
# Distance from 5 to 132: 19.85 km
# Distance from 5 to 133: 36.26 km
# Distance from 5 to 134: 61.43 km
# Distance from 5 to 135: 28.81 km
# Distance from 5 to 136: 29.60 km
# Distance from 5 to 137: 17.57 km
# Distance from 5 to 138: 41.81 km
# Distance from 5 to 139: 7.45 km
# Distance from 5 to 140: 16.38 km
# Distance from 5 to 141: 44.06 km
# Distance from 5 to 142: 25.97 km
# Distance from 5 to 143: 27.12 km
# Distance from 5 to 144: 8.32 km
# Distance from 5 to 145: 41.83 km
# Distance from 5 to 146: 18.73 km
# Distance from 5 to 147: 9.66 km
# Distance from 5 to 148: 11.20 km
# Distance from 5 to 149: 43.19 km
# Distance from 5 to 150: 11.49 km
# Distance from 5 to 151: 33.64 km
# Distance from 5 to 152: 24.23 km
# Distance from 5 to 153: 33.90 km
# Distance from 5 to 154: 38.24 km
# Distance from 5 to 155: 18.65 km
# Processed: origin 5, destinations 131-155. Elements: 1140
#
# API Response for origin 5:
# Status: OK
# Distance from 5 to 156: 61.38 km
# Distance from 5 to 157: 20.37 km
# Distance from 5 to 158: 18.13 km
# Distance from 5 to 159: 41.21 km
# Distance from 5 to 160: 7.71 km
# Distance from 5 to 161: 22.39 km
# Distance from 5 to 162: 14.00 km
# Distance from 5 to 163: 20.13 km
# Distance from 5 to 164: 43.29 km
# Distance from 5 to 165: 11.43 km
# Distance from 5 to 166: 31.16 km
# Distance from 5 to 167: 24.46 km
# Distance from 5 to 168: 16.21 km
# Distance from 5 to 169: 28.30 km
# Distance from 5 to 170: 13.25 km
# Distance from 5 to 171: 30.38 km
# Distance from 5 to 172: 15.03 km
# Distance from 5 to 173: 14.64 km
# Distance from 5 to 174: 11.96 km
# Distance from 5 to 175: 20.55 km
# Distance from 5 to 176: 14.21 km
# Distance from 5 to 177: 26.92 km
# Distance from 5 to 178: 27.97 km
# Distance from 5 to 179: 29.37 km
# Distance from 5 to 180: 18.51 km
# Processed: origin 5, destinations 156-180. Elements: 1165
#
# API Response for origin 5:
# Status: OK
# Distance from 5 to 181: 11.89 km
# Distance from 5 to 182: 49.66 km
# Distance from 5 to 183: 30.45 km
# Distance from 5 to 184: 38.02 km
# Distance from 5 to 185: 24.66 km
# Distance from 5 to 186: 9.31 km
# Distance from 5 to 187: 25.66 km
# Distance from 5 to 188: 13.98 km
# Distance from 5 to 189: 44.72 km
# Distance from 5 to 190: 30.00 km
# Distance from 5 to 191: 22.29 km
# Distance from 5 to 192: 21.40 km
# Distance from 5 to 193: 15.98 km
# Distance from 5 to 194: 16.67 km
# Distance from 5 to 195: 23.89 km
# Distance from 5 to 196: 21.72 km
# Distance from 5 to 197: 32.74 km
# Distance from 5 to 198: 24.25 km
# Distance from 5 to 199: 14.12 km
# Distance from 5 to 200: 14.09 km
# Processed: origin 5, destinations 181-200. Elements: 1185
#
# API Response for origin 6:
# Status: OK
# Distance from 6 to 7: 23.67 km
# Distance from 6 to 8: 26.95 km
# Distance from 6 to 9: 32.44 km
# Distance from 6 to 10: 25.22 km
# Distance from 6 to 11: 12.60 km
# Distance from 6 to 12: 17.59 km
# Distance from 6 to 13: 3.30 km
# Distance from 6 to 14: 20.84 km
# Distance from 6 to 15: 30.93 km
# Distance from 6 to 16: 17.13 km
# Distance from 6 to 17: 25.07 km
# Distance from 6 to 18: 35.66 km
# Distance from 6 to 19: 20.30 km
# Distance from 6 to 20: 27.15 km
# Distance from 6 to 21: 9.75 km
# Distance from 6 to 22: 30.48 km
# Distance from 6 to 23: 0.79 km
# Distance from 6 to 24: 14.13 km
# Distance from 6 to 25: 32.24 km
# Distance from 6 to 26: 19.94 km
# Distance from 6 to 27: 32.43 km
# Distance from 6 to 28: 9.47 km
# Distance from 6 to 29: 24.02 km
# Distance from 6 to 30: 26.97 km
# Distance from 6 to 31: 15.17 km
# Processed: origin 6, destinations 7-31. Elements: 1210
#
# API Response for origin 6:
# Status: OK
# Distance from 6 to 32: 12.08 km
# Distance from 6 to 33: 27.88 km
# Distance from 6 to 34: 2.36 km
# Distance from 6 to 35: 2.02 km
# Distance from 6 to 36: 22.62 km
# Distance from 6 to 37: 29.35 km
# Distance from 6 to 38: 24.51 km
# Distance from 6 to 39: 42.96 km
# Distance from 6 to 40: 18.54 km
# Distance from 6 to 41: 27.32 km
# Distance from 6 to 42: 5.86 km
# Distance from 6 to 43: 35.44 km
# Distance from 6 to 44: 37.95 km
# Distance from 6 to 45: 27.97 km
# Distance from 6 to 46: 18.52 km
# Distance from 6 to 47: 36.69 km
# Distance from 6 to 48: 37.95 km
# Distance from 6 to 49: 16.77 km
# Distance from 6 to 50: 32.75 km
# Distance from 6 to 51: 25.52 km
# Distance from 6 to 52: 5.54 km
# Distance from 6 to 53: 38.94 km
# Distance from 6 to 54: 36.10 km
# Distance from 6 to 55: 32.49 km
# Distance from 6 to 56: 12.85 km
# Processed: origin 6, destinations 32-56. Elements: 1235
#
# API Response for origin 6:
# Status: OK
# Distance from 6 to 57: 14.28 km
# Distance from 6 to 58: 19.89 km
# Distance from 6 to 59: 34.09 km
# Distance from 6 to 60: 10.49 km
# Distance from 6 to 61: 14.89 km
# Distance from 6 to 62: 27.55 km
# Distance from 6 to 63: 32.48 km
# Distance from 6 to 64: 41.29 km
# Distance from 6 to 65: 11.01 km
# Distance from 6 to 66: 7.33 km
# Distance from 6 to 67: 14.53 km
# Distance from 6 to 68: 6.89 km
# Distance from 6 to 69: 4.60 km
# Distance from 6 to 70: 8.34 km
# Distance from 6 to 71: 31.05 km
# Distance from 6 to 72: 16.37 km
# Distance from 6 to 73: 15.98 km
# Distance from 6 to 74: 26.36 km
# Distance from 6 to 75: 13.73 km
# Distance from 6 to 76: 32.72 km
# Distance from 6 to 77: 22.94 km
# Distance from 6 to 78: 13.49 km
# Distance from 6 to 79: 14.93 km
# Distance from 6 to 80: 28.47 km
# Distance from 6 to 81: 37.29 km
# Processed: origin 6, destinations 57-81. Elements: 1260
#
# API Response for origin 6:
# Status: OK
# Distance from 6 to 82: 32.58 km
# Distance from 6 to 83: 29.80 km
# Distance from 6 to 84: 30.90 km
# Distance from 6 to 85: 16.02 km
# Distance from 6 to 86: 33.24 km
# Distance from 6 to 87: 24.36 km
# Distance from 6 to 88: 27.68 km
# Distance from 6 to 89: 36.73 km
# Distance from 6 to 90: 8.37 km
# Distance from 6 to 91: 34.47 km
# Distance from 6 to 92: 33.93 km
# Distance from 6 to 93: 37.74 km
# Distance from 6 to 94: 10.19 km
# Distance from 6 to 95: 5.58 km
# Distance from 6 to 96: 16.75 km
# Distance from 6 to 97: 11.04 km
# Distance from 6 to 98: 27.62 km
# Distance from 6 to 99: 28.07 km
# Distance from 6 to 100: 6.88 km
# Distance from 6 to 101: 33.79 km
# Distance from 6 to 102: 9.96 km
# Distance from 6 to 103: 42.07 km
# Distance from 6 to 104: 38.52 km
# Distance from 6 to 105: 31.61 km
# Distance from 6 to 106: 18.38 km
# Processed: origin 6, destinations 82-106. Elements: 1285
#
# API Response for origin 6:
# Status: OK
# Distance from 6 to 107: 35.00 km
# Distance from 6 to 108: 13.97 km
# Distance from 6 to 109: 38.80 km
# Distance from 6 to 110: 18.36 km
# Distance from 6 to 111: 39.13 km
# Distance from 6 to 112: 16.14 km
# Distance from 6 to 113: 27.22 km
# Distance from 6 to 114: 13.44 km
# Distance from 6 to 115: 26.62 km
# Distance from 6 to 116: 4.87 km
# Distance from 6 to 117: 14.63 km
# Distance from 6 to 118: 19.06 km
# Distance from 6 to 119: 26.66 km
# Distance from 6 to 120: 30.60 km
# Distance from 6 to 121: 30.77 km
# Distance from 6 to 122: 29.51 km
# Distance from 6 to 123: 12.16 km
# Distance from 6 to 124: 30.71 km
# Distance from 6 to 125: 33.46 km
# Distance from 6 to 126: 28.27 km
# Distance from 6 to 127: 17.10 km
# Distance from 6 to 128: 33.29 km
# Distance from 6 to 129: 26.62 km
# Distance from 6 to 130: 34.23 km
# Distance from 6 to 131: 26.70 km
# Processed: origin 6, destinations 107-131. Elements: 1310
#
# API Response for origin 6:
# Status: OK
# Distance from 6 to 132: 35.44 km
# Distance from 6 to 133: 25.25 km
# Distance from 6 to 134: 39.40 km
# Distance from 6 to 135: 4.87 km
# Distance from 6 to 136: 22.97 km
# Distance from 6 to 137: 31.56 km
# Distance from 6 to 138: 19.78 km
# Distance from 6 to 139: 23.79 km
# Distance from 6 to 140: 12.59 km
# Distance from 6 to 141: 20.21 km
# Distance from 6 to 142: 10.56 km
# Distance from 6 to 143: 5.59 km
# Distance from 6 to 144: 28.35 km
# Distance from 6 to 145: 19.80 km
# ...
# Distance from 173 to 181: 22.53 km
# Distance from 173 to 182: 60.30 km
# Distance from 173 to 183: 43.63 km
# Distance from 173 to 184: 48.66 km
# Distance from 173 to 185: 7.86 km
# Distance from 173 to 186: 8.21 km
# Distance from 173 to 187: 20.05 km
# Distance from 173 to 188: 28.26 km
# Distance from 173 to 189: 55.36 km
# Distance from 173 to 190: 43.18 km
# Distance from 173 to 191: 32.92 km
# Distance from 173 to 192: 32.04 km
# Distance from 173 to 193: 26.62 km
# Distance from 173 to 194: 27.31 km
# Distance from 173 to 195: 34.53 km
# Distance from 173 to 196: 7.31 km
# Distance from 173 to 197: 45.92 km
# Distance from 173 to 198: 21.57 km
# Processed: origin 173, destinations 174-198. Elements: 19747
#
# API Response for origin 173:
# Status: OK
# Distance from 173 to 199: 24.75 km
# Distance from 173 to 200: 7.31 km
# Processed: origin 173, destinations 199-200. Elements: 19749
#
# API Response for origin 174:
# Status: OK
# Distance from 174 to 175: 17.59 km
# Distance from 174 to 176: 9.79 km
# Distance from 174 to 177: 15.43 km
# Distance from 174 to 178: 23.56 km
# Distance from 174 to 179: 17.42 km
# Distance from 174 to 180: 22.74 km
# Distance from 174 to 181: 4.84 km
# Distance from 174 to 182: 45.25 km
# Distance from 174 to 183: 18.50 km
# Distance from 174 to 184: 33.61 km
# Distance from 174 to 185: 30.29 km
# Distance from 174 to 186: 18.59 km
# Distance from 174 to 187: 20.36 km
# Distance from 174 to 188: 12.87 km
# Distance from 174 to 189: 40.31 km
# Distance from 174 to 190: 25.59 km
# Distance from 174 to 191: 17.87 km
# Distance from 174 to 192: 16.99 km
# Distance from 174 to 193: 11.57 km
# Distance from 174 to 194: 7.18 km
# Distance from 174 to 195: 19.48 km
# Distance from 174 to 196: 29.09 km
# Distance from 174 to 197: 20.79 km
# Distance from 174 to 198: 15.47 km
# Distance from 174 to 199: 9.58 km
# Processed: origin 174, destinations 175-199. Elements: 19774
#
# API Response for origin 174:
# Status: OK
# Distance from 174 to 200: 18.57 km
# Processed: origin 174, destinations 200-200. Elements: 19775
#
# API Response for origin 175:
# Status: OK
# Distance from 175 to 176: 25.62 km
# Distance from 175 to 177: 29.18 km
# Distance from 175 to 178: 39.38 km
# Distance from 175 to 179: 31.17 km
# Distance from 175 to 180: 8.02 km
# Distance from 175 to 181: 23.31 km
# Distance from 175 to 182: 61.08 km
# Distance from 175 to 183: 32.24 km
# Distance from 175 to 184: 49.44 km
# Distance from 175 to 185: 15.57 km
# Distance from 175 to 186: 22.16 km
# Distance from 175 to 187: 4.18 km
# Distance from 175 to 188: 28.81 km
# Distance from 175 to 189: 56.14 km
# Distance from 175 to 190: 26.17 km
# Distance from 175 to 191: 33.70 km
# Distance from 175 to 192: 32.82 km
# Distance from 175 to 193: 27.40 km
# Distance from 175 to 194: 26.22 km
# Distance from 175 to 195: 35.31 km
# Distance from 175 to 196: 14.38 km
# Distance from 175 to 197: 34.54 km
# Distance from 175 to 198: 7.17 km
# Distance from 175 to 199: 25.52 km
# Distance from 175 to 200: 6.71 km
# Processed: origin 175, destinations 176-200. Elements: 19800
#
# API Response for origin 176:
# Status: OK
# Distance from 176 to 177: 14.49 km
# Distance from 176 to 178: 15.46 km
# Distance from 176 to 179: 16.94 km
# Distance from 176 to 180: 23.93 km
# Distance from 176 to 181: 3.76 km
# Distance from 176 to 182: 37.15 km
# Distance from 176 to 183: 18.01 km
# Distance from 176 to 184: 25.51 km
# Distance from 176 to 185: 31.49 km
# Distance from 176 to 186: 21.57 km
# Distance from 176 to 187: 27.76 km
# Distance from 176 to 188: 4.74 km
# Distance from 176 to 189: 32.22 km
# Distance from 176 to 190: 17.57 km
# Distance from 176 to 191: 9.78 km
# Distance from 176 to 192: 7.79 km
# Distance from 176 to 193: 3.46 km
# Distance from 176 to 194: 10.97 km
# Distance from 176 to 195: 11.38 km
# Distance from 176 to 196: 30.29 km
# Distance from 176 to 197: 20.31 km
# Distance from 176 to 198: 22.87 km
# Distance from 176 to 199: 2.87 km
# Distance from 176 to 200: 19.77 km
# Processed: origin 176, destinations 177-200. Elements: 19824
#
# API Response for origin 177:
# Status: OK
# Distance from 177 to 178: 19.82 km
# Distance from 177 to 179: 6.77 km
# Distance from 177 to 180: 36.68 km
# Distance from 177 to 181: 16.51 km
# Distance from 177 to 182: 44.57 km
# Distance from 177 to 183: 7.84 km
# Distance from 177 to 184: 23.16 km
# Distance from 177 to 185: 44.24 km
# Distance from 177 to 186: 34.85 km
# Distance from 177 to 187: 29.38 km
# Distance from 177 to 188: 17.49 km
# Distance from 177 to 189: 35.08 km
# Distance from 177 to 190: 5.52 km
# Distance from 177 to 191: 20.51 km
# Distance from 177 to 192: 11.87 km
# Distance from 177 to 193: 12.65 km
# Distance from 177 to 194: 9.26 km
# Distance from 177 to 195: 22.11 km
# Distance from 177 to 196: 43.04 km
# Distance from 177 to 197: 7.30 km
# Distance from 177 to 198: 24.49 km
# Distance from 177 to 199: 16.43 km
# Distance from 177 to 200: 32.52 km
# Processed: origin 177, destinations 178-200. Elements: 19847
#
# API Response for origin 178:
# Status: OK
# Distance from 178 to 179: 17.66 km
# Distance from 178 to 180: 38.24 km
# Distance from 178 to 181: 18.07 km
# Distance from 178 to 182: 28.45 km
# Distance from 178 to 183: 18.73 km
# Distance from 178 to 184: 11.19 km
# Distance from 178 to 185: 45.80 km
# Distance from 178 to 186: 35.88 km
# Distance from 178 to 187: 39.82 km
# Distance from 178 to 188: 16.47 km
# Distance from 178 to 189: 17.90 km
# Distance from 178 to 190: 22.93 km
# Distance from 178 to 191: 7.63 km
# Distance from 178 to 192: 15.45 km
# Distance from 178 to 193: 14.44 km
# Distance from 178 to 194: 21.06 km
# Distance from 178 to 195: 10.12 km
# Distance from 178 to 196: 44.60 km
# Distance from 178 to 197: 21.03 km
# Distance from 178 to 198: 34.93 km
# Distance from 178 to 199: 17.71 km
# Distance from 178 to 200: 34.08 km
# Processed: origin 178, destinations 179-200. Elements: 19869
#
# API Response for origin 179:
# Status: OK
# Distance from 179 to 180: 39.47 km
# Distance from 179 to 181: 19.29 km
# Distance from 179 to 182: 42.51 km
# Distance from 179 to 183: 1.77 km
# Distance from 179 to 184: 19.05 km
# Distance from 179 to 185: 47.02 km
# Distance from 179 to 186: 37.63 km
# Distance from 179 to 187: 31.64 km
# Distance from 179 to 188: 20.28 km
# Distance from 179 to 189: 28.27 km
# Distance from 179 to 190: 13.50 km
# Distance from 179 to 191: 15.41 km
# Distance from 179 to 192: 14.65 km
# Distance from 179 to 193: 15.43 km
# Distance from 179 to 194: 11.53 km
# Distance from 179 to 195: 17.57 km
# Distance from 179 to 196: 45.83 km
# Distance from 179 to 197: 4.07 km
# Distance from 179 to 198: 26.75 km
# Distance from 179 to 199: 19.22 km
# Distance from 179 to 200: 35.30 km
# Processed: origin 179, destinations 180-200. Elements: 19890
#
# API Response for origin 180:
# Status: OK
# Distance from 180 to 181: 21.24 km
# Distance from 180 to 182: 59.01 km
# Distance from 180 to 183: 39.79 km
# Distance from 180 to 184: 47.36 km
# Distance from 180 to 185: 9.01 km
# Distance from 180 to 186: 14.85 km
# Distance from 180 to 187: 12.29 km
# Distance from 180 to 188: 26.74 km
# Distance from 180 to 189: 54.07 km
# Distance from 180 to 190: 39.35 km
# Distance from 180 to 191: 31.63 km
# Distance from 180 to 192: 30.75 km
# Distance from 180 to 193: 25.32 km
# Distance from 180 to 194: 32.75 km
# Distance from 180 to 195: 33.24 km
# Distance from 180 to 196: 7.81 km
# Distance from 180 to 197: 42.09 km
# Distance from 180 to 198: 15.52 km
# Distance from 180 to 199: 23.45 km
# Distance from 180 to 200: 5.13 km
# Processed: origin 180, destinations 181-200. Elements: 19910
#
# API Response for origin 181:
# Status: OK
# Distance from 181 to 182: 39.84 km
# Distance from 181 to 183: 20.62 km
# Distance from 181 to 184: 28.19 km
# Distance from 181 to 185: 28.61 km
# Distance from 181 to 186: 18.69 km
# Distance from 181 to 187: 24.89 km
# Distance from 181 to 188: 5.89 km
# Distance from 181 to 189: 34.90 km
# Distance from 181 to 190: 20.18 km
# Distance from 181 to 191: 12.46 km
# Distance from 181 to 192: 11.58 km
# Distance from 181 to 193: 6.15 km
# Distance from 181 to 194: 9.04 km
# Distance from 181 to 195: 14.07 km
# Distance from 181 to 196: 27.42 km
# Distance from 181 to 197: 22.92 km
# Distance from 181 to 198: 20.00 km
# Distance from 181 to 199: 3.10 km
# Distance from 181 to 200: 16.90 km
# Processed: origin 181, destinations 182-200. Elements: 19929
#
# API Response for origin 182:
# Status: OK
# Distance from 182 to 183: 43.14 km
# Distance from 182 to 184: 19.75 km
# Distance from 182 to 185: 66.75 km
# Distance from 182 to 186: 60.62 km
# Distance from 182 to 187: 64.23 km
# Distance from 182 to 188: 36.73 km
# Distance from 182 to 189: 9.92 km
# Distance from 182 to 190: 47.34 km
# Distance from 182 to 191: 26.26 km
# Distance from 182 to 192: 36.40 km
# Distance from 182 to 193: 35.39 km
# Distance from 182 to 194: 45.47 km
# Distance from 182 to 195: 25.53 km
# Distance from 182 to 196: 65.55 km
# Distance from 182 to 197: 45.44 km
# Distance from 182 to 198: 59.34 km
# Distance from 182 to 199: 38.66 km
# Distance from 182 to 200: 55.03 km
# Processed: origin 182, destinations 183-200. Elements: 19947
#
# API Response for origin 183:
# Status: OK
# Distance from 183 to 184: 20.04 km
# Distance from 183 to 185: 47.69 km
# Distance from 183 to 186: 38.30 km
# Distance from 183 to 187: 32.31 km
# Distance from 183 to 188: 20.95 km
# Distance from 183 to 189: 29.26 km
# Distance from 183 to 190: 14.17 km
# Distance from 183 to 191: 16.08 km
# Distance from 183 to 192: 15.32 km
# Distance from 183 to 193: 16.10 km
# Distance from 183 to 194: 12.19 km
# Distance from 183 to 195: 18.24 km
# Distance from 183 to 196: 46.49 km
# Distance from 183 to 197: 3.08 km
# Distance from 183 to 198: 27.42 km
# Distance from 183 to 199: 19.88 km
# Distance from 183 to 200: 35.97 km
# Processed: origin 183, destinations 184-200. Elements: 19964
#
# API Response for origin 184:
# Status: OK
# Distance from 184 to 185: 55.79 km
# Distance from 184 to 186: 45.87 km
# Distance from 184 to 187: 48.29 km
# Distance from 184 to 188: 26.46 km
# Distance from 184 to 189: 11.03 km
# Distance from 184 to 190: 30.15 km
# Distance from 184 to 191: 17.62 km
# Distance from 184 to 192: 25.44 km
# Distance from 184 to 193: 24.43 km
# Distance from 184 to 194: 28.18 km
# Distance from 184 to 195: 20.11 km
# Distance from 184 to 196: 54.59 km
# Distance from 184 to 197: 23.60 km
# Distance from 184 to 198: 43.40 km
# Distance from 184 to 199: 27.70 km
# Distance from 184 to 200: 44.07 km
# Processed: origin 184, destinations 185-200. Elements: 19980
#
# API Response for origin 185:
# Status: OK
# Distance from 185 to 186: 14.55 km
# Distance from 185 to 187: 19.82 km
# Distance from 185 to 188: 34.27 km
# Distance from 185 to 189: 61.60 km
# Distance from 185 to 190: 46.88 km
# Distance from 185 to 191: 39.16 km
# Distance from 185 to 192: 38.28 km
# Distance from 185 to 193: 32.86 km
# Distance from 185 to 194: 34.71 km
# Distance from 185 to 195: 40.77 km
# Distance from 185 to 196: 2.73 km
# Distance from 185 to 197: 49.62 km
# Distance from 185 to 198: 23.05 km
# Distance from 185 to 199: 30.98 km
# Distance from 185 to 200: 11.78 km
# Processed: origin 185, destinations 186-200. Elements: 19995
#
# API Response for origin 186:
# Status: OK
# Distance from 186 to 187: 28.67 km
# Distance from 186 to 188: 24.50 km
# Distance from 186 to 189: 51.83 km
# Distance from 186 to 190: 37.10 km
# Distance from 186 to 191: 29.39 km
# Distance from 186 to 192: 28.50 km
# Distance from 186 to 193: 23.08 km
# Distance from 186 to 194: 23.77 km
# Distance from 186 to 195: 30.99 km
# Distance from 186 to 196: 14.15 km
# Distance from 186 to 197: 39.84 km
# Distance from 186 to 198: 31.35 km
# Distance from 186 to 199: 21.22 km
# Distance from 186 to 200: 17.10 km
# Processed: origin 186, destinations 187-200. Elements: 20009
#
# API Response for origin 187:
# Status: OK
# Distance from 187 to 188: 30.13 km
# Distance from 187 to 189: 56.23 km
# Distance from 187 to 190: 27.04 km
# Distance from 187 to 191: 37.66 km
# Distance from 187 to 192: 33.08 km
# Distance from 187 to 193: 31.36 km
# Distance from 187 to 194: 27.09 km
# Distance from 187 to 195: 39.27 km
# Distance from 187 to 196: 18.90 km
# Distance from 187 to 197: 35.41 km
# Distance from 187 to 198: 6.30 km
# Distance from 187 to 199: 26.84 km
# Distance from 187 to 200: 12.12 km
# Processed: origin 187, destinations 188-200. Elements: 20022
#
# API Response for origin 188:
# Status: OK
# Distance from 188 to 189: 37.44 km
# Distance from 188 to 190: 20.50 km
# Distance from 188 to 191: 10.36 km
# Distance from 188 to 192: 9.39 km
# Distance from 188 to 193: 4.23 km
# Distance from 188 to 194: 13.90 km
# Distance from 188 to 195: 8.54 km
# Distance from 188 to 196: 33.26 km
# Distance from 188 to 197: 23.24 km
# Distance from 188 to 198: 25.76 km
# Distance from 188 to 199: 4.24 km
# Distance from 188 to 200: 22.74 km
# Processed: origin 188, destinations 189-200. Elements: 20034
#
# API Response for origin 189:
# Status: OK
# Distance from 189 to 190: 38.33 km
# Distance from 189 to 191: 23.65 km
# Distance from 189 to 192: 31.47 km
# Distance from 189 to 193: 30.45 km
# Distance from 189 to 194: 36.45 km
# Distance from 189 to 195: 26.38 km
# Distance from 189 to 196: 60.62 km
# Distance from 189 to 197: 31.86 km
# Distance from 189 to 198: 50.33 km
# Distance from 189 to 199: 33.73 km
# Distance from 189 to 200: 50.10 km
# Processed: origin 189, destinations 190-200. Elements: 20045
#
# API Response for origin 190:
# Status: OK
# Distance from 190 to 191: 23.78 km
# Distance from 190 to 192: 15.14 km
# Distance from 190 to 193: 15.92 km
# Distance from 190 to 194: 11.61 km
# Distance from 190 to 195: 25.39 km
# Distance from 190 to 196: 46.32 km
# Distance from 190 to 197: 10.03 km
# Distance from 190 to 198: 21.59 km
# Distance from 190 to 199: 19.71 km
# Distance from 190 to 200: 35.80 km
# Processed: origin 190, destinations 191-200. Elements: 20055
#
# API Response for origin 191:
# Status: OK
# Distance from 191 to 192: 9.03 km
# Distance from 191 to 193: 8.01 km
# Distance from 191 to 194: 17.41 km
# Distance from 191 to 195: 3.07 km
# Distance from 191 to 196: 38.18 km
# Distance from 191 to 197: 26.75 km
# Distance from 191 to 198: 30.76 km
# Distance from 191 to 199: 11.29 km
# Distance from 191 to 200: 27.66 km
# Processed: origin 191, destinations 192-200. Elements: 20064
#
# API Response for origin 192:
# Status: OK
# Distance from 192 to 193: 5.31 km
# Distance from 192 to 194: 7.79 km
# Distance from 192 to 195: 9.19 km
# Distance from 192 to 196: 35.86 km
# Distance from 192 to 197: 13.75 km
# Distance from 192 to 198: 28.43 km
# Distance from 192 to 199: 9.25 km
# Distance from 192 to 200: 25.34 km
# Processed: origin 192, destinations 193-200. Elements: 20072
#
# API Response for origin 193:
# Status: OK
# Distance from 193 to 194: 11.34 km
# Distance from 193 to 195: 9.22 km
# Distance from 193 to 196: 32.11 km
# Distance from 193 to 197: 20.68 km
# Distance from 193 to 198: 24.69 km
# Distance from 193 to 199: 5.22 km
# Distance from 193 to 200: 21.59 km
# Processed: origin 193, destinations 194-200. Elements: 20079
#
# API Response for origin 194:
# Status: OK
# Distance from 194 to 195: 16.55 km
# Distance from 194 to 196: 34.34 km
# Distance from 194 to 197: 14.59 km
# Distance from 194 to 198: 21.05 km
# Distance from 194 to 199: 16.66 km
# Distance from 194 to 200: 23.82 km
# Processed: origin 194, destinations 195-200. Elements: 20085
#
# API Response for origin 195:
# Status: OK
# Distance from 195 to 196: 39.76 km
# Distance from 195 to 197: 21.07 km
# Distance from 195 to 198: 32.34 km
# Distance from 195 to 199: 12.87 km
# Distance from 195 to 200: 29.24 km
# Processed: origin 195, destinations 196-200. Elements: 20090
#
# API Response for origin 196:
# Status: OK
# Distance from 196 to 197: 48.38 km
# Distance from 196 to 198: 21.81 km
# Distance from 196 to 199: 29.74 km
# Distance from 196 to 200: 10.71 km
# Processed: origin 196, destinations 197-200. Elements: 20094
#
# API Response for origin 197:
# Status: OK
# Distance from 197 to 198: 29.90 km
# Distance from 197 to 199: 22.37 km
# Distance from 197 to 200: 38.46 km
# Processed: origin 197, destinations 198-200. Elements: 20097
#
# API Response for origin 198:
# Status: OK
# Distance from 198 to 199: 23.19 km
# Distance from 198 to 200: 14.87 km
# Processed: origin 198, destinations 199-200. Elements: 20099
#
# API Response for origin 199:
# Status: OK
# Distance from 199 to 200: 19.72 km
# Processed: origin 199, destinations 200-200. Elements: 20100
#
# Final element count: 20100
# Matrix filled: 40200 elements
# Distance matrix created and cached.
# Distance matrix shape: (201, 201)

# %%
print(len(distance_matrix), len(locations_mapping))
distance_matrix, locations_mapping
# Out:
# 201 201
# (array([[    0., 26649., 42412., ..., 26961., 19427., 35516.],
#         [26649.,     0., 16811., ..., 27994., 10448., 16977.],
#         [42412., 16811.,     0., ..., 43273., 25728., 29712.],
#         ...,
#         [26961., 27994., 43273., ...,     0., 23191., 14872.],
#         [19427., 10448., 25728., ..., 23191.,     0., 19722.],
#         [35516., 16977., 29712., ..., 14872., 19722.,     0.]]),
#  {'0': {'latitude': 33.6424,
#    'longitude': -117.8417,
#    'address': 'UCI Warehouse: 2006 McGaw Ave, Irvine, CA 92614'},
#   '1': {'latitude': 33.83584608,
#    'longitude': -117.83314454,
#    'address': '2003 E IVY HILL LN, ORANGE, California 92867'},
#   '2': {'latitude': 33.87945857,
#    'longitude': -117.69402105,
#    'address': '5550 SHADY CREEK LN, YORBA LINDA, California 92887'},
#   '3': {'latitude': 33.71094889,
#    'longitude': -117.79430468,
#    'address': '7 CONNECTICUT, IRVINE, California 92606'},
#   '4': {'latitude': 33.69807045,
#    'longitude': -117.98647427,
#    'address': '8131 KINER AVE, HUNTINGTON BEACH, California 92646'},
#   '5': {'latitude': 33.82804231,
#    'longitude': -117.86362642,
#    'address': '2395 N RIVER TRAIL RD, ORANGE, California 92865'},
#   '6': {'latitude': 33.68815467,
#    'longitude': -117.76248549,
#    'address': '1733 CONTESSA Building 10, IRVINE, California 92620'},
#   '7': {'latitude': 33.77628241,
#    'longitude': -117.93308989,
#    'address': '11441 ACACIA PKWY Unit 122, GARDEN GROVE, California 92840'},
#   '8': {'latitude': 33.49704581,
#    'longitude': -117.66651235,
#    'address': '32021 VIA TONADA, SAN JUAN CAPISTRANO, California 92675'},
#   '9': {'latitude': 33.81263302,
#    'longitude': -117.99001746,
#    'address': '10375 FERN AVE Unit B, STANTON, California 90680'},
#   '10': {'latitude': 33.74464923,
#    'longitude': -117.93129445,
#    'address': '4702 W 1ST ST Unit A, SANTA ANA, California 92703'},
#   '11': {'latitude': 33.60684249,
#    'longitude': -117.71204297,
#    'address': '45 CALLE ARAGON Unit O, LAGUNA WOODS, California 92637'},
#   '12': {'latitude': 33.64984731,
#    'longitude': -117.65641006,
#    'address': '21552 PEDROSO, MISSION VIEJO, California 92691'},
#   '13': {'latitude': 33.69981776,
#    'longitude': -117.74365596,
#    'address': '416 PIEDMONT, IRVINE, California 92620'},
#   '14': {'latitude': 33.55411478,
#    'longitude': -117.69112754,
#    'address': '25132 CAMINO DEL MAR Unit H, LAGUNA NIGUEL, California 92677'},
#   '15': {'latitude': 33.52874521,
#    'longitude': -117.62278027,
#    'address': '10 FARRA ST, Rancho Mission Viejo, California 92694'},
#   '16': {'latitude': 33.65065664,
#    'longitude': -117.64325908,
#    'address': '21622 MARGUERITE PKWY Unit 468 Building 38, MISSION VIEJO, California 92692'},
#   '17': {'latitude': 33.6151821,
#    'longitude': -117.93339823,
#    'address': '123 33RD ST Unit 1, NEWPORT BEACH, California 92663'},
#   '18': {'latitude': 33.85745841,
#    'longitude': -118.0372436,
#    'address': '5600 ORANGETHORPE AVE Unit 2408 Building 24, LA PALMA, California 90623'},
#   '19': {'latitude': 33.78672093,
#    'longitude': -117.90480117,
#    'address': '12122 ADRIAN ST Unit 207 Building 7, GARDEN GROVE, California 92840'},
#   '20': {'latitude': 33.82390537,
#    'longitude': -117.95002586,
#    'address': '628 S NUTWOOD ST, ANAHEIM, California 92804'},
#   '21': {'latitude': 33.73682445,
#    'longitude': -117.8272613,
#    'address': '26 VIA MEDIA, TUSTIN, California 92780'},
#   '22': {'latitude': 33.74621531,
#    'longitude': -118.01230724,
#    'address': '200 WESTMINSTER MALL, WESTMINSTER, California 92683'},
#   '23': {'latitude': 33.68508141,
#    'longitude': -117.76357747,
#    'address': '2317 PENDIO Building 10, IRVINE, California 92620'},
#   '24': {'latitude': 33.59744157,
#    'longitude': -117.69747922,
#    'address': '25122 WILKES PL, LAGUNA HILLS, California 92653'},
#   '25': {'latitude': 33.54888993,
#    'longitude': -117.59811851,
#    'address': '274 ALIENTA LN Building 4, Rancho Mission Viejo, California 92675'},
#   '26': {'latitude': 33.62013399,
#    'longitude': -117.64000427,
#    'address': '28141 VIA BELLO, MISSION VIEJO, California 92692'},
#   '27': {'latitude': 33.71837685,
#    'longitude': -118.0478168,
#    'address': '16766 SIMS ST Unit A, HUNTINGTON BEACH, California 92649'},
#   '28': {'latitude': 33.7364041,
#    'longitude': -117.80733065,
#    'address': '13542 DEAN ST, TUSTIN, California 92780'},
#   '29': {'latitude': 33.55284677,
#    'longitude': -117.63727783,
#    'address': '29511 SIENNA PKWY, Ladera Ranch, California 92694'},
#   '30': {'latitude': 33.66964697,
#    'longitude': -117.98541454,
#    'address': '8131 RACEPOINT DR Unit 203, HUNTINGTON BEACH, California 92646'},
#   '31': {'latitude': 33.73057615,
#    'longitude': -117.86414916,
#    'address': '1332 S MAPLE ST, SANTA ANA, California 92707'},
#   '32': {'latitude': 33.73553283,
#    'longitude': -117.83515512,
#    'address': '15660 TUSTIN VILLAGE WAY Unit 42, TUSTIN, California 92780'},
#   '33': {'latitude': 33.86259707,
#    'longitude': -117.87014282,
#    'address': '208 E ORANGETHORPE AVE, PLACENTIA, California 92870'},
#   '34': {'latitude': 33.69245916,
#    'longitude': -117.74480826,
#    'address': '10305 PAYTON, IRVINE, California 92620'},
#   '35': {'latitude': 33.69456604,
#    'longitude': -117.74968942,
#    'address': '74 TWIN GABLES, IRVINE, California 92620'},
#   '36': {'latitude': 33.71986852,
#    'longitude': -117.92227402,
#    'address': '11859 GOODALE AVE, FOUNTAIN VALLEY, California 92708'},
#   '37': {'latitude': 33.68682861,
#    'longitude': -118.00413796,
#    'address': '18971 STEWART ST, HUNTINGTON BEACH, California 92648'},
#   '38': {'latitude': 33.5260784,
#    'longitude': -117.69298992,
#    'address': '25012 HIDDEN HILLS RD Unit B, LAGUNA NIGUEL, California 92677'},
#   '39': {'latitude': 33.93703299,
#    'longitude': -117.93014926,
#    'address': '561 N DEXTER ST, LA HABRA, California 90631'},
#   '40': {'latitude': 33.69558095,
#    'longitude': -117.90386748,
#    'address': '3490 WIMBLEDON WAY, COSTA MESA, California 92626'},
#   '41': {'latitude': 33.82951609,
#    'longitude': -117.77255801,
#    'address': '2448 EATON RD, ORANGE, California 92867'},
#   '42': {'latitude': 33.66539496,
#    'longitude': -117.79377851,
#    'address': '24 ROBINSONG, IRVINE, California 92614'},
#   '43': {'latitude': 33.89651985,
#    'longitude': -117.92329203,
#    'address': '2520 SUNFLOWER ST, FULLERTON, California 92835'},
#   '44': {'latitude': 33.7722395,
#    'longitude': -118.08073262,
#    'address': '13140 DEL MONTE DR Unit I Building 51, SEAL BEACH, California 90740'},
#   '45': {'latitude': 33.86513085,
#    'longitude': -117.87099566,
#    'address': '161 E ORANGETHORPE AVE Unit 134, PLACENTIA, California 92870'},
#   '46': {'latitude': 33.60776761,
#    'longitude': -117.89630953,
#    'address': '230 AGATE AVE, NEWPORT BEACH, California 92662'},
#   '47': {'latitude': 33.92242193,
#    'longitude': -117.85901397,
#    'address': '2942 SHAMROCK AVE, BREA, California 92821'},
#   '48': {'latitude': 33.42261626,
#    'longitude': -117.61630733,
#    'address': '262 AVENIDA VICTORIA Unit 1, SAN CLEMENTE, California 92672'},
#   '49': {'latitude': 33.67555407,
#    'longitude': -117.88039223,
#    'address': '245 FISCHER AVE Unit A8A, COSTA MESA, California 92626'},
#   '50': {'latitude': 33.86160059,
#    'longitude': -118.01078601,
#    'address': '7030 MELROSE ST Unit C, BUENA PARK, California 90621'},
#   '51': {'latitude': 33.77350227,
#    'longitude': -117.95736792,
#    'address': '10080 GARDEN GROVE BLVD Unit 356, GARDEN GROVE, California 92844'},
#   '52': {'latitude': 33.65508593,
#    'longitude': -117.75362219,
#    'address': '11410 SPECTRUM, IRVINE, California 92618'},
#   '53': {'latitude': 33.42441009,
#    'longitude': -117.60978809,
#    'address': '621 S EL CAMINO REAL, SAN CLEMENTE, California 92672'},
#   '54': {'latitude': 33.92322437,
#    'longitude': -117.86896824,
#    'address': '355 WINDING LN, BREA, California 92821'},
#   '55': {'latitude': 33.46930206,
#    'longitude': -117.68276339,
#    'address': '25611 QUAIL RUN Unit 47 Building 3, DANA POINT, California 92629'},
#   '56': {'latitude': 33.74434934,
#    'longitude': -117.8313703,
#    'address': '185 S MYRTLE AVE, TUSTIN, California 92780'},
#   '57': {'latitude': 33.76185684,
#    'longitude': -117.86554616,
#    'address': '1900 N SPURGEON ST Unit 206, SANTA ANA, California 92706'},
#   '58': {'latitude': 33.70638268,
#    'longitude': -117.90088579,
#    'address': '3102 S DIAMOND ST, SANTA ANA, California 92704'},
#   '59': {'latitude': 33.67950248,
#    'longitude': -118.02469406,
#    'address': '6102 GREENBRIER DR, HUNTINGTON BEACH, California 92648'},
#   '60': {'latitude': 33.7491037,
#    'longitude': -117.78625567,
#    'address': '2112 OMEGA DR, North Tustin, California 92705'},
#   '61': {'latitude': 33.69853916,
#    'longitude': -117.85435764,
#    'address': '17281 EASTMAN, IRVINE, California 92614'},
#   '62': {'latitude': 33.60460402,
#    'longitude': -117.90728084,
#    'address': '517 W BAY AVE, NEWPORT BEACH, California 92661'},
#   '63': {'latitude': 33.79530589,
#    'longitude': -118.02196708,
#    'address': '6373 BATAAN ST, CYPRESS, California 90630'},
#   '64': {'latitude': 33.82859801,
#    'longitude': -118.06133144,
#    'address': '9208 BLOOMFIELD AVE Unit 70, CYPRESS, California 90630'},
#   '65': {'latitude': 33.75699259,
#    'longitude': -117.76646771,
#    'address': '2669 DIETRICH DR, TUSTIN, California 92782'},
#   '66': {'latitude': 33.67153271,
#    'longitude': -117.80799848,
#    'address': '6 RAINSTAR, IRVINE, California 92614'},
#   '67': {'latitude': 33.75435247,
#    'longitude': -117.8654093,
#    'address': '1025 N SPURGEON ST, SANTA ANA, California 92701'},
#   '68': {'latitude': 33.69632512,
#    'longitude': -117.71642327,
#    'address': '5315 ARCHWAY, IRVINE, California 92618'},
#   '69': {'latitude': 33.67430071,
#    'longitude': -117.77564761,
#    'address': '155 TAROCCO, IRVINE, California 92618'},
#   '70': {'latitude': 33.6863415,
#    'longitude': -117.82126501,
#    'address': '335 DURANZO AISLE, IRVINE, California 92606'},
#   '71': {'latitude': 33.855552,
#    'longitude': -117.72968039,
#    'address': '8350 E QUIET CANYON CT, ANAHEIM, California 92808'},
#   '72': {'latitude': 33.71208981,
#    'longitude': -117.86550124,
#    'address': '2601 S ORANGE AVE, SANTA ANA, California 92707'},
#   '73': {'latitude': 33.77240063,
#    'longitude': -117.83407773,
#    'address': '2610 N PONDEROSA ST, SANTA ANA, California 92705'},
#   '74': {'latitude': 33.62975435,
#    'longitude': -117.95084981,
#    'address': '305 CANAL ST, NEWPORT BEACH, California 92663'},
#   '75': {'latitude': 33.67308999,
#    'longitude': -117.85801685,
#    'address': '2253 MARTIN Unit 412, IRVINE, California 92612'},
#   '76': {'latitude': 33.7566495,
#    'longitude': -118.03094803,
#    'address': '14146 BARBER ST, WESTMINSTER, California 92683'},
#   '77': {'latitude': 33.76296732,
#    'longitude': -117.93737934,
#    'address': '13742 EUCLID ST Unit 5, GARDEN GROVE, California 92843'},
#   '78': {'latitude': 33.68237522,
#    'longitude': -117.67173424,
#    'address': '26322 TOWNE CENTRE DR Unit 215 Building 2, LAKE FOREST, California 92610'},
#   '79': {'latitude': 33.68160456,
#    'longitude': -117.65511172,
#    'address': '19431 RUE DE VALORE Unit A Building 62, LAKE FOREST, California 92610'},
#   '80': {'latitude': 33.49886928,
#    'longitude': -117.70812381,
#    'address': '30 PORTLAND PL, LAGUNA NIGUEL, California 92677'},
#   '81': {'latitude': 33.82003806,
#    'longitude': -118.03480717,
#    'address': '9767 GRAHAM ST, CYPRESS, California 90630'},
#   '82': {'latitude': 33.8646675,
#    'longitude': -118.00058159,
#    'address': '7616 9TH ST Unit A, BUENA PARK, California 90621'},
#   '83': {'latitude': 33.7614876,
#    'longitude': -118.00252604,
#    'address': '7232 20TH ST Unit 6, WESTMINSTER, California 92683'},
#   '84': {'latitude': 33.87641831,
#    'longitude': -117.75874422,
#    'address': '5915 VIA DEL TECOLOTE, YORBA LINDA, California 92887'},
#   '85': {'latitude': 33.68861717,
#    'longitude': -117.65279179,
#    'address': '18 CAMARIN ST, LAKE FOREST, California 92610'},
#   '86': {'latitude': 33.53600395,
#    'longitude': -117.59798065,
#    'address': '42 MARISOL ST, Rancho Mission Viejo, California 92675'},
#   '87': {'latitude': 33.77694292,
#    'longitude': -117.9524713,
#    'address': '10372 STANFORD AVE Unit T, GARDEN GROVE, California 92840'},
#   '88': {'latitude': 33.83745824,
#    'longitude': -117.76695562,
#    'address': '781 S STILLWATER LN, ANAHEIM, California 92807'},
#   '89': {'latitude': 33.91693899,
#    'longitude': -117.92119393,
#    'address': '500 E IMPERIAL HWY Unit E, FULLERTON, California 92835'},
#   '90': {'latitude': 33.72906556,
#    'longitude': -117.77771219,
#    'address': '14 CHANDON, IRVINE, California 92602'},
#   '91': {'latitude': 33.90878384,
#    'longitude': -117.90012462,
#    'address': '408 E FIR ST, BREA, California 92821'},
#   '92': {'latitude': 33.91558618,
#    'longitude': -117.8731946,
#    'address': '315 DEVONSHIRE DR, BREA, California 92821'},
#   '93': {'latitude': 33.85109584,
#    'longitude': -118.0498448,
#    'address': '7672 BARBI LN, LA PALMA, California 90623'},
#   '94': {'latitude': 33.74379839,
#    'longitude': -117.78946338,
#    'address': '2195 COLLIER CT, TUSTIN, California 92782'},
#   '95': {'latitude': 33.65593767,
#    'longitude': -117.74985937,
#    'address': '7725 GATEWAY BLVD Unit 2418 Building 2000, IRVINE, California 92618'},
#   '96': {'latitude': 33.57623002,
#    'longitude': -117.70972945,
#    'address': '24112 HOLLYOAK Unit H, ALISO VIEJO, California 92656'},
#   '97': {'latitude': 33.75211232,
#    'longitude': -117.80689824,
#    'address': '12700 NEWPORT AVE Unit 15, North Tustin, California 92780'},
#   '98': {'latitude': 33.66745695,
#    'longitude': -117.99193399,
#    'address': '1117 ENGLAND ST Unit A, HUNTINGTON BEACH, California 92648'},
#   '99': {'latitude': 33.83616759,
#    'longitude': -117.74836373,
#    'address': '990 S RUTGERS CIR, ANAHEIM, California 92807'},
#   '100': {'latitude': 33.6471467,
#    'longitude': -117.7765787,
#    'address': '71 CORIANDER, IRVINE, California 92603'},
#   '101': {'latitude': 33.85761829,
#    'longitude': -118.02309476,
#    'address': '7067 EAGLE DR, BUENA PARK, California 90620'},
#   '102': {'latitude': 33.72172328,
#    'longitude': -117.81357028,
#    'address': '14542 HYANNIS PORT RD, TUSTIN, California 92780'},
#   '103': {'latitude': 33.3925862,
#    'longitude': -117.59711914,
#    'address': '4036 CALLE MARLENA, SAN CLEMENTE, California 92672'},
#   '104': {'latitude': 33.72397187,
#    'longitude': -118.04719923,
#    'address': '16393 VISTA ROMA CIR, HUNTINGTON BEACH, California 92649'},
#   '105': {'latitude': 33.85987579,
#    'longitude': -118.00114024,
#    'address': '7551 ORANGETHORPE AVE Unit 302, BUENA PARK, California 90621'},
#   '106': {'latitude': 33.60325323,
#    'longitude': -117.64268731,
#    'address': '27941 NEVADO, MISSION VIEJO, California 92692'},
#   '107': {'latitude': 33.81866897,
#    'longitude': -118.02130629,
#    'address': '9951 HOLDER ST Unit 51, CYPRESS, California 90630'},
#   '108': {'latitude': 33.73751162,
#    'longitude': -117.85880358,
#    'address': '814 S CEDAR ST, SANTA ANA, California 92701'},
#   '109': {'latitude': 33.44870035,
#    'longitude': -117.59421471,
#    'address': '1100 CALLE DEL CERRO Unit 152L, SAN CLEMENTE, California 92672'},
#   '110': {'latitude': 33.5793255,
#    'longitude': -117.68716942,
#    'address': '26422 DAPPLE GREY DR, LAGUNA HILLS, California 92653'},
#   '111': {'latitude': 33.93253472,
#    'longitude': -117.89193648,
#    'address': '272 BROOKSHIRE PL, BREA, California 92821'},
#   '112': {'latitude': 33.60664489,
#    'longitude': -117.66881606,
#    'address': '26442 NACCOME DR, MISSION VIEJO, California 92691'},
#   '113': {'latitude': 33.5868294,
#    'longitude': -117.85665954,
#    'address': '8 PELICAN POINT DR, NEWPORT BEACH, California 92657'},
#   '114': {'latitude': 33.76984167,
#    'longitude': -117.79063631,
#    'address': '11151 COVENTRY PL, North Tustin, California 92705'},
#   '115': {'latitude': 33.77415968,
#    'longitude': -117.97786721,
#    'address': '8851 GARDEN GROVE BLVD Unit 102, GARDEN GROVE, California 92844'},
#   '116': {'latitude': 33.7019043,
#    'longitude': -117.78619823,
#    'address': '4182 BELVEDERE ST, IRVINE, California 92604'},
#   '117': {'latitude': 33.74662462,
#    'longitude': -117.87319219,
#    'address': '100 N ROSS ST Unit B359 Building B, SANTA ANA, California 92701'},
#   '118': {'latitude': 33.79921467,
#    'longitude': -117.83381933,
#    'address': '724 N RUSSELL DR, ORANGE, California 92867'},
#   '119': {'latitude': 33.75793878,
#    'longitude': -117.97412116,
#    'address': '14081 MAGNOLIA ST Unit 126, WESTMINSTER, California 92683'},
#   '120': {'latitude': 33.8759818,
#    'longitude': -117.92890442,
#    'address': '613 N HIGHLAND AVE, FULLERTON, California 92832'},
#   '121': {'latitude': 33.87785626,
#    'longitude': -117.93474883,
#    'address': '800 GLENHAVEN AVE, FULLERTON, California 92832'},
#   '122': {'latitude': 33.86924127,
#    'longitude': -117.87563146,
#    'address': '319 S WALNUT AVE, PLACENTIA, California 92870'},
#   '123': {'latitude': 33.68499513,
#    'longitude': -117.84044144,
#    'address': '2552 KELVIN AVE Unit 105, IRVINE, California 92614'},
#   '124': {'latitude': 33.85566027,
#    'longitude': -117.91966245,
#    'address': '1430 N LEMON ST, ANAHEIM, California 92801'},
#   '125': {'latitude': 33.88278452,
#    'longitude': -117.99905779,
#    'address': '7661 STAGE RD Unit 2, BUENA PARK, California 90621'},
#   '126': {'latitude': 33.77247076,
#    'longitude': -117.98813892,
#    'address': '8081 LARSON AVE Unit 6, GARDEN GROVE, California 92844'},
#   '127': {'latitude': 33.79417009,
#    'longitude': -117.84968767,
#    'address': '445 N CENTER ST, ORANGE, California 92866'},
#   '128': {'latitude': 33.81215086,
#    'longitude': -118.00073865,
#    'address': '7570 CODY DR, STANTON, California 90680'},
#   '129': {'latitude': 33.49325097,
#    'longitude': -117.71873912,
#    'address': '32410 CROWN VALLEY PKWY Unit 303, DANA POINT, California 92629'},
#   '130': {'latitude': 33.75524287,
#    'longitude': -118.04155256,
#    'address': '14271 BAKER ST, WESTMINSTER, California 92683'},
#   '131': {'latitude': 33.83677127,
#    'longitude': -117.85404767,
#    'address': '420 W LINDEN DR, ORANGE, California 92865'},
#   '132': {'latitude': 33.83545481,
#    'longitude': -118.01984277,
#    'address': '8765 HOLDER ST, BUENA PARK, California 90620'},
#   '133': {'latitude': 33.60920857,
#    'longitude': -117.84824451,
#    'address': '6 JADE CV, NEWPORT BEACH, California 92625'},
#   '134': {'latitude': 33.41966065,
#    'longitude': -117.61537861,
#    'address': '317 CAZADOR LN Unit A, SAN CLEMENTE, California 92672'},
#   '135': {'latitude': 33.69779735,
#    'longitude': -117.72803223,
#    'address': '181 COMPASS, IRVINE, California 92618'},
#   '136': {'latitude': 33.62943303,
#    'longitude': -117.92304802,
#    'address': '226 E 15TH ST Unit B, COSTA MESA, California 92627'},
#   '137': {'latitude': 33.84753786,
#    'longitude': -117.73787429,
#    'address': '8031 E SANDSTONE DR, ANAHEIM, California 92808'},
#   '138': {'latitude': 33.55868372,
#    'longitude': -117.67018088,
#    'address': '1006 THE SHOPS AT MISSION VIEJO, MISSION VIEJO, California 92691'},
#   '139': {'latitude': 33.82169687,
#    'longitude': -117.80336339,
#    'address': '18702 MESA DR, VILLA PARK, California 92861'},
#   '140': {'latitude': 33.73915955,
#    'longitude': -117.83470778,
#    'address': '15500 TUSTIN VILLAGE WAY Unit 49, TUSTIN, California 92780'},
#   '141': {'latitude': 33.54557536,
#    'longitude': -117.79508403,
#    'address': '665 CLIFF DR, LAGUNA BEACH, California 92651'},
#   '142': {'latitude': 33.67653097,
#    'longitude': -117.82304592,
#    'address': '34 SORRENTO, IRVINE, California 92614'},
#   '143': {'latitude': 33.67816654,
#    'longitude': -117.79493478,
#    'address': '6 ALDERBERRY, IRVINE, California 92604'},
#   '144': {'latitude': 33.87301958,
#    'longitude': -117.85116057,
#    'address': '910 SPYGLASS PL, PLACENTIA, California 92870'},
#   '145': {'latitude': 33.54448356,
#    'longitude': -117.77697943,
#    'address': '549 MYSTIC WAY, LAGUNA BEACH, California 92651'},
#   '146': {'latitude': 33.71031442,
#    'longitude': -117.92156584,
#    'address': '2737 S CRODDY WAY Unit A, SANTA ANA, California 92704'},
#   '147': {'latitude': 33.83893972,
#    'longitude': -117.78856915,
#    'address': '684 S FRONTIER CT, ANAHEIM, California 92807'},
#   '148': {'latitude': 33.772724,
#    'longitude': -117.84985014,
#    'address': '2626 N OLD GRAND ST, SANTA ANA, California 92705'},
#   '149': {'latitude': 33.63560376,
#    'longitude': -117.63403939,
#    'address': '22491 BAYBERRY, MISSION VIEJO, California 92692'},
#   '150': {'latitude': 33.82875013,
#    'longitude': -117.76200846,
#    'address': '8519 KENDRA LOOP, ORANGE, California 92867'},
#   '151': {'latitude': 33.60971515,
#    'longitude': -117.71138537,
#    'address': '24012 CALLE DE LA PLATA Unit 150, LAGUNA HILLS, California 92653'},
#   '152': {'latitude': 33.67203492,
#    'longitude': -117.89118836,
#    'address': '813 PRESIDIO DR, COSTA MESA, California 92626'},
#   '153': {'latitude': 33.63394654,
#    'longitude': -117.69719712,
#    'address': '22675 SHADY GROVE CIR, LAKE FOREST, California 92630'},
#   '154': {'latitude': 33.63938629,
#    'longitude': -117.66699547,
#    'address': '22252 CRIPPLE CRK, LAKE FOREST, California 92630'},
#   '155': {'latitude': 33.7212297,
#    'longitude': -117.80920865,
#    'address': '14371 RAINTREE RD, TUSTIN, California 92780'},
#   '156': {'latitude': 33.44390405,
#    'longitude': -117.59075387,
#    'address': '705 LOMA ADRIA, SAN CLEMENTE, California 92672'},
#   '157': {'latitude': 33.77897161,
#    'longitude': -117.9971961,
#    'address': '7700 LAMPSON AVE Unit 126, STANTON, California 92841'},
#   '158': {'latitude': 33.85310027,
#    'longitude': -118.0215696,
#    'address': '6387 HANCOCK WAY, BUENA PARK, California 90620'},
#   '159': {'latitude': 33.56055351,
#    'longitude': -117.6713048,
#    'address': '27741 CROWN VALLEY PKWY Unit 309, MISSION VIEJO, California 92691'},
#   '160': {'latitude': 33.87269055,
#    'longitude': -117.86743507,
#    'address': '201 E CHAPMAN AVE Unit 42B Building 4, PLACENTIA, California 92870'},
#   '161': {'latitude': 33.75444103,
#    'longitude': -118.00646193,
#    'address': '7032 MAIN ST Unit 18, WESTMINSTER, California 92683'},
#   '162': {'latitude': 33.73049081,
#    'longitude': -117.88906326,
#    'address': '1306 S SPRUCE ST, SANTA ANA, California 92704'},
#   '163': {'latitude': 33.78031853,
#    'longitude': -117.98922294,
#    'address': '849 CHATEAU CT, STANTON, California 92841'},
#   '164': {'latitude': 33.65168008,
#    'longitude': -117.64233213,
#    'address': '27982 VIRGINIA, MISSION VIEJO, California 92692'},
#   '165': {'latitude': 33.91285457,
#    'longitude': -117.89128151,
#    'address': '920 E IMPERIAL HWY, BREA, California 92821'},
#   '166': {'latitude': 33.74328049,
#    'longitude': -118.0972222,
#    'address': '424 OPAL COVE WAY, SEAL BEACH, California 90740'},
#   '167': {'latitude': 33.68365966,
#    'longitude': -117.83784087,
#    'address': '2790 KELVIN AVE Unit 1207 Building 1, IRVINE, California 92614'},
#   '168': {'latitude': 33.88509903,
#    'longitude': -117.96293743,
#    'address': '1338 NOUTARY DR, FULLERTON, California 92833'},
#   '169': {'latitude': 33.6415822,
#    'longitude': -117.89599449,
#    'address': '2200 WINDWARD LN, NEWPORT BEACH, California 92660'},
#   '170': {'latitude': 33.8991442,
#    'longitude': -117.80181581,
#    'address': '4245 HIDDEN OAKS DR, YORBA LINDA, California 92886'},
#   '171': {'latitude': 33.67371643,
#    'longitude': -117.99200508,
#    'address': '1815 ALSUNA LN, HUNTINGTON BEACH, California 92648'},
#   '172': {'latitude': 33.74754266,
#    'longitude': -117.91233112,
#    'address': '3200 W 5TH ST Unit 305, SANTA ANA, California 92703'},
#   '173': {'latitude': 33.89415119,
#    'longitude': -117.94461232,
#    'address': '2051 N EUCLID ST Unit E, FULLERTON, California 92835'},
#   '174': {'latitude': 33.76362431,
#    'longitude': -117.90324305,
#    'address': '1940 N FAIRVIEW ST Unit 2, SANTA ANA, California 92706'},
#   '175': {'latitude': 33.82443044,
#    'longitude': -118.00791352,
#    'address': '3354 W ORANGE AVE, ANAHEIM, California 92804'},
#   '176': {'latitude': 33.75131547,
#    'longitude': -117.8386676,
#    'address': '722 N PARK CENTER DR Unit 102, SANTA ANA, California 92705'},
#   '177': {'latitude': 33.65075617,
#    'longitude': -117.89347423,
#    'address': '379 SANTA ISABEL AVE, NEWPORT BEACH, California 92660'},
#   '178': {'latitude': 33.65161521,
#    'longitude': -117.74399453,
#    'address': '670 SPECTRUM CENTER DR, IRVINE, California 92618'},
#   '179': {'latitude': 33.6305519,
#    'longitude': -117.8749538,
#    'address': '70 SEA ISLAND DR, NEWPORT BEACH, California 92660'},
#   '180': {'latitude': 33.88173614,
#    'longitude': -117.99444584,
#    'address': '5335 FALLS WAY Unit H, BUENA PARK, California 90621'},
#   '181': {'latitude': 33.76261313,
#    'longitude': -117.86178939,
#    'address': '519 E 20TH ST, SANTA ANA, California 92706'},
#   '182': {'latitude': 33.63253692,
#    'longitude': -117.57272242,
#    'address': '13 INVERARY, RANCHO SANTA MARGARITA, California 92679'},
#   '183': {'latitude': 33.62613288,
#    'longitude': -117.88152556,
#    'address': '4000 PARK NEWPORT Unit 402, NEWPORT BEACH, California 92660'},
#   '184': {'latitude': 33.58328302,
#    'longitude': -117.70977783,
#    'address': '26035 MOULTON PKWY Unit 217 Building N, LAGUNA HILLS, California 92653'},
#   '185': {'latitude': 33.94092828,
#    'longitude': -117.96131135,
#    'address': '921 N RUSSELL ST, LA HABRA, California 90631'},
#   '186': {'latitude': 33.89530668,
#    'longitude': -117.87050528,
#    'address': '1856 N PLACENTIA AVE, PLACENTIA, California 92870'},
#   '187': {'latitude': 33.81734001,
#    'longitude': -118.0439924,
#    'address': '5117 BALL RD, CYPRESS, California 90630'},
#   '188': {'latitude': 33.75788757,
#    'longitude': -117.8039323,
#    'address': '14121 DRYDEN LN, North Tustin, California 92705'},
#   '189': {'latitude': 33.59755911,
#    'longitude': -117.62278278,
#    'address': '5 GREENVALE, Las Flores, California 92688'},
#   '190': {'latitude': 33.64838453,
#    'longitude': -117.94178823,
#    'address': '1015 GROVE PL, COSTA MESA, California 92627'},
#   '191': {'latitude': 33.70156117,
#    'longitude': -117.76713371,
#    'address': '5 CARVER, IRVINE, California 92620'},
#   '192': {'latitude': 33.70217224,
#    'longitude': -117.8272141,
#    'address': '16003 LEGACY RD Unit 204, TUSTIN, California 92782'},
#   '193': {'latitude': 33.73325121,
#    'longitude': -117.82444964,
#    'address': '14300 NEWPORT AVE Unit 89, TUSTIN, California 92780'},
#   '194': {'latitude': 33.71227685,
#    'longitude': -117.8985474,
#    'address': '2221 W ADAMS ST, SANTA ANA, California 92704'},
#   '195': {'latitude': 33.71321597,
#    'longitude': -117.75733534,
#    'address': '88 STREAMWOOD, IRVINE, California 92620'},
#   '196': {'latitude': 33.92913889,
#    'longitude': -117.97506977,
#    'address': '391 S OAKLAND DR, LA HABRA, California 90631'},
#   '197': {'latitude': 33.60498686,
#    'longitude': -117.89041746,
#    'address': '112 ONYX AVE, NEWPORT BEACH, California 92662'},
#   '198': {'latitude': 33.78430559,
#    'longitude': -118.02991389,
#    'address': '12262 SAINT MARK ST, GARDEN GROVE, California 92845'},
#   '199': {'latitude': 33.76342741,
#    'longitude': -117.84123636,
#    'address': '1919 N SHERRY LN Unit 63, SANTA ANA, California 92705'},
#   '200': {'latitude': 33.86121284,
#    'longitude': -117.97969648,
#    'address': '8833 ACADEMY DR Unit 20, BUENA PARK, California 90621'}})

# %% [markdown]
# ---
#
# ## Generate benchmark from google solution api, opimization route....

# %%
# Cell 1: Imports
import numpy as np
import json
import googlemaps
from datetime import datetime
import matplotlib.pyplot as plt

# Cell 2: Load Data
# Load distance matrix
distance_matrix = np.load('distance_matrix.npy')
print(f"Distance matrix shape: {distance_matrix.shape}")

# Load locations mapping
with open('locations_mapping.json', 'r') as f:
    locations_mapping = json.load(f)
print(f"Number of locations: {len(locations_mapping)}")
# Out:
# Distance matrix shape: (201, 201)
# Number of locations: 201

# %%
# Cell 3: Helper Functions
def plot_route(route, title="Route"):
    """Plot the route on a scatter plot"""
    plt.figure(figsize=(12, 8))
    
    # Extract coordinates
    x_coords = [locations_mapping[str(i)]['longitude'] for i in route]
    y_coords = [locations_mapping[str(i)]['latitude'] for i in route]
    
    # Add warehouse return coordinates
    x_coords.append(locations_mapping['0']['longitude'])
    y_coords.append(locations_mapping['0']['latitude'])
    
    # Plot points and routes
    plt.scatter(x_coords, y_coords, c='blue', s=50)
    plt.plot(x_coords, y_coords, 'r-', alpha=0.5)
    
    # Highlight warehouse
    plt.scatter([x_coords[0]], [y_coords[0]], c='red', s=100, label='Warehouse')
    
    plt.title(title)
    plt.legend()
    plt.grid(True)
    plt.show()

def get_google_benchmark_route_chunked():
    """Get optimized route from Google Maps Routes API using chunks"""
    import time  # Import time module inside function
    from datetime import datetime
    
    # Initialize Google Maps client
    gmaps = googlemaps.Client(key='NONE')
    
    try:
        MAX_WAYPOINTS = 23  # Using 23 to be safe (25 - origin - destination)
        n_locations = len(locations_mapping) - 1  # Excluding warehouse
        n_chunks = (n_locations + MAX_WAYPOINTS - 1) // MAX_WAYPOINTS  # Ceiling division
        
        print(f"Breaking {n_locations} locations into {n_chunks} chunks...")
        
        final_route = [0]  # Start with warehouse
        total_distance = 0
        
        # Process locations in chunks
        for chunk in range(n_chunks):
            start_idx = chunk * MAX_WAYPOINTS + 1  # +1 to skip warehouse
            end_idx = min((chunk + 1) * MAX_WAYPOINTS + 1, len(locations_mapping))
            
            print(f"\nProcessing chunk {chunk + 1}/{n_chunks} (locations {start_idx} to {end_idx-1})")
            
            # Create waypoints for this chunk
            waypoints = []
            for i in range(start_idx, end_idx):
                waypoint = f"{locations_mapping[str(i)]['latitude']},{locations_mapping[str(i)]['longitude']}"
                waypoints.append(waypoint)
            
            # Warehouse coordinates
            warehouse = f"{locations_mapping['0']['latitude']},{locations_mapping['0']['longitude']}"
            
            # If it's not the first chunk, use last location from previous chunk as origin
            origin = warehouse if chunk == 0 else f"{locations_mapping[str(final_route[-1])]['latitude']},{locations_mapping[str(final_route[-1])]['longitude']}"
            
            # If it's not the last chunk, don't return to warehouse yet
            destination = warehouse if chunk == n_chunks-1 else waypoints[-1]
            
            # Make API request for this chunk
            result = gmaps.directions(
                origin=origin,
                destination=destination,
                waypoints=waypoints[:-1] if chunk != n_chunks-1 else waypoints,  # Exclude last waypoint if it's destination
                optimize_waypoints=True,
                mode="driving"
            )
            
            if result:
                # Extract optimized route for this chunk
                waypoint_order = result[0]['waypoint_order']
                chunk_route = [start_idx + i for i in waypoint_order]
                
                # Add to final route
                if chunk == n_chunks-1:
                    final_route.extend(chunk_route)
                else:
                    final_route.extend(chunk_route[:-1])  # Exclude last point as it'll be origin of next chunk
                
                # Add distances
                chunk_distance = sum(leg['distance']['value'] for leg in result[0]['legs'])
                total_distance += chunk_distance
                
                print(f"Chunk {chunk + 1} processed: {len(chunk_route)} locations, {chunk_distance/1000:.2f} km")
            
            # Sleep briefly to avoid hitting API rate limits
            time.sleep(1)
        
        # Save benchmark data
        benchmark_data = {
            'route': final_route,
            'distance': total_distance,
            'timestamp': datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
            'num_chunks': n_chunks
        }
        
        # Save to file
        with open('google_benchmark.json', 'w') as f:
            json.dump(benchmark_data, f)
        
        print(f"\nFinal Results:")
        print(f"Total Distance: {total_distance/1000:.2f} km")
        print(f"Number of stops: {len(final_route)}")
        
        # Plot the route
        plot_route(final_route, "Google Maps Chunked Optimized Route")
        
        return benchmark_data
            
    except Exception as e:
        print(f"Error calling Google Maps API: {str(e)}")
        import traceback
        traceback.print_exc()
        return None

# Run the chunked version
benchmark_data = get_google_benchmark_route_chunked()
# Out:
# Breaking 200 locations into 9 chunks...
#
# Processing chunk 1/9 (locations 1 to 23)
# Chunk 1 processed: 22 locations, 233.88 km
#
# Processing chunk 2/9 (locations 24 to 46)
# Chunk 2 processed: 22 locations, 258.85 km
#
# Processing chunk 3/9 (locations 47 to 69)
# Chunk 3 processed: 22 locations, 256.16 km
#
# Processing chunk 4/9 (locations 70 to 92)
# Chunk 4 processed: 22 locations, 225.08 km
#
# Processing chunk 5/9 (locations 93 to 115)
# Chunk 5 processed: 22 locations, 253.33 km
#
# Processing chunk 6/9 (locations 116 to 138)
# Chunk 6 processed: 22 locations, 242.09 km
#
# Processing chunk 7/9 (locations 139 to 161)
# Chunk 7 processed: 22 locations, 213.16 km
#
# Processing chunk 8/9 (locations 162 to 184)
# Chunk 8 processed: 22 locations, 232.09 km
#
# Processing chunk 9/9 (locations 185 to 200)
# Chunk 9 processed: 16 locations, 182.98 km
#
# Final Results:
# Total Distance: 2097.62 km
# Number of stops: 185
