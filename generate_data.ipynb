# %%
import pandas as pd
import numpy as np
import requests
import time
import json

# %% [markdown]
# # Load Original Data Set and prepare it

# %%
df = pd.read_csv("Address_Point_OCPW___OCFA.csv")
df.head()
# Out:
# /var/folders/4z/5nxj2j413mvcb6fq306y6t6w0000gn/T/ipykernel_4008/662411323.py:1: DtypeWarning: Columns (4,6,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Address_Point_OCPW___OCFA.csv")
#    OBJECTID  AddressPtID     StreetName  AddressNumber Fractional Unit  \
# 0         1   92689299.0    ASHGROVE DR           8172        NaN  NaN
# 1         2   92689094.0  BARRINGTON DR           8101        NaN  NaN
# 2         3   92689097.0  BARRINGTON DR           8122        NaN  NaN
# 3         4   92689155.0    FAIRHOPE DR           4632        NaN  NaN
# 4         5   92689091.0  BARRINGTON DR           8161        NaN  NaN
#
#   Building SubAddressFlag  RouteExternalKey  ZipCode  ...  \
# 0      NaN            NaN       394473602.0    90638  ...
# 1      NaN            NaN               NaN    90638  ...
# 2      NaN            NaN               NaN    90638  ...
# 3      NaN            NaN               NaN    90638  ...
# 4      NaN            NaN               NaN    90638  ...
#
#                   Address FullNumber  UnitID  created_user  \
# 0    8172 ASHGROVE DR            NaN     NaN   ARCGISADMIN
# 1  8101 BARRINGTON DR            NaN     NaN   ARCGISADMIN
# 2  8122 BARRINGTON DR            NaN     NaN   ARCGISADMIN
# 3    4632 FAIRHOPE DR            NaN     NaN   ARCGISADMIN
# 4  8161 BARRINGTON DR            NaN     NaN   ARCGISADMIN
#
#              created_date  last_edited_user        last_edited_date  \
# 0  2024/09/03 13:46:03+00       ARCGISADMIN  2024/09/03 13:46:03+00
# 1  2024/09/03 13:46:03+00       ARCGISADMIN  2024/09/03 13:46:03+00
# 2  2024/09/03 13:46:03+00       ARCGISADMIN  2024/09/03 13:46:03+00
# 3  2024/09/03 13:46:03+00       ARCGISADMIN  2024/09/03 13:46:03+00
# 4  2024/09/03 13:46:03+00       ARCGISADMIN  2024/09/03 13:46:03+00
#
#           County StateAbbr ADD_TYPE
# 0  Orange County        CA      NaN
# 1  Orange County        CA      NaN
# 2  Orange County        CA      NaN
# 3  Orange County        CA      NaN
# 4  Orange County        CA      NaN
#
# [5 rows x 24 columns]

# %%
# Randomly sample 200 rows
sampled_df = df.sample(200)

# Save the sampled data into a new CSV file
sampled_df.to_csv("sampled_data1.csv", index=False)

# %% [markdown]
# # Extract 200 randomly sampled data set

# %%
sampled_df = pd.read_csv("sampled_data1.csv")
sampled_df.head()
# Out:
#    OBJECTID  AddressPtID             StreetName  AddressNumber  Fractional  \
# 0   1131713   26024335.0           RIDE OUT WAY            830         NaN
# 1    309146   92883264.0  AVENIDA DE LA CARLOTA          24391         NaN
# 2   1063801   92775897.0         VALLEY VIEW ST           7921         NaN
# 3    691438   30030058.0          GLOUCESTER LN          19801         NaN
# 4    249638   92747576.0             ENTERPRISE              2         NaN
#
#     Unit Building SubAddressFlag  RouteExternalKey  ZipCode  ...  \
# 0    NaN      NaN            NaN               NaN    92835  ...
# 1    270      NaN            NaN         1179469.0    92653  ...
# 2    NaN      NaN            NaN               NaN    90623  ...
# 3    NaN      NaN            NaN               NaN    92646  ...
# 4  10310       10            NaN               NaN    92656  ...
#
#                               Address FullNumber  UnitID  created_user  \
# 0                830 RIDE OUT WAY            NaN     NaN   ARCGISADMIN
# 1  24391 AVENIDA DE LA CARLOTA    270        NaN     NaN   ARCGISADMIN
# 2             7921 VALLEY VIEW ST            NaN     NaN   ARCGISADMIN
# 3             19801 GLOUCESTER LN            NaN     NaN   ARCGISADMIN
# 4             2 ENTERPRISE   10 10310        NaN     NaN   ARCGISADMIN
#
#              created_date  last_edited_user        last_edited_date  \
# 0  2024/09/03 13:46:03+00       ARCGISADMIN  2024/09/03 13:46:03+00
# 1  2024/09/03 13:46:03+00       ARCGISADMIN  2024/09/03 13:46:03+00
# 2  2024/09/03 13:46:03+00       ARCGISADMIN  2024/09/03 13:46:03+00
# 3  2024/09/03 13:46:03+00       ARCGISADMIN  2024/09/03 13:46:03+00
# 4  2024/09/03 13:46:03+00       ARCGISADMIN  2024/09/03 13:46:03+00
#
#           County StateAbbr ADD_TYPE
# 0  Orange County        CA      NaN
# 1  Orange County        CA      NaN
# 2  Orange County        CA      NaN
# 3  Orange County        CA      NaN
# 4  Orange County        CA      NaN
#
# [5 rows x 24 columns]

# %%
sampled_df.loc[1]
# Out:
# OBJECTID                                        309146
# AddressPtID                                 92883264.0
# StreetName                       AVENIDA DE LA CARLOTA
# AddressNumber                                    24391
# Fractional                                         NaN
# Unit                                               270
# Building                                           NaN
# SubAddressFlag                                     NaN
# RouteExternalKey                             1179469.0
# ZipCode                                          92653
# City                                      LAGUNA HILLS
# State                                       California
# X                                          -117.701114
# Y                                            33.608235
# Address             24391 AVENIDA DE LA CARLOTA    270
# FullNumber                                         NaN
# UnitID                                             NaN
# created_user                               ARCGISADMIN
# created_date                    2024/09/03 13:46:03+00
# last_edited_user                           ARCGISADMIN
# last_edited_date                2024/09/03 13:46:03+00
# County                                   Orange County
# StateAbbr                                           CA
# ADD_TYPE                                           NaN
# Name: 1, dtype: object

# %%
sampled_df.loc[2]
# Out:
# OBJECTID                            1063801
# AddressPtID                      92775897.0
# StreetName                   VALLEY VIEW ST
# AddressNumber                          7921
# Fractional                              NaN
# Unit                                    NaN
# Building                                NaN
# SubAddressFlag                          NaN
# RouteExternalKey                        NaN
# ZipCode                               90623
# City                               LA PALMA
# State                            California
# X                               -118.029364
# Y                                 33.847553
# Address             7921 VALLEY VIEW ST
# FullNumber                              NaN
# UnitID                                  NaN
# created_user                    ARCGISADMIN
# created_date         2024/09/03 13:46:03+00
# last_edited_user                ARCGISADMIN
# last_edited_date     2024/09/03 13:46:03+00
# County                        Orange County
# StateAbbr                                CA
# ADD_TYPE                                NaN
# Name: 2, dtype: object

# %% [markdown]
# # Upon checking from google maps, X and Y need to be swapped!

# %%
# Swap X and Y coordinates
sampled_df['X_temp'] = sampled_df['X']
sampled_df['X'] = sampled_df['Y']
sampled_df['Y'] = sampled_df['X_temp']
sampled_df.drop('X_temp', axis=1, inplace=True)

# %% [markdown]
# # Put UCI as WAREHOUSE, add another address

# %%
# Create UCI warehouse data
warehouse_df = pd.DataFrame({
    'X': [33.6424],  # Latitude
    'Y': [-117.8417],  # Longitude
    'AddressNumber': ['260'],
    'StreetName': ['Aldrich Hall'],
    'City': ['Irvine'],
    'State': ['California'],
    'ZipCode': ['92697']
})

# Add missing columns to warehouse_df
for col in sampled_df.columns:
    if col not in warehouse_df.columns:
        warehouse_df[col] = None
        
# Combine warehouse and delivery locations
complete_df = pd.concat([warehouse_df, sampled_df], ignore_index=True)
# Out:
# /var/folders/4z/5nxj2j413mvcb6fq306y6t6w0000gn/T/ipykernel_4008/967765116.py:18: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   complete_df = pd.concat([warehouse_df, sampled_df], ignore_index=True)

# %%
complete_df.head()
# Out:
#            X           Y AddressNumber             StreetName  \
# 0  33.642400 -117.841700           260           Aldrich Hall
# 1  33.907789 -117.939657           830           RIDE OUT WAY
# 2  33.608235 -117.701114         24391  AVENIDA DE LA CARLOTA
# 3  33.847553 -118.029364          7921         VALLEY VIEW ST
# 4  33.674988 -117.964585         19801          GLOUCESTER LN
#
#                City       State ZipCode OBJECTID  AddressPtID Fractional  ...  \
# 0            Irvine  California   92697     None          NaN       None  ...
# 1         FULLERTON  California   92835  1131713   26024335.0        NaN  ...
# 2      LAGUNA HILLS  California   92653   309146   92883264.0        NaN  ...
# 3          LA PALMA  California   90623  1063801   92775897.0        NaN  ...
# 4  HUNTINGTON BEACH  California   92646   691438   30030058.0        NaN  ...
#
#                               Address FullNumber UnitID  created_user  \
# 0                                None       None   None          None
# 1                830 RIDE OUT WAY            NaN    NaN   ARCGISADMIN
# 2  24391 AVENIDA DE LA CARLOTA    270        NaN    NaN   ARCGISADMIN
# 3             7921 VALLEY VIEW ST            NaN    NaN   ARCGISADMIN
# 4             19801 GLOUCESTER LN            NaN    NaN   ARCGISADMIN
#
#              created_date last_edited_user        last_edited_date  \
# 0                    None             None                    None
# 1  2024/09/03 13:46:03+00      ARCGISADMIN  2024/09/03 13:46:03+00
# 2  2024/09/03 13:46:03+00      ARCGISADMIN  2024/09/03 13:46:03+00
# 3  2024/09/03 13:46:03+00      ARCGISADMIN  2024/09/03 13:46:03+00
# 4  2024/09/03 13:46:03+00      ARCGISADMIN  2024/09/03 13:46:03+00
#
#           County StateAbbr ADD_TYPE
# 0           None      None     None
# 1  Orange County        CA      NaN
# 2  Orange County        CA      NaN
# 3  Orange County        CA      NaN
# 4  Orange County        CA      NaN
#
# [5 rows x 24 columns]

# %%
def create_distance_matrix(locations_df, api_key, batch_size=25):
    """
    Create a distance matrix using Google Maps API
    """
    # Create locations list
    locations = [f"{row['X']},{row['Y']}" for _, row in locations_df.iterrows()]
    n_locations = len(locations)
    
    # Initialize matrix
    distance_matrix = np.zeros((n_locations, n_locations))
    element_count = 0
    
    # Calculate distances
    for i in range(0, n_locations):
        for j in range(i + 1, n_locations, batch_size):
            batch_end = min(j + batch_size, n_locations)
            destinations = locations[j:batch_end]
            
            # API request
            url = "https://maps.googleapis.com/maps/api/distancematrix/json"
            params = {
                'origins': locations[i],
                'destinations': '|'.join(destinations),
                'mode': 'driving',
                'key': api_key
            }
            
            try:
                response = requests.get(url, params=params)
                data = response.json()
                
                print(f"\nAPI Response for origin {i}:")
                print(f"Status: {data['status']}")
                if 'error_message' in data:
                    print(f"Error: {data['error_message']}")
                    continue
                
                if data['status'] == 'OK' and len(data['rows']) > 0:
                    elements = data['rows'][0]['elements']
                    for col_idx, element in enumerate(elements):
                        matrix_j = j + col_idx
                        if element['status'] == 'OK':
                            distance = element['distance']['value']
                            distance_matrix[i][matrix_j] = distance
                            distance_matrix[matrix_j][i] = distance
                            element_count += 1
                            print(f"Distance from {i} to {matrix_j}: {distance/1000:.2f} km")
                
                print(f"Processed: origin {i}, destinations {j}-{batch_end-1}. Elements: {element_count}")
                # Respect Google Maps API rate limits
                time.sleep(0.2)  # Increased delay to be safe
                
            except Exception as e:
                print(f"Error in batch {i},{j}: {str(e)}")
                time.sleep(1)  # Longer delay after an error
    
    # Create mapping
    locations_mapping = {}
    for idx, row in locations_df.iterrows():
        # Special handling for warehouse (index 0)
        if idx == 0:
            address = "UCI Warehouse: 260 Aldrich Hall, Irvine, CA 92697"
        else:
            address_parts = [str(row['AddressNumber']), row['StreetName']]
            if pd.notna(row['Unit']):
                address_parts.append(f"Unit {row['Unit']}")
            if pd.notna(row['Building']):
                address_parts.append(f"Building {row['Building']}")
            address = f"{' '.join(address_parts)}, {row['City']}, {row['State']} {row['ZipCode']}"
        
        locations_mapping[str(idx)] = {
            'lat': row['X'],
            'lng': row['Y'],
            'address': address
        }
    
    # Save results
    np.save('distance_matrix.npy', distance_matrix)
    with open('locations_mapping.json', 'w') as f:
        json.dump(locations_mapping, f)
    
    print(f"\nFinal element count: {element_count}")
    print(f"Matrix filled: {np.count_nonzero(distance_matrix)} elements")
    return distance_matrix, locations_mapping

# %%
def load_cached_distances():
    """Load the cached distance matrix and location mapping"""
    try:
        distance_matrix = np.load('distance_matrix.npy')
        with open('locations_mapping.json', 'r') as f:
            locations_mapping = json.load(f)
        return distance_matrix, locations_mapping
    except:
        return None, None

# %%
# API key
# api_key = "NOPE"  # Replace with your actual API key

# Try to load cached data first
distance_matrix, locations_mapping = load_cached_distances()

# If no cached data exists, create new distance matrix
if distance_matrix is None:
    print("Creating new distance matrix...")
    distance_matrix, locations_mapping = create_distance_matrix(complete_df, api_key)
    print("Distance matrix created and cached.")
else:
    print("Loaded cached distance matrix.")

print(f"Distance matrix shape: {distance_matrix.shape}")
# Out:
# Creating new distance matrix...
#
# API Response for origin 0:
# Status: OK
# Distance from 0 to 1: 45.08 km
# Distance from 0 to 2: 21.78 km
# Distance from 0 to 3: 40.64 km
# Distance from 0 to 4: 16.48 km
# Distance from 0 to 5: 15.41 km
# Distance from 0 to 6: 24.22 km
# Distance from 0 to 7: 17.46 km
# Distance from 0 to 8: 11.14 km
# Distance from 0 to 9: 21.42 km
# Distance from 0 to 10: 22.88 km
# Distance from 0 to 11: 18.58 km
# Distance from 0 to 12: 30.81 km
# Distance from 0 to 13: 19.20 km
# Distance from 0 to 14: 8.57 km
# Distance from 0 to 15: 42.34 km
# Distance from 0 to 16: 22.18 km
# Distance from 0 to 17: 13.43 km
# Distance from 0 to 18: 36.75 km
# Distance from 0 to 19: 17.72 km
# Distance from 0 to 20: 30.72 km
# Distance from 0 to 21: 10.18 km
# Distance from 0 to 22: 6.10 km
# Distance from 0 to 23: 17.98 km
# Distance from 0 to 24: 32.37 km
# Distance from 0 to 25: 39.37 km
# Processed: origin 0, destinations 1-25. Elements: 25
#
# API Response for origin 0:
# Status: OK
# Distance from 0 to 26: 27.20 km
# Distance from 0 to 27: 20.22 km
# Distance from 0 to 28: 17.64 km
# Distance from 0 to 29: 29.94 km
# Distance from 0 to 30: 5.28 km
# Distance from 0 to 31: 23.23 km
# Distance from 0 to 32: 35.45 km
# Distance from 0 to 33: 8.98 km
# Distance from 0 to 34: 36.12 km
# Distance from 0 to 35: 21.64 km
# Distance from 0 to 36: 38.93 km
# Distance from 0 to 37: 38.71 km
# Distance from 0 to 38: 24.45 km
# Distance from 0 to 39: 7.83 km
# Distance from 0 to 40: 17.63 km
# Distance from 0 to 41: 26.33 km
# Distance from 0 to 42: 18.94 km
# Distance from 0 to 43: 28.54 km
# Distance from 0 to 44: 12.78 km
# Distance from 0 to 45: 9.71 km
# Distance from 0 to 46: 18.31 km
# Distance from 0 to 47: 28.37 km
# Distance from 0 to 48: 18.36 km
# Distance from 0 to 49: 14.67 km
# Distance from 0 to 50: 21.91 km
# Processed: origin 0, destinations 26-50. Elements: 50
#
# API Response for origin 0:
# Status: OK
# Distance from 0 to 51: 18.48 km
# Distance from 0 to 52: 20.93 km
# Distance from 0 to 53: 41.34 km
# Distance from 0 to 54: 29.47 km
# Distance from 0 to 55: 12.43 km
# Distance from 0 to 56: 15.54 km
# Distance from 0 to 57: 30.67 km
# Distance from 0 to 58: 31.94 km
# Distance from 0 to 59: 15.79 km
# Distance from 0 to 60: 15.94 km
# Distance from 0 to 61: 29.14 km
# Distance from 0 to 62: 37.87 km
# Distance from 0 to 63: 41.45 km
# Distance from 0 to 64: 26.89 km
# Distance from 0 to 65: 40.04 km
# Distance from 0 to 66: 19.09 km
# Distance from 0 to 67: 31.47 km
# Distance from 0 to 68: 10.49 km
# Distance from 0 to 69: 22.67 km
# Distance from 0 to 70: 23.24 km
# Distance from 0 to 71: 30.51 km
# Distance from 0 to 72: 24.29 km
# Distance from 0 to 73: 9.45 km
# Distance from 0 to 74: 10.73 km
# Distance from 0 to 75: 5.66 km
# Processed: origin 0, destinations 51-75. Elements: 75
#
# API Response for origin 0:
# Status: OK
# Distance from 0 to 76: 33.00 km
# Distance from 0 to 77: 41.65 km
# Distance from 0 to 78: 32.61 km
# Distance from 0 to 79: 18.79 km
# Distance from 0 to 80: 36.40 km
# Distance from 0 to 81: 26.42 km
# Distance from 0 to 82: 35.60 km
# Distance from 0 to 83: 19.08 km
# Distance from 0 to 84: 32.06 km
# Distance from 0 to 85: 35.32 km
# Distance from 0 to 86: 18.99 km
# Distance from 0 to 87: 23.74 km
# Distance from 0 to 88: 20.98 km
# Distance from 0 to 89: 8.34 km
# Distance from 0 to 90: 8.91 km
# Distance from 0 to 91: 39.83 km
# Distance from 0 to 92: 34.93 km
# Distance from 0 to 93: 34.25 km
# Distance from 0 to 94: 18.06 km
# Distance from 0 to 95: 4.38 km
# Distance from 0 to 96: 4.70 km
# Distance from 0 to 97: 24.78 km
# Distance from 0 to 98: 33.47 km
# Distance from 0 to 99: 16.25 km
# Distance from 0 to 100: 28.80 km
# Processed: origin 0, destinations 76-100. Elements: 100
#
# API Response for origin 0:
# Status: OK
# Distance from 0 to 101: 19.64 km
# Distance from 0 to 102: 10.66 km
# Distance from 0 to 103: 1.24 km
# Distance from 0 to 104: 33.50 km
# Distance from 0 to 105: 18.14 km
# Distance from 0 to 106: 10.40 km
# Distance from 0 to 107: 30.81 km
# Distance from 0 to 108: 4.61 km
# Distance from 0 to 109: 35.90 km
# Distance from 0 to 110: 19.85 km
# Distance from 0 to 111: 27.37 km
# Distance from 0 to 112: 3.05 km
# Distance from 0 to 113: 20.34 km
# Distance from 0 to 114: 40.91 km
# Distance from 0 to 115: 25.21 km
# Distance from 0 to 116: 39.34 km
# Distance from 0 to 117: 35.34 km
# Distance from 0 to 118: 20.09 km
# Distance from 0 to 119: 23.49 km
# Distance from 0 to 120: 18.48 km
# Distance from 0 to 121: 17.00 km
# Distance from 0 to 122: 16.98 km
# Distance from 0 to 123: 21.39 km
# Distance from 0 to 124: 11.90 km
# Distance from 0 to 125: 36.70 km
# Processed: origin 0, destinations 101-125. Elements: 125
#
# API Response for origin 0:
# Status: OK
# Distance from 0 to 126: 6.68 km
# Distance from 0 to 127: 30.41 km
# Distance from 0 to 128: 13.52 km
# Distance from 0 to 129: 38.64 km
# Distance from 0 to 130: 19.18 km
# Distance from 0 to 131: 6.68 km
# Distance from 0 to 132: 16.65 km
# Distance from 0 to 133: 39.00 km
# Distance from 0 to 134: 30.03 km
# Distance from 0 to 135: 24.49 km
# Distance from 0 to 136: 21.45 km
# Distance from 0 to 137: 35.18 km
# Distance from 0 to 138: 37.51 km
# Distance from 0 to 139: 14.01 km
# Distance from 0 to 140: 10.68 km
# Distance from 0 to 141: 15.62 km
# Distance from 0 to 142: 27.21 km
# Distance from 0 to 143: 26.16 km
# Distance from 0 to 144: 9.59 km
# Distance from 0 to 145: 39.61 km
# Distance from 0 to 146: 32.63 km
# Distance from 0 to 147: 36.90 km
# Distance from 0 to 148: 10.44 km
# Distance from 0 to 149: 27.95 km
# Distance from 0 to 150: 18.27 km
# Processed: origin 0, destinations 126-150. Elements: 150
#
# API Response for origin 0:
# Status: OK
# Distance from 0 to 151: 28.16 km
# Distance from 0 to 152: 45.77 km
# Distance from 0 to 153: 19.34 km
# Distance from 0 to 154: 26.20 km
# Distance from 0 to 155: 36.23 km
# Distance from 0 to 156: 18.74 km
# Distance from 0 to 157: 19.89 km
# Distance from 0 to 158: 15.66 km
# Distance from 0 to 159: 33.58 km
# Distance from 0 to 160: 19.44 km
# Distance from 0 to 161: 38.17 km
# Distance from 0 to 162: 17.71 km
# Distance from 0 to 163: 27.64 km
# Distance from 0 to 164: 19.62 km
# Distance from 0 to 165: 24.34 km
# Distance from 0 to 166: 8.14 km
# Distance from 0 to 167: 3.73 km
# Distance from 0 to 168: 18.23 km
# Distance from 0 to 169: 19.18 km
# Distance from 0 to 170: 19.13 km
# Distance from 0 to 171: 17.95 km
# Distance from 0 to 172: 28.31 km
# Distance from 0 to 173: 39.43 km
# Distance from 0 to 174: 24.75 km
# Distance from 0 to 175: 6.46 km
# Processed: origin 0, destinations 151-175. Elements: 175
#
# API Response for origin 0:
# Status: OK
# Distance from 0 to 176: 4.48 km
# Distance from 0 to 177: 10.46 km
# Distance from 0 to 178: 13.50 km
# Distance from 0 to 179: 12.56 km
# Distance from 0 to 180: 21.67 km
# Distance from 0 to 181: 12.75 km
# Distance from 0 to 182: 35.35 km
# Distance from 0 to 183: 34.45 km
# Distance from 0 to 184: 3.22 km
# Distance from 0 to 185: 13.23 km
# Distance from 0 to 186: 44.63 km
# Distance from 0 to 187: 32.00 km
# Distance from 0 to 188: 33.39 km
# Distance from 0 to 189: 34.79 km
# Distance from 0 to 190: 10.94 km
# Distance from 0 to 191: 36.08 km
# Distance from 0 to 192: 31.64 km
# Distance from 0 to 193: 7.69 km
# Distance from 0 to 194: 25.29 km
# Distance from 0 to 195: 32.47 km
# Distance from 0 to 196: 35.96 km
# Distance from 0 to 197: 38.81 km
# Distance from 0 to 198: 26.48 km
# Distance from 0 to 199: 35.73 km
# Distance from 0 to 200: 19.29 km
# Processed: origin 0, destinations 176-200. Elements: 200
#
# API Response for origin 1:
# Status: OK
# Distance from 1 to 2: 47.12 km
# Distance from 1 to 3: 16.82 km
# Distance from 1 to 4: 44.16 km
# Distance from 1 to 5: 54.50 km
# Distance from 1 to 6: 33.53 km
# Distance from 1 to 7: 45.50 km
# Distance from 1 to 8: 33.26 km
# Distance from 1 to 9: 49.47 km
# Distance from 1 to 10: 26.44 km
# Distance from 1 to 11: 57.67 km
# Distance from 1 to 12: 59.78 km
# Distance from 1 to 13: 40.17 km
# Distance from 1 to 14: 35.18 km
# Distance from 1 to 15: 74.73 km
# Distance from 1 to 16: 54.38 km
# Distance from 1 to 17: 43.22 km
# Distance from 1 to 18: 14.65 km
# Distance from 1 to 19: 45.78 km
# Distance from 1 to 20: 19.99 km
# Distance from 1 to 21: 42.66 km
# Distance from 1 to 22: 37.41 km
# Distance from 1 to 23: 31.73 km
# Distance from 1 to 24: 15.29 km
# Distance from 1 to 25: 7.83 km
# Distance from 1 to 26: 18.08 km
# Processed: origin 1, destinations 2-26. Elements: 225
#
# API Response for origin 1:
# Status: OK
# Distance from 1 to 27: 33.36 km
# Distance from 1 to 28: 26.41 km
# Distance from 1 to 29: 16.07 km
# Distance from 1 to 30: 38.06 km
# Distance from 1 to 31: 51.24 km
# Distance from 1 to 32: 46.00 km
# Distance from 1 to 33: 44.44 km
# Distance from 1 to 34: 24.69 km
# Distance from 1 to 35: 33.62 km
# Distance from 1 to 36: 29.35 km
# Distance from 1 to 37: 10.23 km
# Distance from 1 to 38: 19.82 km
# Distance from 1 to 39: 38.94 km
# Distance from 1 to 40: 45.68 km
# Distance from 1 to 41: 21.08 km
# Distance from 1 to 42: 53.96 km
# Distance from 1 to 43: 26.80 km
# Distance from 1 to 44: 41.70 km
# Distance from 1 to 45: 39.03 km
# Distance from 1 to 46: 33.42 km
# Distance from 1 to 47: 59.45 km
# Distance from 1 to 48: 53.98 km
# Distance from 1 to 49: 27.53 km
# Distance from 1 to 50: 35.48 km
# Distance from 1 to 51: 28.70 km
# Processed: origin 1, destinations 27-51. Elements: 250
#
# API Response for origin 1:
# Status: OK
# Distance from 1 to 52: 56.70 km
# Distance from 1 to 53: 8.02 km
# Distance from 1 to 54: 60.55 km
# Distance from 1 to 55: 42.00 km
# Distance from 1 to 56: 44.46 km
# Distance from 1 to 57: 20.82 km
# Distance from 1 to 58: 27.16 km
# Distance from 1 to 59: 35.35 km
# Distance from 1 to 60: 26.78 km
# Distance from 1 to 61: 63.10 km
# Distance from 1 to 62: 9.62 km
# Distance from 1 to 63: 5.21 km
# Distance from 1 to 64: 53.76 km
# Distance from 1 to 65: 14.73 km
# Distance from 1 to 66: 27.71 km
# Distance from 1 to 67: 14.58 km
# Distance from 1 to 68: 49.58 km
# Distance from 1 to 69: 34.08 km
# Distance from 1 to 70: 46.70 km
# Distance from 1 to 71: 41.06 km
# Distance from 1 to 72: 51.49 km
# Distance from 1 to 73: 36.64 km
# Distance from 1 to 74: 38.45 km
# Distance from 1 to 75: 38.44 km
# Distance from 1 to 76: 67.14 km
# Processed: origin 1, destinations 52-76. Elements: 275
#
# API Response for origin 1:
# Status: OK
# Distance from 1 to 77: 74.05 km
# Distance from 1 to 78: 56.07 km
# Distance from 1 to 79: 25.32 km
# Distance from 1 to 80: 71.85 km
# Distance from 1 to 81: 60.75 km
# Distance from 1 to 82: 11.05 km
# Distance from 1 to 83: 48.00 km
# Distance from 1 to 84: 64.46 km
# Distance from 1 to 85: 12.86 km
# Distance from 1 to 86: 26.83 km
# Distance from 1 to 87: 33.79 km
# Distance from 1 to 88: 49.04 km
# Distance from 1 to 89: 36.65 km
# Distance from 1 to 90: 35.27 km
# Distance from 1 to 91: 16.02 km
# Distance from 1 to 92: 20.06 km
# Distance from 1 to 93: 66.65 km
# Distance from 1 to 94: 38.13 km
# Distance from 1 to 95: 40.98 km
# Distance from 1 to 96: 38.69 km
# Distance from 1 to 97: 58.37 km
# Distance from 1 to 98: 16.82 km
# Distance from 1 to 99: 43.97 km
# Distance from 1 to 100: 55.49 km
# Distance from 1 to 101: 40.26 km
# Processed: origin 1, destinations 77-101. Elements: 300
#
# API Response for origin 1:
# Status: OK
# Distance from 1 to 102: 37.34 km
# Distance from 1 to 103: 44.09 km
# Distance from 1 to 104: 15.14 km
# Distance from 1 to 105: 31.42 km
# Distance from 1 to 106: 35.70 km
# Distance from 1 to 107: 41.36 km
# Distance from 1 to 108: 41.07 km
# Distance from 1 to 109: 68.30 km
# Distance from 1 to 110: 43.31 km
# Distance from 1 to 111: 23.34 km
# Distance from 1 to 112: 40.87 km
# Distance from 1 to 113: 27.69 km
# Distance from 1 to 114: 5.94 km
# Distance from 1 to 115: 21.55 km
# Distance from 1 to 116: 71.74 km
# Distance from 1 to 117: 10.26 km
# Distance from 1 to 118: 27.82 km
# Distance from 1 to 119: 29.95 km
# Distance from 1 to 120: 45.33 km
# Distance from 1 to 121: 25.77 km
# Distance from 1 to 122: 27.26 km
# Distance from 1 to 123: 32.80 km
# Distance from 1 to 124: 29.01 km
# Distance from 1 to 125: 10.20 km
# Distance from 1 to 126: 38.03 km
# Processed: origin 1, destinations 102-126. Elements: 325
#
# API Response for origin 1:
# Status: OK
# Distance from 1 to 127: 60.79 km
# Distance from 1 to 128: 42.44 km
# Distance from 1 to 129: 8.49 km
# Distance from 1 to 130: 29.95 km
# Distance from 1 to 131: 37.82 km
# Distance from 1 to 132: 30.46 km
# Distance from 1 to 133: 62.46 km
# Distance from 1 to 134: 63.99 km
# Distance from 1 to 135: 34.65 km
# Distance from 1 to 136: 32.86 km
# Distance from 1 to 137: 11.09 km
# Distance from 1 to 138: 9.60 km
# Distance from 1 to 139: 42.93 km
# Distance from 1 to 140: 35.97 km
# Distance from 1 to 141: 34.89 km
# Distance from 1 to 142: 58.29 km
# Distance from 1 to 143: 54.98 km
# Distance from 1 to 144: 40.01 km
# Distance from 1 to 145: 8.52 km
# Distance from 1 to 146: 16.96 km
# Distance from 1 to 147: 8.20 km
# Distance from 1 to 148: 43.09 km
# Distance from 1 to 149: 54.64 km
# Distance from 1 to 150: 33.49 km
# Distance from 1 to 151: 22.06 km
# Processed: origin 1, destinations 127-151. Elements: 350
#
# API Response for origin 1:
# Status: OK
# Distance from 1 to 152: 4.57 km
# Distance from 1 to 153: 25.14 km
# Distance from 1 to 154: 55.02 km
# Distance from 1 to 155: 9.24 km
# Distance from 1 to 156: 26.32 km
# Distance from 1 to 157: 24.52 km
# Distance from 1 to 158: 28.46 km
# Distance from 1 to 159: 18.80 km
# Distance from 1 to 160: 54.52 km
# Distance from 1 to 161: 7.69 km
# Distance from 1 to 162: 26.33 km
# Distance from 1 to 163: 58.89 km
# Distance from 1 to 164: 44.20 km
# Distance from 1 to 165: 34.67 km
# Distance from 1 to 166: 35.90 km
# Distance from 1 to 167: 42.20 km
# Distance from 1 to 168: 40.28 km
# Distance from 1 to 169: 43.30 km
# Distance from 1 to 170: 32.24 km
# Distance from 1 to 171: 28.55 km
# Distance from 1 to 172: 57.28 km
# Distance from 1 to 173: 8.32 km
# Distance from 1 to 174: 34.10 km
# Distance from 1 to 175: 46.03 km
# Distance from 1 to 176: 38.24 km
# Processed: origin 1, destinations 152-176. Elements: 375
#
# API Response for origin 1:
# Status: OK
# Distance from 1 to 177: 37.75 km
# Distance from 1 to 178: 29.28 km
# Distance from 1 to 179: 30.60 km
# Distance from 1 to 180: 33.75 km
# Distance from 1 to 181: 40.47 km
# Distance from 1 to 182: 13.05 km
# Distance from 1 to 183: 57.91 km
# Distance from 1 to 184: 41.73 km
# Distance from 1 to 185: 40.95 km
# Distance from 1 to 186: 11.69 km
# Distance from 1 to 187: 14.45 km
# Distance from 1 to 188: 67.54 km
# Distance from 1 to 189: 13.52 km
# Distance from 1 to 190: 34.61 km
# Distance from 1 to 191: 17.65 km
# Distance from 1 to 192: 55.10 km
# Distance from 1 to 193: 35.11 km
# Distance from 1 to 194: 54.11 km
# Distance from 1 to 195: 15.55 km
# Distance from 1 to 196: 69.22 km
# Distance from 1 to 197: 5.80 km
# Distance from 1 to 198: 49.95 km
# Distance from 1 to 199: 24.42 km
# Distance from 1 to 200: 50.70 km
# Processed: origin 1, destinations 177-200. Elements: 399
#
# API Response for origin 2:
# Status: OK
# Distance from 2 to 3: 45.71 km
# Distance from 2 to 4: 30.27 km
# Distance from 2 to 5: 6.21 km
# Distance from 2 to 6: 40.33 km
# Distance from 2 to 7: 3.80 km
# Distance from 2 to 8: 15.62 km
# Distance from 2 to 9: 6.59 km
# Distance from 2 to 10: 27.37 km
# Distance from 2 to 11: 8.66 km
# Distance from 2 to 12: 16.18 km
# Distance from 2 to 13: 13.78 km
# Distance from 2 to 14: 17.97 km
# Distance from 2 to 15: 31.28 km
# Distance from 2 to 16: 7.04 km
# Distance from 2 to 17: 9.00 km
# Distance from 2 to 18: 46.89 km
# Distance from 2 to 19: 4.33 km
# Distance from 2 to 20: 44.56 km
# Distance from 2 to 21: 28.83 km
# Distance from 2 to 22: 17.48 km
# Distance from 2 to 23: 19.66 km
# Distance from 2 to 24: 36.90 km
# Distance from 2 to 25: 38.49 km
# Distance from 2 to 26: 42.26 km
# Distance from 2 to 27: 34.06 km
# Processed: origin 2, destinations 3-27. Elements: 424
#
# API Response for origin 2:
# Status: OK
# Distance from 2 to 28: 22.70 km
# Distance from 2 to 29: 34.48 km
# Distance from 2 to 30: 18.81 km
# Distance from 2 to 31: 6.52 km
# Distance from 2 to 32: 49.30 km
# Distance from 2 to 33: 30.61 km
# Distance from 2 to 34: 49.96 km
# Distance from 2 to 35: 35.48 km
# Distance from 2 to 36: 40.43 km
# Distance from 2 to 37: 43.77 km
# Distance from 2 to 38: 39.51 km
# Distance from 2 to 39: 17.01 km
# Distance from 2 to 40: 4.08 km
# Distance from 2 to 41: 32.80 km
# Distance from 2 to 42: 6.59 km
# Distance from 2 to 43: 33.61 km
# Distance from 2 to 44: 27.87 km
# Distance from 2 to 45: 13.83 km
# Distance from 2 to 46: 32.14 km
# Distance from 2 to 47: 16.00 km
# Distance from 2 to 48: 7.83 km
# Distance from 2 to 49: 26.56 km
# Distance from 2 to 50: 35.75 km
# Distance from 2 to 51: 32.31 km
# Distance from 2 to 52: 8.12 km
# Processed: origin 2, destinations 28-52. Elements: 449
#
# API Response for origin 2:
# Status: OK
# Distance from 2 to 53: 46.41 km
# Distance from 2 to 54: 17.10 km
# Distance from 2 to 55: 11.08 km
# Distance from 2 to 56: 30.64 km
# Distance from 2 to 57: 44.52 km
# Distance from 2 to 58: 36.11 km
# Distance from 2 to 59: 17.14 km
# Distance from 2 to 60: 24.36 km
# Distance from 2 to 61: 16.96 km
# Distance from 2 to 62: 42.93 km
# Distance from 2 to 63: 46.51 km
# Distance from 2 to 64: 6.88 km
# Distance from 2 to 65: 45.10 km
# Distance from 2 to 66: 21.23 km
# Distance from 2 to 67: 37.95 km
# Distance from 2 to 68: 20.91 km
# Distance from 2 to 69: 21.35 km
# Distance from 2 to 70: 12.54 km
# Distance from 2 to 71: 44.35 km
# Distance from 2 to 72: 4.28 km
# Distance from 2 to 73: 23.91 km
# Distance from 2 to 74: 24.57 km
# Distance from 2 to 75: 17.96 km
# Distance from 2 to 76: 18.37 km
# Distance from 2 to 77: 30.60 km
# Processed: origin 2, destinations 53-77. Elements: 474
#
# API Response for origin 2:
# Status: OK
# Distance from 2 to 78: 12.88 km
# Distance from 2 to 79: 23.86 km
# Distance from 2 to 80: 23.11 km
# Distance from 2 to 81: 17.30 km
# Distance from 2 to 82: 40.13 km
# Distance from 2 to 83: 34.18 km
# Distance from 2 to 84: 21.01 km
# Distance from 2 to 85: 49.12 km
# Distance from 2 to 86: 26.93 km
# Distance from 2 to 87: 37.59 km
# Distance from 2 to 88: 11.91 km
# Distance from 2 to 89: 17.52 km
# Distance from 2 to 90: 18.73 km
# Distance from 2 to 91: 44.90 km
# Distance from 2 to 92: 41.94 km
# Distance from 2 to 93: 23.20 km
# Distance from 2 to 94: 31.88 km
# Distance from 2 to 95: 17.56 km
# Distance from 2 to 96: 19.44 km
# Distance from 2 to 97: 12.03 km
# Distance from 2 to 98: 45.70 km
# Distance from 2 to 99: 30.08 km
# Distance from 2 to 100: 12.04 km
# Distance from 2 to 101: 33.46 km
# Distance from 2 to 102: 14.77 km
# Processed: origin 2, destinations 78-102. Elements: 499
#
# API Response for origin 2:
# Status: OK
# Distance from 2 to 103: 21.21 km
# Distance from 2 to 104: 45.86 km
# Distance from 2 to 105: 31.97 km
# Distance from 2 to 106: 16.18 km
# Distance from 2 to 107: 44.65 km
# Distance from 2 to 108: 22.60 km
# Distance from 2 to 109: 24.85 km
# Distance from 2 to 110: 15.96 km
# Distance from 2 to 111: 32.43 km
# Distance from 2 to 112: 19.59 km
# Distance from 2 to 113: 34.49 km
# Distance from 2 to 114: 45.44 km
# Distance from 2 to 115: 31.68 km
# Distance from 2 to 116: 28.29 km
# Distance from 2 to 117: 40.41 km
# Distance from 2 to 118: 21.01 km
# Distance from 2 to 119: 26.31 km
# Distance from 2 to 120: 9.41 km
# Distance from 2 to 121: 22.06 km
# Distance from 2 to 122: 30.81 km
# Distance from 2 to 123: 17.66 km
# Distance from 2 to 124: 27.09 km
# Distance from 2 to 125: 41.76 km
# Distance from 2 to 126: 24.21 km
# Distance from 2 to 127: 15.78 km
# Processed: origin 2, destinations 103-127. Elements: 524
#
# API Response for origin 2:
# Status: OK
# Distance from 2 to 128: 28.61 km
# Distance from 2 to 129: 43.17 km
# Distance from 2 to 130: 33.01 km
# Distance from 2 to 131: 17.25 km
# Distance from 2 to 132: 20.27 km
# Distance from 2 to 133: 17.77 km
# Distance from 2 to 134: 17.85 km
# Distance from 2 to 135: 38.33 km
# Distance from 2 to 136: 17.72 km
# Distance from 2 to 137: 44.50 km
# Distance from 2 to 138: 42.05 km
# Distance from 2 to 139: 29.11 km
# Distance from 2 to 140: 15.87 km
# Distance from 2 to 141: 16.68 km
# Distance from 2 to 142: 14.84 km
# Distance from 2 to 143: 11.52 km
# Distance from 2 to 144: 13.71 km
# Distance from 2 to 145: 44.14 km
# Distance from 2 to 146: 45.84 km
# Distance from 2 to 147: 41.47 km
# Distance from 2 to 148: 12.23 km
# Distance from 2 to 149: 9.67 km
# Distance from 2 to 150: 32.10 km
# Distance from 2 to 151: 42.00 km
# Distance from 2 to 152: 50.83 km
# Processed: origin 2, destinations 128-152. Elements: 549
#
# API Response for origin 2:
# Status: OK
# Distance from 2 to 153: 24.40 km
# Distance from 2 to 154: 11.57 km
# Distance from 2 to 155: 40.76 km
# Distance from 2 to 156: 25.04 km
# Distance from 2 to 157: 24.95 km
# Distance from 2 to 158: 22.76 km
# Distance from 2 to 159: 47.68 km
# Distance from 2 to 160: 8.38 km
# Distance from 2 to 161: 39.66 km
# Distance from 2 to 162: 22.77 km
# Distance from 2 to 163: 10.55 km
# Distance from 2 to 164: 33.88 km
# Distance from 2 to 165: 38.18 km
# Distance from 2 to 166: 19.46 km
# Distance from 2 to 167: 18.79 km
# Distance from 2 to 168: 32.06 km
# Distance from 2 to 169: 32.97 km
# Distance from 2 to 170: 32.96 km
# Distance from 2 to 171: 35.35 km
# Distance from 2 to 172: 11.44 km
# Distance from 2 to 173: 44.49 km
# Distance from 2 to 174: 38.59 km
# Distance from 2 to 175: 20.12 km
# Distance from 2 to 176: 18.98 km
# Distance from 2 to 177: 23.86 km
# Processed: origin 2, destinations 153-177. Elements: 574
#
# API Response for origin 2:
# Status: OK
# Distance from 2 to 178: 27.29 km
# Distance from 2 to 179: 26.36 km
# Distance from 2 to 180: 35.51 km
# Distance from 2 to 181: 26.59 km
# Distance from 2 to 182: 40.41 km
# Distance from 2 to 183: 13.76 km
# Distance from 2 to 184: 18.31 km
# Distance from 2 to 185: 27.06 km
# Distance from 2 to 186: 49.16 km
# Distance from 2 to 187: 37.06 km
# Distance from 2 to 188: 18.76 km
# Distance from 2 to 189: 48.56 km
# Distance from 2 to 190: 20.19 km
# Distance from 2 to 191: 43.09 km
# Distance from 2 to 192: 9.79 km
# Distance from 2 to 193: 19.19 km
# Distance from 2 to 194: 10.66 km
# Distance from 2 to 195: 38.94 km
# Distance from 2 to 196: 20.48 km
# Distance from 2 to 197: 43.88 km
# Distance from 2 to 198: 12.48 km
# Distance from 2 to 199: 49.57 km
# Distance from 2 to 200: 4.66 km
# Processed: origin 2, destinations 178-200. Elements: 597
#
# API Response for origin 3:
# Status: OK
# Distance from 3 to 4: 24.20 km
# Distance from 3 to 5: 52.21 km
# Distance from 3 to 6: 11.61 km
# Distance from 3 to 7: 43.21 km
# Distance from 3 to 8: 30.97 km
# Distance from 3 to 9: 47.18 km
# Distance from 3 to 10: 24.14 km
# Distance from 3 to 11: 55.38 km
# Distance from 3 to 12: 57.49 km
# Distance from 3 to 13: 37.88 km
# Distance from 3 to 14: 32.89 km
# Distance from 3 to 15: 72.44 km
# Distance from 3 to 16: 52.09 km
# Distance from 3 to 17: 40.93 km
# Distance from 3 to 18: 29.45 km
# Distance from 3 to 19: 43.48 km
# Distance from 3 to 20: 5.63 km
# Distance from 3 to 21: 40.37 km
# Distance from 3 to 22: 35.12 km
# Distance from 3 to 23: 29.44 km
# Distance from 3 to 24: 15.39 km
# Distance from 3 to 25: 10.09 km
# Distance from 3 to 26: 8.13 km
# Distance from 3 to 27: 17.62 km
# Distance from 3 to 28: 24.11 km
# Processed: origin 3, destinations 4-28. Elements: 622
#
# API Response for origin 3:
# Status: OK
# Distance from 3 to 29: 18.58 km
# Distance from 3 to 30: 35.77 km
# Distance from 3 to 31: 48.95 km
# Distance from 3 to 32: 22.81 km
# Distance from 3 to 33: 42.15 km
# Distance from 3 to 34: 6.66 km
# Distance from 3 to 35: 13.73 km
# Distance from 3 to 36: 31.63 km
# Distance from 3 to 37: 5.58 km
# Distance from 3 to 38: 10.85 km
# Distance from 3 to 39: 36.64 km
# Distance from 3 to 40: 43.39 km
# Distance from 3 to 41: 23.58 km
# Distance from 3 to 42: 51.67 km
# Distance from 3 to 43: 24.43 km
# Distance from 3 to 44: 39.41 km
# Distance from 3 to 45: 36.74 km
# Distance from 3 to 46: 20.00 km
# Distance from 3 to 47: 57.16 km
# Distance from 3 to 48: 51.69 km
# Distance from 3 to 49: 25.24 km
# Distance from 3 to 50: 14.37 km
# Distance from 3 to 51: 26.32 km
# Distance from 3 to 52: 54.41 km
# Distance from 3 to 53: 9.24 km
# Processed: origin 3, destinations 29-53. Elements: 647
#
# API Response for origin 3:
# Status: OK
# Distance from 3 to 54: 58.26 km
# Distance from 3 to 55: 39.71 km
# Distance from 3 to 56: 42.17 km
# Distance from 3 to 57: 5.94 km
# Distance from 3 to 58: 29.44 km
# Distance from 3 to 59: 33.06 km
# Distance from 3 to 60: 24.48 km
# Distance from 3 to 61: 60.81 km
# Distance from 3 to 62: 6.84 km
# Distance from 3 to 63: 13.00 km
# Distance from 3 to 64: 51.47 km
# Distance from 3 to 65: 5.41 km
# Distance from 3 to 66: 25.42 km
# Distance from 3 to 67: 22.02 km
# Distance from 3 to 68: 47.29 km
# Distance from 3 to 69: 31.79 km
# Distance from 3 to 70: 44.41 km
# Distance from 3 to 71: 11.89 km
# Distance from 3 to 72: 49.20 km
# Distance from 3 to 73: 34.35 km
# Distance from 3 to 74: 36.16 km
# Distance from 3 to 75: 36.15 km
# Distance from 3 to 76: 64.85 km
# Distance from 3 to 77: 71.76 km
# Distance from 3 to 78: 53.78 km
# Processed: origin 3, destinations 54-78. Elements: 672
#
# API Response for origin 3:
# Status: OK
# Distance from 3 to 79: 23.03 km
# Distance from 3 to 80: 69.56 km
# Distance from 3 to 81: 58.46 km
# Distance from 3 to 82: 18.83 km
# Distance from 3 to 83: 24.77 km
# Distance from 3 to 84: 62.17 km
# Distance from 3 to 85: 24.98 km
# Distance from 3 to 86: 24.52 km
# Distance from 3 to 87: 11.21 km
# Distance from 3 to 88: 46.74 km
# Distance from 3 to 89: 34.35 km
# Distance from 3 to 90: 32.98 km
# Distance from 3 to 91: 1.32 km
# Distance from 3 to 92: 27.64 km
# Distance from 3 to 93: 64.36 km
# Distance from 3 to 94: 21.50 km
# Distance from 3 to 95: 38.68 km
# Distance from 3 to 96: 36.40 km
# Distance from 3 to 97: 56.07 km
# Distance from 3 to 98: 1.67 km
# Distance from 3 to 99: 21.97 km
# Distance from 3 to 100: 53.20 km
# Distance from 3 to 101: 23.63 km
# Distance from 3 to 102: 35.04 km
# Distance from 3 to 103: 41.80 km
# Processed: origin 3, destinations 79-103. Elements: 697
#
# API Response for origin 3:
# Status: OK
# Distance from 3 to 104: 3.71 km
# Distance from 3 to 105: 29.04 km
# Distance from 3 to 106: 33.40 km
# Distance from 3 to 107: 12.02 km
# Distance from 3 to 108: 38.78 km
# Distance from 3 to 109: 66.01 km
# Distance from 3 to 110: 41.02 km
# Distance from 3 to 111: 15.41 km
# Distance from 3 to 112: 38.58 km
# Distance from 3 to 113: 25.31 km
# Distance from 3 to 114: 17.36 km
# Distance from 3 to 115: 24.34 km
# Distance from 3 to 116: 69.45 km
# Distance from 3 to 117: 6.90 km
# Distance from 3 to 118: 25.53 km
# Distance from 3 to 119: 27.65 km
# Distance from 3 to 120: 43.03 km
# Distance from 3 to 121: 23.48 km
# Distance from 3 to 122: 24.89 km
# Distance from 3 to 123: 30.51 km
# Distance from 3 to 124: 33.90 km
# Distance from 3 to 125: 5.67 km
# Distance from 3 to 126: 35.74 km
# Distance from 3 to 127: 58.50 km
# Distance from 3 to 128: 40.15 km
# Processed: origin 3, destinations 104-128. Elements: 722
#
# API Response for origin 3:
# Status: OK
# Distance from 3 to 129: 21.87 km
# Distance from 3 to 130: 27.58 km
# Distance from 3 to 131: 35.53 km
# Distance from 3 to 132: 28.17 km
# Distance from 3 to 133: 60.17 km
# Distance from 3 to 134: 61.70 km
# Distance from 3 to 135: 12.33 km
# Distance from 3 to 136: 30.57 km
# Distance from 3 to 137: 23.20 km
# Distance from 3 to 138: 20.75 km
# Distance from 3 to 139: 40.64 km
# Distance from 3 to 140: 33.67 km
# Distance from 3 to 141: 32.60 km
# Distance from 3 to 142: 56.00 km
# Distance from 3 to 143: 52.69 km
# Distance from 3 to 144: 37.72 km
# Distance from 3 to 145: 22.84 km
# Distance from 3 to 146: 3.69 km
# Distance from 3 to 147: 12.44 km
# Distance from 3 to 148: 40.80 km
# Distance from 3 to 149: 52.35 km
# Distance from 3 to 150: 19.96 km
# Distance from 3 to 151: 7.16 km
# Distance from 3 to 152: 13.67 km
# Distance from 3 to 153: 23.28 km
# Processed: origin 3, destinations 129-153. Elements: 747
#
# API Response for origin 3:
# Status: OK
# Distance from 3 to 154: 52.73 km
# Distance from 3 to 155: 19.47 km
# Distance from 3 to 156: 24.02 km
# Distance from 3 to 157: 22.23 km
# Distance from 3 to 158: 26.17 km
# Distance from 3 to 159: 1.98 km
# Distance from 3 to 160: 52.23 km
# Distance from 3 to 161: 11.26 km
# Distance from 3 to 162: 24.04 km
# Distance from 3 to 163: 56.60 km
# Distance from 3 to 164: 24.16 km
# Distance from 3 to 165: 13.19 km
# Distance from 3 to 166: 33.61 km
# Distance from 3 to 167: 39.91 km
# Distance from 3 to 168: 21.72 km
# Distance from 3 to 169: 23.26 km
# Distance from 3 to 170: 16.41 km
# Distance from 3 to 171: 26.17 km
# Distance from 3 to 172: 54.99 km
# Distance from 3 to 173: 8.40 km
# Distance from 3 to 174: 11.41 km
# Distance from 3 to 175: 43.74 km
# Distance from 3 to 176: 35.95 km
# Distance from 3 to 177: 35.46 km
# Distance from 3 to 178: 28.81 km
# Processed: origin 3, destinations 154-178. Elements: 772
#
# API Response for origin 3:
# Status: OK
# Distance from 3 to 179: 28.23 km
# Distance from 3 to 180: 13.86 km
# Distance from 3 to 181: 25.95 km
# Distance from 3 to 182: 5.40 km
# Distance from 3 to 183: 55.62 km
# Distance from 3 to 184: 39.44 km
# Distance from 3 to 185: 23.40 km
# Distance from 3 to 186: 27.86 km
# Distance from 3 to 187: 12.09 km
# Distance from 3 to 188: 65.25 km
# Distance from 3 to 189: 25.33 km
# Distance from 3 to 190: 32.32 km
# Distance from 3 to 191: 28.79 km
# Distance from 3 to 192: 52.81 km
# Distance from 3 to 193: 32.82 km
# Distance from 3 to 194: 51.82 km
# Distance from 3 to 195: 22.43 km
# Distance from 3 to 196: 66.93 km
# Distance from 3 to 197: 10.37 km
# Distance from 3 to 198: 47.65 km
# Distance from 3 to 199: 7.58 km
# Distance from 3 to 200: 48.41 km
# Processed: origin 3, destinations 179-200. Elements: 794
#
# API Response for origin 4:
# Status: OK
# Distance from 4 to 5: 28.15 km
# Distance from 4 to 6: 15.21 km
# Distance from 4 to 7: 28.00 km
# Distance from 4 to 8: 23.71 km
# Distance from 4 to 9: 31.95 km
# Distance from 4 to 10: 24.74 km
# Distance from 4 to 11: 31.32 km
# Distance from 4 to 12: 42.15 km
# Distance from 4 to 13: 29.73 km
# Distance from 4 to 14: 17.38 km
# Distance from 4 to 15: 55.07 km
# Distance from 4 to 16: 32.72 km
# Distance from 4 to 17: 23.97 km
# Distance from 4 to 18: 38.61 km
# Distance from 4 to 19: 28.26 km
# Distance from 4 to 20: 21.71 km
# Distance from 4 to 21: 10.09 km
# Distance from 4 to 22: 13.93 km
# Distance from 4 to 23: 19.84 km
# Distance from 4 to 24: 34.23 km
# Distance from 4 to 25: 41.23 km
# Distance from 4 to 26: 18.19 km
# Distance from 4 to 27: 9.00 km
# Distance from 4 to 28: 19.50 km
# Distance from 4 to 29: 31.80 km
# Processed: origin 4, destinations 5-29. Elements: 819
#
# API Response for origin 4:
# Status: OK
# Distance from 4 to 30: 14.58 km
# Distance from 4 to 31: 33.77 km
# Distance from 4 to 32: 14.59 km
# Distance from 4 to 33: 10.66 km
# Distance from 4 to 34: 27.11 km
# Distance from 4 to 35: 12.63 km
# Distance from 4 to 36: 40.79 km
# Distance from 4 to 37: 40.57 km
# Distance from 4 to 38: 15.43 km
# Distance from 4 to 39: 17.64 km
# Distance from 4 to 40: 28.16 km
# Distance from 4 to 41: 28.19 km
# Distance from 4 to 42: 31.68 km
# Distance from 4 to 43: 13.57 km
# Distance from 4 to 44: 7.88 km
# Distance from 4 to 45: 20.34 km
# Distance from 4 to 46: 8.00 km
# Distance from 4 to 47: 41.98 km
# Distance from 4 to 48: 31.09 km
# Distance from 4 to 49: 14.71 km
# Distance from 4 to 50: 12.89 km
# Distance from 4 to 51: 11.23 km
# Distance from 4 to 52: 33.66 km
# Distance from 4 to 53: 43.20 km
# Distance from 4 to 54: 43.07 km
# Processed: origin 4, destinations 30-54. Elements: 844
#
# API Response for origin 4:
# Status: OK
# Distance from 4 to 55: 22.97 km
# Distance from 4 to 56: 9.62 km
# Distance from 4 to 57: 21.66 km
# Distance from 4 to 58: 33.80 km
# Distance from 4 to 59: 25.80 km
# Distance from 4 to 60: 17.80 km
# Distance from 4 to 61: 41.88 km
# Distance from 4 to 62: 39.73 km
# Distance from 4 to 63: 43.31 km
# Distance from 4 to 64: 36.28 km
# Distance from 4 to 65: 21.32 km
# Distance from 4 to 66: 20.95 km
# Distance from 4 to 67: 33.33 km
# Distance from 4 to 68: 23.23 km
# Distance from 4 to 69: 24.53 km
# Distance from 4 to 70: 33.78 km
# Distance from 4 to 71: 21.50 km
# Distance from 4 to 72: 34.02 km
# Distance from 4 to 73: 9.67 km
# Distance from 4 to 74: 7.58 km
# Distance from 4 to 75: 14.96 km
# Distance from 4 to 76: 44.34 km
# Distance from 4 to 77: 54.39 km
# Distance from 4 to 78: 43.15 km
# Distance from 4 to 79: 20.66 km
# Processed: origin 4, destinations 55-79. Elements: 869
#
# API Response for origin 4:
# Status: OK
# Distance from 4 to 80: 49.14 km
# Distance from 4 to 81: 39.16 km
# Distance from 4 to 82: 37.46 km
# Distance from 4 to 83: 4.80 km
# Distance from 4 to 84: 44.80 km
# Distance from 4 to 85: 37.18 km
# Distance from 4 to 86: 20.85 km
# Distance from 4 to 87: 14.73 km
# Distance from 4 to 88: 31.52 km
# Distance from 4 to 89: 18.14 km
# Distance from 4 to 90: 18.13 km
# Distance from 4 to 91: 25.40 km
# Distance from 4 to 92: 36.80 km
# Distance from 4 to 93: 46.99 km
# Distance from 4 to 94: 4.04 km
# Distance from 4 to 95: 16.93 km
# Distance from 4 to 96: 13.76 km
# Distance from 4 to 97: 37.51 km
# Distance from 4 to 98: 24.46 km
# Distance from 4 to 99: 4.11 km
# Distance from 4 to 100: 38.01 km
# Distance from 4 to 101: 2.34 km
# Distance from 4 to 102: 21.29 km
# Distance from 4 to 103: 17.74 km
# Distance from 4 to 104: 24.49 km
# Processed: origin 4, destinations 80-104. Elements: 894
#
# API Response for origin 4:
# Status: OK
# Distance from 4 to 105: 8.64 km
# Distance from 4 to 106: 20.21 km
# Distance from 4 to 107: 21.80 km
# Distance from 4 to 108: 14.72 km
# Distance from 4 to 109: 48.64 km
# Distance from 4 to 110: 30.39 km
# Distance from 4 to 111: 17.49 km
# Distance from 4 to 112: 14.53 km
# Distance from 4 to 113: 13.09 km
# Distance from 4 to 114: 42.77 km
# Distance from 4 to 115: 27.07 km
# Distance from 4 to 116: 52.08 km
# Distance from 4 to 117: 37.21 km
# Distance from 4 to 118: 21.95 km
# Distance from 4 to 119: 25.35 km
# Distance from 4 to 120: 29.02 km
# Distance from 4 to 121: 18.86 km
# Distance from 4 to 122: 12.57 km
# Distance from 4 to 123: 23.25 km
# Distance from 4 to 124: 10.88 km
# Distance from 4 to 125: 38.56 km
# Distance from 4 to 126: 8.76 km
# Distance from 4 to 127: 41.76 km
# Distance from 4 to 128: 7.86 km
# Distance from 4 to 129: 40.50 km
# Processed: origin 4, destinations 105-129. Elements: 919
#
# API Response for origin 4:
# Status: OK
# Distance from 4 to 130: 9.68 km
# Distance from 4 to 131: 15.90 km
# Distance from 4 to 132: 18.51 km
# Distance from 4 to 133: 49.53 km
# Distance from 4 to 134: 42.77 km
# Distance from 4 to 135: 15.48 km
# Distance from 4 to 136: 23.31 km
# Distance from 4 to 137: 37.04 km
# Distance from 4 to 138: 39.38 km
# Distance from 4 to 139: 7.94 km
# Distance from 4 to 140: 22.34 km
# Distance from 4 to 141: 25.34 km
# Distance from 4 to 142: 40.81 km
# Distance from 4 to 143: 37.50 km
# Distance from 4 to 144: 20.23 km
# Distance from 4 to 145: 41.47 km
# Distance from 4 to 146: 23.62 km
# Distance from 4 to 147: 38.76 km
# Distance from 4 to 148: 20.98 km
# Distance from 4 to 149: 37.16 km
# Distance from 4 to 150: 7.07 km
# Distance from 4 to 151: 19.15 km
# Distance from 4 to 152: 47.63 km
# Distance from 4 to 153: 21.20 km
# Distance from 4 to 154: 37.54 km
# Processed: origin 4, destinations 130-154. Elements: 944
#
# API Response for origin 4:
# Status: OK
# Distance from 4 to 155: 38.09 km
# Distance from 4 to 156: 20.61 km
# Distance from 4 to 157: 21.75 km
# Distance from 4 to 158: 17.52 km
# Distance from 4 to 159: 24.57 km
# Distance from 4 to 160: 32.18 km
# Distance from 4 to 161: 40.03 km
# Distance from 4 to 162: 19.57 km
# Distance from 4 to 163: 38.18 km
# Distance from 4 to 164: 4.19 km
# Distance from 4 to 165: 15.33 km
# Distance from 4 to 166: 15.92 km
# Distance from 4 to 167: 19.50 km
# Distance from 4 to 168: 5.22 km
# Distance from 4 to 169: 3.29 km
# Distance from 4 to 170: 8.82 km
# Distance from 4 to 171: 12.18 km
# Distance from 4 to 172: 38.85 km
# Distance from 4 to 173: 41.29 km
# Distance from 4 to 174: 15.74 km
# Distance from 4 to 175: 22.54 km
# Distance from 4 to 176: 14.75 km
# Distance from 4 to 177: 8.04 km
# Distance from 4 to 178: 11.39 km
# Distance from 4 to 179: 10.81 km
# Processed: origin 4, destinations 155-179. Elements: 969
#
# API Response for origin 4:
# Status: OK
# Distance from 4 to 180: 12.65 km
# Distance from 4 to 181: 4.51 km
# Distance from 4 to 182: 22.57 km
# Distance from 4 to 183: 44.99 km
# Distance from 4 to 184: 16.62 km
# Distance from 4 to 185: 5.99 km
# Distance from 4 to 186: 46.49 km
# Distance from 4 to 187: 18.38 km
# Distance from 4 to 188: 44.74 km
# Distance from 4 to 189: 36.65 km
# Distance from 4 to 190: 12.80 km
# Distance from 4 to 191: 37.95 km
# Distance from 4 to 192: 42.18 km
# Distance from 4 to 193: 14.64 km
# Distance from 4 to 194: 36.63 km
# Distance from 4 to 195: 34.33 km
# Distance from 4 to 196: 48.70 km
# Distance from 4 to 197: 40.68 km
# Distance from 4 to 198: 37.02 km
# Distance from 4 to 199: 26.71 km
# Distance from 4 to 200: 32.02 km
# Processed: origin 4, destinations 180-200. Elements: 990
#
# API Response for origin 5:
# Status: OK
# Distance from 5 to 6: 36.77 km
# Distance from 5 to 7: 8.71 km
# Distance from 5 to 8: 18.80 km
# Distance from 5 to 9: 11.00 km
# Distance from 5 to 10: 35.43 km
# Distance from 5 to 11: 3.96 km
# Distance from 5 to 12: 16.45 km
# Distance from 5 to 13: 18.47 km
# Distance from 5 to 14: 19.96 km
# Distance from 5 to 15: 28.26 km
# Distance from 5 to 16: 11.45 km
# Distance from 5 to 17: 10.06 km
# Distance from 5 to 18: 49.30 km
# Distance from 5 to 19: 8.65 km
# Distance from 5 to 20: 43.27 km
# Distance from 5 to 21: 22.73 km
# Distance from 5 to 22: 19.47 km
# Distance from 5 to 23: 22.84 km
# Distance from 5 to 24: 44.92 km
# Distance from 5 to 25: 51.92 km
# Distance from 5 to 26: 39.75 km
# Distance from 5 to 27: 32.77 km
# Distance from 5 to 28: 25.88 km
# Distance from 5 to 29: 42.49 km
# Distance from 5 to 30: 19.78 km
# Processed: origin 5, destinations 6-30. Elements: 1015
#
# API Response for origin 5:
# Status: OK
# Distance from 5 to 31: 9.98 km
# Distance from 5 to 32: 48.00 km
# Distance from 5 to 33: 20.98 km
# Distance from 5 to 34: 48.67 km
# Distance from 5 to 35: 34.19 km
# Distance from 5 to 36: 43.59 km
# Distance from 5 to 37: 46.95 km
# Distance from 5 to 38: 37.00 km
# Distance from 5 to 39: 19.00 km
# Distance from 5 to 40: 8.86 km
# Distance from 5 to 41: 38.88 km
# Distance from 5 to 42: 4.87 km
# Distance from 5 to 43: 36.79 km
# Distance from 5 to 44: 25.33 km
# Distance from 5 to 45: 15.82 km
# Distance from 5 to 46: 30.86 km
# Distance from 5 to 47: 14.30 km
# Distance from 5 to 48: 3.11 km
# Distance from 5 to 49: 27.22 km
# Distance from 5 to 50: 34.46 km
# Distance from 5 to 51: 31.04 km
# Distance from 5 to 52: 6.85 km
# Distance from 5 to 53: 49.59 km
# Distance from 5 to 54: 15.40 km
# Distance from 5 to 55: 10.36 km
# Processed: origin 5, destinations 31-55. Elements: 1040
#
# API Response for origin 5:
# Status: OK
# Distance from 5 to 56: 28.09 km
# Distance from 5 to 57: 43.22 km
# Distance from 5 to 58: 39.27 km
# Distance from 5 to 59: 20.44 km
# Distance from 5 to 60: 28.49 km
# Distance from 5 to 61: 13.98 km
# Distance from 5 to 62: 46.11 km
# Distance from 5 to 63: 49.69 km
# Distance from 5 to 64: 11.20 km
# Distance from 5 to 65: 48.28 km
# Distance from 5 to 66: 24.41 km
# Distance from 5 to 67: 44.02 km
# Distance from 5 to 68: 16.92 km
# Distance from 5 to 69: 24.53 km
# Distance from 5 to 70: 22.52 km
# Distance from 5 to 71: 43.06 km
# Distance from 5 to 72: 8.60 km
# Distance from 5 to 73: 22.00 km
# Distance from 5 to 74: 23.29 km
# Distance from 5 to 75: 20.16 km
# Distance from 5 to 76: 18.64 km
# Distance from 5 to 77: 27.58 km
# Distance from 5 to 78: 17.20 km
# Distance from 5 to 79: 27.04 km
# Distance from 5 to 80: 22.33 km
# Processed: origin 5, destinations 56-80. Elements: 1065
#
# API Response for origin 5:
# Status: OK
# Distance from 5 to 81: 11.49 km
# Distance from 5 to 82: 48.15 km
# Distance from 5 to 83: 31.63 km
# Distance from 5 to 84: 17.99 km
# Distance from 5 to 85: 47.87 km
# Distance from 5 to 86: 31.54 km
# Distance from 5 to 87: 36.30 km
# Distance from 5 to 88: 15.68 km
# Distance from 5 to 89: 19.51 km
# Distance from 5 to 90: 20.72 km
# Distance from 5 to 91: 48.08 km
# Distance from 5 to 92: 47.49 km
# Distance from 5 to 93: 20.18 km
# Distance from 5 to 94: 30.61 km
# Distance from 5 to 95: 19.10 km
# Distance from 5 to 96: 17.41 km
# Distance from 5 to 97: 9.04 km
# Distance from 5 to 98: 46.02 km
# Distance from 5 to 99: 28.80 km
# Distance from 5 to 100: 14.73 km
# Distance from 5 to 101: 32.19 km
# Distance from 5 to 102: 16.77 km
# Distance from 5 to 103: 15.63 km
# Distance from 5 to 104: 46.05 km
# Distance from 5 to 105: 30.69 km
# Processed: origin 5, destinations 81-105. Elements: 1090
#
# API Response for origin 5:
# Status: OK
# Distance from 5 to 106: 19.36 km
# Distance from 5 to 107: 43.36 km
# Distance from 5 to 108: 17.92 km
# Distance from 5 to 109: 21.83 km
# Distance from 5 to 110: 19.12 km
# Distance from 5 to 111: 35.61 km
# Distance from 5 to 112: 15.59 km
# Distance from 5 to 113: 32.90 km
# Distance from 5 to 114: 53.46 km
# Distance from 5 to 115: 37.76 km
# Distance from 5 to 116: 25.27 km
# Distance from 5 to 117: 43.59 km
# Distance from 5 to 118: 24.19 km
# Distance from 5 to 119: 36.04 km
# Distance from 5 to 120: 13.18 km
# Distance from 5 to 121: 25.24 km
# Distance from 5 to 122: 29.53 km
# Distance from 5 to 123: 20.84 km
# Distance from 5 to 124: 24.45 km
# Distance from 5 to 125: 44.94 km
# Distance from 5 to 126: 19.24 km
# Distance from 5 to 127: 16.05 km
# Distance from 5 to 128: 26.07 km
# Distance from 5 to 129: 51.19 km
# Distance from 5 to 130: 31.74 km
# Processed: origin 5, destinations 106-130. Elements: 1115
#
# API Response for origin 5:
# Status: OK
# Distance from 5 to 131: 19.25 km
# Distance from 5 to 132: 23.45 km
# Distance from 5 to 133: 21.60 km
# Distance from 5 to 134: 14.87 km
# Distance from 5 to 135: 37.04 km
# Distance from 5 to 136: 20.90 km
# Distance from 5 to 137: 47.73 km
# Distance from 5 to 138: 50.07 km
# Distance from 5 to 139: 26.56 km
# Distance from 5 to 140: 19.05 km
# Distance from 5 to 141: 19.86 km
# Distance from 5 to 142: 13.14 km
# Distance from 5 to 143: 11.79 km
# Distance from 5 to 144: 15.70 km
# Distance from 5 to 145: 52.16 km
# Distance from 5 to 146: 45.18 km
# Distance from 5 to 147: 49.45 km
# Distance from 5 to 148: 11.52 km
# Distance from 5 to 149: 13.37 km
# Distance from 5 to 150: 30.83 km
# Distance from 5 to 151: 40.71 km
# Distance from 5 to 152: 54.01 km
# Distance from 5 to 153: 27.58 km
# Distance from 5 to 154: 11.83 km
# Distance from 5 to 155: 48.78 km
# Processed: origin 5, destinations 131-155. Elements: 1140
#
# API Response for origin 5:
# Status: OK
# Distance from 5 to 156: 31.30 km
# Distance from 5 to 157: 28.13 km
# Distance from 5 to 158: 28.21 km
# Distance from 5 to 159: 46.13 km
# Distance from 5 to 160: 4.27 km
# Distance from 5 to 161: 50.73 km
# Distance from 5 to 162: 25.95 km
# Distance from 5 to 163: 14.39 km
# Distance from 5 to 164: 32.17 km
# Distance from 5 to 165: 36.89 km
# Distance from 5 to 166: 21.46 km
# Distance from 5 to 167: 15.27 km
# Distance from 5 to 168: 30.78 km
# Distance from 5 to 169: 31.73 km
# Distance from 5 to 170: 31.68 km
# Distance from 5 to 171: 30.50 km
# Distance from 5 to 172: 15.06 km
# Distance from 5 to 173: 47.67 km
# Distance from 5 to 174: 37.30 km
# Distance from 5 to 175: 18.34 km
# Distance from 5 to 176: 18.79 km
# Distance from 5 to 177: 23.01 km
# Distance from 5 to 178: 26.05 km
# Distance from 5 to 179: 25.11 km
# Distance from 5 to 180: 34.22 km
# Processed: origin 5, destinations 156-180. Elements: 1165
#
# API Response for origin 5:
# Status: OK
# Distance from 5 to 181: 25.31 km
# Distance from 5 to 182: 43.59 km
# Distance from 5 to 183: 17.59 km
# Distance from 5 to 184: 16.59 km
# Distance from 5 to 185: 25.79 km
# Distance from 5 to 186: 57.18 km
# Distance from 5 to 187: 40.24 km
# Distance from 5 to 188: 19.03 km
# Distance from 5 to 189: 47.34 km
# Distance from 5 to 190: 23.50 km
# Distance from 5 to 191: 48.63 km
# Distance from 5 to 192: 14.10 km
# Distance from 5 to 193: 21.11 km
# Distance from 5 to 194: 10.92 km
# Distance from 5 to 195: 45.02 km
# Distance from 5 to 196: 21.89 km
# Distance from 5 to 197: 47.06 km
# Distance from 5 to 198: 25.76 km
# Distance from 5 to 199: 48.28 km
# Distance from 5 to 200: 3.60 km
# Processed: origin 5, destinations 181-200. Elements: 1185
#
# API Response for origin 6:
# Status: OK
# Distance from 6 to 7: 37.94 km
# Distance from 6 to 8: 25.70 km
# Distance from 6 to 9: 41.91 km
# Distance from 6 to 10: 18.75 km
# Distance from 6 to 11: 40.25 km
# Distance from 6 to 12: 52.22 km
# Distance from 6 to 13: 32.60 km
# Distance from 6 to 14: 27.61 km
# Distance from 6 to 15: 64.01 km
# Distance from 6 to 16: 46.81 km
# Distance from 6 to 17: 32.87 km
# Distance from 6 to 18: 34.69 km
# Distance from 6 to 19: 38.21 km
# Distance from 6 to 20: 6.26 km
# Distance from 6 to 21: 25.23 km
# Distance from 6 to 22: 22.82 km
# Distance from 6 to 23: 24.17 km
# Distance from 6 to 24: 22.60 km
# Distance from 6 to 25: 16.40 km
# Distance from 6 to 26: 4.43 km
# Distance from 6 to 27: 6.06 km
# Distance from 6 to 28: 18.84 km
# Distance from 6 to 29: 20.17 km
# Distance from 6 to 30: 23.47 km
# Distance from 6 to 31: 43.68 km
# Processed: origin 6, destinations 7-31. Elements: 1210
#
# API Response for origin 6:
# Status: OK
# Distance from 6 to 32: 15.85 km
# Distance from 6 to 33: 27.01 km
# Distance from 6 to 34: 9.81 km
# Distance from 6 to 35: 3.33 km
# Distance from 6 to 36: 36.87 km
# Distance from 6 to 37: 12.03 km
# Distance from 6 to 38: 2.49 km
# Distance from 6 to 39: 26.53 km
# Distance from 6 to 40: 38.12 km
# Distance from 6 to 41: 24.27 km
# Distance from 6 to 42: 40.61 km
# Distance from 6 to 43: 8.34 km
# Distance from 6 to 44: 24.19 km
# Distance from 6 to 45: 29.24 km
# Distance from 6 to 46: 7.43 km
# Distance from 6 to 47: 51.89 km
# Distance from 6 to 48: 40.03 km
# Distance from 6 to 49: 19.97 km
# Distance from 6 to 50: 3.67 km
# Distance from 6 to 51: 9.67 km
# Distance from 6 to 52: 42.60 km
# Distance from 6 to 53: 15.54 km
# Distance from 6 to 54: 52.98 km
# Distance from 6 to 55: 31.86 km
# Distance from 6 to 56: 26.95 km
# Processed: origin 6, destinations 32-56. Elements: 1235
#
# API Response for origin 6:
# Status: OK
# Distance from 6 to 57: 5.99 km
# Distance from 6 to 58: 29.88 km
# Distance from 6 to 59: 27.79 km
# Distance from 6 to 60: 19.21 km
# Distance from 6 to 61: 50.82 km
# Distance from 6 to 62: 12.63 km
# Distance from 6 to 63: 18.67 km
# Distance from 6 to 64: 46.19 km
# Distance from 6 to 65: 8.53 km
# Distance from 6 to 66: 21.93 km
# Distance from 6 to 67: 28.28 km
# Distance from 6 to 68: 32.16 km
# Distance from 6 to 69: 26.52 km
# Distance from 6 to 70: 39.14 km
# Distance from 6 to 71: 10.90 km
# Distance from 6 to 72: 43.93 km
# Distance from 6 to 73: 19.25 km
# Distance from 6 to 74: 16.26 km
# Distance from 6 to 75: 23.85 km
# Distance from 6 to 76: 59.58 km
# Distance from 6 to 77: 63.33 km
# Distance from 6 to 78: 48.51 km
# Distance from 6 to 79: 17.76 km
# Distance from 6 to 80: 64.29 km
# Distance from 6 to 81: 48.09 km
# Processed: origin 6, destinations 57-81. Elements: 1260
#
# API Response for origin 6:
# Status: OK
# Distance from 6 to 82: 25.82 km
# Distance from 6 to 83: 14.52 km
# Distance from 6 to 84: 53.73 km
# Distance from 6 to 85: 31.97 km
# Distance from 6 to 86: 19.14 km
# Distance from 6 to 87: 1.96 km
# Distance from 6 to 88: 41.47 km
# Distance from 6 to 89: 29.08 km
# Distance from 6 to 90: 27.70 km
# Distance from 6 to 91: 10.81 km
# Distance from 6 to 92: 32.88 km
# Distance from 6 to 93: 55.92 km
# Distance from 6 to 94: 12.26 km
# Distance from 6 to 95: 25.87 km
# Distance from 6 to 96: 22.70 km
# Distance from 6 to 97: 46.45 km
# Distance from 6 to 98: 10.31 km
# Distance from 6 to 99: 12.73 km
# Distance from 6 to 100: 47.92 km
# Distance from 6 to 101: 14.39 km
# Distance from 6 to 102: 29.77 km
# Distance from 6 to 103: 26.67 km
# Distance from 6 to 104: 7.91 km
# Distance from 6 to 105: 8.57 km
# Distance from 6 to 106: 28.13 km
# Processed: origin 6, destinations 82-106. Elements: 1285
#
# API Response for origin 6:
# Status: OK
# Distance from 6 to 107: 11.20 km
# Distance from 6 to 108: 23.66 km
# Distance from 6 to 109: 57.58 km
# Distance from 6 to 110: 35.74 km
# Distance from 6 to 111: 9.66 km
# Distance from 6 to 112: 23.46 km
# Distance from 6 to 113: 8.74 km
# Distance from 6 to 114: 31.13 km
# Distance from 6 to 115: 23.15 km
# Distance from 6 to 116: 61.01 km
# Distance from 6 to 117: 12.54 km
# Distance from 6 to 118: 21.88 km
# Distance from 6 to 119: 22.26 km
# Distance from 6 to 120: 37.76 km
# Distance from 6 to 121: 18.20 km
# Distance from 6 to 122: 11.49 km
# Distance from 6 to 123: 25.23 km
# Distance from 6 to 124: 16.56 km
# Distance from 6 to 125: 11.46 km
# Distance from 6 to 126: 20.52 km
# Distance from 6 to 127: 53.23 km
# Distance from 6 to 128: 24.93 km
# Distance from 6 to 129: 28.86 km
# Distance from 6 to 130: 9.39 km
# Distance from 6 to 131: 24.80 km
# Processed: origin 6, destinations 107-131. Elements: 1310
#
# API Response for origin 6:
# Status: OK
# Distance from 6 to 132: 22.90 km
# Distance from 6 to 133: 54.89 km
# Distance from 6 to 134: 51.70 km
# Distance from 6 to 135: 2.70 km
# Distance from 6 to 136: 25.30 km
# Distance from 6 to 137: 30.20 km
# Distance from 6 to 138: 27.74 km
# Distance from 6 to 139: 25.42 km
# Distance from 6 to 140: 28.40 km
# Distance from 6 to 141: 27.33 km
# Distance from 6 to 142: 50.72 km
# Distance from 6 to 143: 47.41 km
# Distance from 6 to 144: 29.12 km
# Distance from 6 to 145: 29.84 km
# Distance from 6 to 146: 7.97 km
# ...
# Distance from 173 to 181: 38.00 km
# Distance from 173 to 182: 6.88 km
# Distance from 173 to 183: 55.44 km
# Distance from 173 to 184: 39.25 km
# Distance from 173 to 185: 38.47 km
# Distance from 173 to 186: 17.81 km
# Distance from 173 to 187: 10.51 km
# Distance from 173 to 188: 65.06 km
# Distance from 173 to 189: 16.59 km
# Distance from 173 to 190: 32.14 km
# Distance from 173 to 191: 26.63 km
# Distance from 173 to 192: 52.63 km
# Distance from 173 to 193: 32.63 km
# Distance from 173 to 194: 51.63 km
# Distance from 173 to 195: 15.46 km
# Distance from 173 to 196: 66.75 km
# Distance from 173 to 197: 2.81 km
# Distance from 173 to 198: 47.47 km
# Processed: origin 173, destinations 174-198. Elements: 19747
#
# API Response for origin 173:
# Status: OK
# Distance from 173 to 199: 15.88 km
# Distance from 173 to 200: 48.23 km
# Processed: origin 173, destinations 199-200. Elements: 19749
#
# API Response for origin 174:
# Status: OK
# Distance from 174 to 175: 30.60 km
# Distance from 174 to 176: 22.81 km
# Distance from 174 to 177: 16.15 km
# Distance from 174 to 178: 15.48 km
# Distance from 174 to 179: 14.90 km
# Distance from 174 to 180: 4.26 km
# Distance from 174 to 181: 15.86 km
# Distance from 174 to 182: 11.35 km
# Distance from 174 to 183: 50.98 km
# Distance from 174 to 184: 24.71 km
# Distance from 174 to 185: 13.31 km
# Distance from 174 to 186: 35.49 km
# Distance from 174 to 187: 10.68 km
# Distance from 174 to 188: 52.79 km
# Distance from 174 to 189: 33.11 km
# Distance from 174 to 190: 20.86 km
# Distance from 174 to 191: 34.66 km
# Distance from 174 to 192: 48.17 km
# Distance from 174 to 193: 22.70 km
# Distance from 174 to 194: 44.69 km
# Distance from 174 to 195: 31.04 km
# Distance from 174 to 196: 62.29 km
# Distance from 174 to 197: 17.81 km
# Distance from 174 to 198: 43.02 km
# Distance from 174 to 199: 8.94 km
# Processed: origin 174, destinations 175-199. Elements: 19774
#
# API Response for origin 174:
# Status: OK
# Distance from 174 to 200: 40.12 km
# Processed: origin 174, destinations 200-200. Elements: 19775
#
# API Response for origin 175:
# Status: OK
# Distance from 175 to 176: 7.30 km
# Distance from 175 to 177: 14.28 km
# Distance from 175 to 178: 17.72 km
# Distance from 175 to 179: 16.78 km
# Distance from 175 to 180: 25.93 km
# Distance from 175 to 181: 17.01 km
# Distance from 175 to 182: 36.74 km
# Distance from 175 to 183: 31.93 km
# Distance from 175 to 184: 3.48 km
# Distance from 175 to 185: 17.48 km
# Distance from 175 to 186: 46.02 km
# Distance from 175 to 187: 33.40 km
# Distance from 175 to 188: 31.68 km
# Distance from 175 to 189: 36.19 km
# Distance from 175 to 190: 10.62 km
# Distance from 175 to 191: 37.48 km
# Distance from 175 to 192: 29.12 km
# Distance from 175 to 193: 9.62 km
# Distance from 175 to 194: 23.57 km
# Distance from 175 to 195: 33.86 km
# Distance from 175 to 196: 33.39 km
# Distance from 175 to 197: 40.21 km
# Distance from 175 to 198: 23.96 km
# Distance from 175 to 199: 39.99 km
# Distance from 175 to 200: 20.16 km
# Processed: origin 175, destinations 176-200. Elements: 19800
#
# API Response for origin 176:
# Status: OK
# Distance from 176 to 177: 9.15 km
# Distance from 176 to 178: 12.59 km
# Distance from 176 to 179: 11.65 km
# Distance from 176 to 180: 20.80 km
# Distance from 176 to 181: 11.88 km
# Distance from 176 to 182: 31.61 km
# Distance from 176 to 183: 33.71 km
# Distance from 176 to 184: 2.98 km
# Distance from 176 to 185: 12.36 km
# Distance from 176 to 186: 40.90 km
# Distance from 176 to 187: 28.27 km
# Distance from 176 to 188: 33.46 km
# Distance from 176 to 189: 31.05 km
# Distance from 176 to 190: 4.76 km
# Distance from 176 to 191: 32.35 km
# Distance from 176 to 192: 30.91 km
# Distance from 176 to 193: 4.12 km
# Distance from 176 to 194: 25.36 km
# Distance from 176 to 195: 28.73 km
# Distance from 176 to 196: 35.18 km
# Distance from 176 to 197: 35.08 km
# Distance from 176 to 198: 25.75 km
# Distance from 176 to 199: 34.86 km
# Distance from 176 to 200: 21.47 km
# Processed: origin 176, destinations 177-200. Elements: 19824
#
# API Response for origin 177:
# Status: OK
# Distance from 177 to 178: 4.40 km
# Distance from 177 to 179: 3.44 km
# Distance from 177 to 180: 13.27 km
# Distance from 177 to 181: 4.03 km
# Distance from 177 to 182: 31.46 km
# Distance from 177 to 183: 39.24 km
# Distance from 177 to 184: 10.88 km
# Distance from 177 to 185: 4.82 km
# Distance from 177 to 186: 40.75 km
# Distance from 177 to 187: 22.50 km
# Distance from 177 to 188: 38.99 km
# Distance from 177 to 189: 30.91 km
# Distance from 177 to 190: 5.59 km
# Distance from 177 to 191: 32.20 km
# Distance from 177 to 192: 36.44 km
# Distance from 177 to 193: 8.90 km
# Distance from 177 to 194: 30.89 km
# Distance from 177 to 195: 28.59 km
# Distance from 177 to 196: 42.95 km
# Distance from 177 to 197: 34.93 km
# Distance from 177 to 198: 31.28 km
# Distance from 177 to 199: 27.33 km
# Distance from 177 to 200: 26.28 km
# Processed: origin 177, destinations 178-200. Elements: 19847
#
# API Response for origin 178:
# Status: OK
# Distance from 178 to 179: 1.57 km
# Distance from 178 to 180: 12.40 km
# Distance from 178 to 181: 6.98 km
# Distance from 178 to 182: 23.61 km
# Distance from 178 to 183: 42.27 km
# Distance from 178 to 184: 13.90 km
# Distance from 178 to 185: 5.62 km
# Distance from 178 to 186: 30.59 km
# Distance from 178 to 187: 15.74 km
# Distance from 178 to 188: 42.02 km
# Distance from 178 to 189: 28.98 km
# Distance from 178 to 190: 6.50 km
# Distance from 178 to 191: 30.28 km
# Distance from 178 to 192: 39.46 km
# Distance from 178 to 193: 8.26 km
# Distance from 178 to 194: 33.91 km
# Distance from 178 to 195: 26.66 km
# Distance from 178 to 196: 45.98 km
# Distance from 178 to 197: 27.08 km
# Distance from 178 to 198: 34.30 km
# Distance from 178 to 199: 26.46 km
# Distance from 178 to 200: 29.31 km
# Processed: origin 178, destinations 179-200. Elements: 19869
#
# API Response for origin 179:
# Status: OK
# Distance from 179 to 180: 15.18 km
# Distance from 179 to 181: 5.94 km
# Distance from 179 to 182: 24.65 km
# Distance from 179 to 183: 41.16 km
# Distance from 179 to 184: 12.79 km
# Distance from 179 to 185: 4.31 km
# Distance from 179 to 186: 31.63 km
# Distance from 179 to 187: 15.91 km
# Distance from 179 to 188: 40.91 km
# Distance from 179 to 189: 32.82 km
# Distance from 179 to 190: 7.00 km
# Distance from 179 to 191: 34.11 km
# Distance from 179 to 192: 38.35 km
# Distance from 179 to 193: 10.81 km
# Distance from 179 to 194: 32.80 km
# Distance from 179 to 195: 30.50 km
# Distance from 179 to 196: 44.87 km
# Distance from 179 to 197: 28.12 km
# Distance from 179 to 198: 33.19 km
# Distance from 179 to 199: 29.24 km
# Distance from 179 to 200: 28.19 km
# Processed: origin 179, destinations 180-200. Elements: 19890
#
# API Response for origin 180:
# Status: OK
# Distance from 180 to 181: 13.59 km
# Distance from 180 to 182: 10.82 km
# Distance from 180 to 183: 50.25 km
# Distance from 180 to 184: 22.44 km
# Distance from 180 to 185: 11.04 km
# Distance from 180 to 186: 34.76 km
# Distance from 180 to 187: 9.08 km
# Distance from 180 to 188: 50.52 km
# Distance from 180 to 189: 32.38 km
# Distance from 180 to 190: 18.59 km
# Distance from 180 to 191: 33.94 km
# Distance from 180 to 192: 47.45 km
# Distance from 180 to 193: 20.43 km
# Distance from 180 to 194: 42.41 km
# Distance from 180 to 195: 30.32 km
# Distance from 180 to 196: 54.52 km
# Distance from 180 to 197: 16.45 km
# Distance from 180 to 198: 42.29 km
# Distance from 180 to 199: 12.71 km
# Distance from 180 to 200: 37.84 km
# Processed: origin 180, destinations 181-200. Elements: 19910
#
# API Response for origin 181:
# Status: OK
# Distance from 181 to 182: 23.47 km
# Distance from 181 to 183: 41.04 km
# Distance from 181 to 184: 12.59 km
# Distance from 181 to 185: 5.12 km
# Distance from 181 to 186: 42.55 km
# Distance from 181 to 187: 22.79 km
# Distance from 181 to 188: 40.79 km
# Distance from 181 to 189: 32.71 km
# Distance from 181 to 190: 8.86 km
# Distance from 181 to 191: 34.00 km
# Distance from 181 to 192: 38.23 km
# Distance from 181 to 193: 10.70 km
# Distance from 181 to 194: 32.69 km
# Distance from 181 to 195: 30.38 km
# Distance from 181 to 196: 44.67 km
# Distance from 181 to 197: 36.73 km
# Distance from 181 to 198: 33.08 km
# Distance from 181 to 199: 27.62 km
# Distance from 181 to 200: 28.00 km
# Processed: origin 181, destinations 182-200. Elements: 19929
#
# API Response for origin 182:
# Status: OK
# Distance from 182 to 183: 50.57 km
# Distance from 182 to 184: 34.38 km
# Distance from 182 to 185: 33.60 km
# Distance from 182 to 186: 24.62 km
# Distance from 182 to 187: 5.98 km
# Distance from 182 to 188: 60.19 km
# Distance from 182 to 189: 22.09 km
# Distance from 182 to 190: 27.27 km
# Distance from 182 to 191: 25.54 km
# Distance from 182 to 192: 47.76 km
# Distance from 182 to 193: 27.76 km
# Distance from 182 to 194: 46.77 km
# Distance from 182 to 195: 19.18 km
# Distance from 182 to 196: 61.88 km
# Distance from 182 to 197: 6.82 km
# Distance from 182 to 198: 42.60 km
# Distance from 182 to 199: 10.97 km
# Distance from 182 to 200: 43.36 km
# Processed: origin 182, destinations 183-200. Elements: 19947
#
# API Response for origin 183:
# Status: OK
# Distance from 183 to 184: 31.79 km
# Distance from 183 to 185: 40.54 km
# Distance from 183 to 186: 52.58 km
# Distance from 183 to 187: 46.46 km
# Distance from 183 to 188: 11.88 km
# Distance from 183 to 189: 47.97 km
# Distance from 183 to 190: 33.67 km
# Distance from 183 to 191: 42.50 km
# Distance from 183 to 192: 5.34 km
# Distance from 183 to 193: 32.67 km
# Distance from 183 to 194: 10.96 km
# Distance from 183 to 195: 46.70 km
# Distance from 183 to 196: 13.56 km
# Distance from 183 to 197: 53.27 km
# Distance from 183 to 198: 10.86 km
# Distance from 183 to 199: 63.05 km
# Distance from 183 to 200: 14.46 km
# Processed: origin 183, destinations 184-200. Elements: 19964
#
# API Response for origin 184:
# Status: OK
# Distance from 184 to 185: 13.80 km
# Distance from 184 to 186: 44.26 km
# Distance from 184 to 187: 31.63 km
# Distance from 184 to 188: 32.66 km
# Distance from 184 to 189: 34.41 km
# Distance from 184 to 190: 8.85 km
# Distance from 184 to 191: 35.71 km
# Distance from 184 to 192: 30.10 km
# Distance from 184 to 193: 6.85 km
# Distance from 184 to 194: 24.56 km
# Distance from 184 to 195: 32.09 km
# Distance from 184 to 196: 34.38 km
# Distance from 184 to 197: 38.44 km
# Distance from 184 to 198: 24.95 km
# Distance from 184 to 199: 36.29 km
# Distance from 184 to 200: 19.59 km
# Processed: origin 184, destinations 185-200. Elements: 19980
#
# API Response for origin 185:
# Status: OK
# Distance from 185 to 186: 34.90 km
# Distance from 185 to 187: 13.79 km
# Distance from 185 to 188: 42.02 km
# Distance from 185 to 189: 33.93 km
# Distance from 185 to 190: 10.08 km
# Distance from 185 to 191: 35.22 km
# Distance from 185 to 192: 39.46 km
# Distance from 185 to 193: 11.92 km
# Distance from 185 to 194: 33.91 km
# Distance from 185 to 195: 31.61 km
# Distance from 185 to 196: 43.73 km
# Distance from 185 to 197: 37.95 km
# Distance from 185 to 198: 34.30 km
# Distance from 185 to 199: 23.83 km
# Distance from 185 to 200: 29.33 km
# Processed: origin 185, destinations 186-200. Elements: 19995
#
# API Response for origin 186:
# Status: OK
# Distance from 186 to 187: 25.62 km
# Distance from 186 to 188: 67.59 km
# Distance from 186 to 189: 5.64 km
# Distance from 186 to 190: 34.67 km
# Distance from 186 to 191: 9.77 km
# Distance from 186 to 192: 55.16 km
# Distance from 186 to 193: 35.16 km
# Distance from 186 to 194: 54.16 km
# Distance from 186 to 195: 8.73 km
# Distance from 186 to 196: 69.27 km
# Distance from 186 to 197: 14.37 km
# Distance from 186 to 198: 50.00 km
# Distance from 186 to 199: 41.49 km
# Distance from 186 to 200: 50.75 km
# Processed: origin 186, destinations 187-200. Elements: 20009
#
# API Response for origin 187:
# Status: OK
# Distance from 187 to 188: 57.28 km
# Distance from 187 to 189: 23.02 km
# Distance from 187 to 190: 24.35 km
# Distance from 187 to 191: 26.48 km
# Distance from 187 to 192: 44.84 km
# Distance from 187 to 193: 24.85 km
# Distance from 187 to 194: 43.85 km
# Distance from 187 to 195: 20.12 km
# Distance from 187 to 196: 58.96 km
# Distance from 187 to 197: 9.30 km
# Distance from 187 to 198: 39.69 km
# Distance from 187 to 199: 10.30 km
# Distance from 187 to 200: 40.44 km
# Processed: origin 187, destinations 188-200. Elements: 20022
#
# API Response for origin 188:
# Status: OK
# Distance from 188 to 189: 58.26 km
# Distance from 188 to 190: 43.96 km
# Distance from 188 to 191: 52.79 km
# Distance from 188 to 192: 15.63 km
# Distance from 188 to 193: 42.96 km
# Distance from 188 to 194: 10.44 km
# Distance from 188 to 195: 56.99 km
# Distance from 188 to 196: 11.39 km
# Distance from 188 to 197: 63.56 km
# Distance from 188 to 198: 21.15 km
# Distance from 188 to 199: 73.34 km
# Distance from 188 to 200: 15.87 km
# Processed: origin 188, destinations 189-200. Elements: 20034
#
# API Response for origin 189:
# Status: OK
# Distance from 189 to 190: 27.57 km
# Distance from 189 to 191: 5.09 km
# Distance from 189 to 192: 46.52 km
# Distance from 189 to 193: 28.06 km
# Distance from 189 to 194: 46.99 km
# Distance from 189 to 195: 3.54 km
# Distance from 189 to 196: 60.63 km
# Distance from 189 to 197: 14.14 km
# Distance from 189 to 198: 41.36 km
# Distance from 189 to 199: 33.37 km
# Distance from 189 to 200: 43.58 km
# Processed: origin 189, destinations 190-200. Elements: 20045
#
# API Response for origin 190:
# Status: OK
# Distance from 190 to 191: 27.55 km
# Distance from 190 to 192: 34.91 km
# Distance from 190 to 193: 3.45 km
# Distance from 190 to 194: 29.37 km
# Distance from 190 to 195: 23.94 km
# Distance from 190 to 196: 39.19 km
# Distance from 190 to 197: 30.29 km
# Distance from 190 to 198: 29.75 km
# Distance from 190 to 199: 31.92 km
# Distance from 190 to 200: 26.05 km
# Processed: origin 190, destinations 191-200. Elements: 20055
#
# API Response for origin 191:
# Status: OK
# Distance from 191 to 192: 41.03 km
# Distance from 191 to 193: 28.52 km
# Distance from 191 to 194: 47.45 km
# Distance from 191 to 195: 6.01 km
# Distance from 191 to 196: 55.15 km
# Distance from 191 to 197: 23.31 km
# Distance from 191 to 198: 35.88 km
# Distance from 191 to 199: 36.35 km
# Distance from 191 to 200: 44.04 km
# Processed: origin 191, destinations 192-200. Elements: 20064
#
# API Response for origin 192:
# Status: OK
# Distance from 192 to 193: 31.00 km
# Distance from 192 to 194: 9.84 km
# Distance from 192 to 195: 45.03 km
# Distance from 192 to 196: 17.46 km
# Distance from 192 to 197: 51.61 km
# Distance from 192 to 198: 9.19 km
# Distance from 192 to 199: 61.38 km
# Distance from 192 to 200: 12.54 km
# Processed: origin 192, destinations 193-200. Elements: 20072
#
# API Response for origin 193:
# Status: OK
# Distance from 193 to 194: 26.59 km
# Distance from 193 to 195: 25.15 km
# Distance from 193 to 196: 36.41 km
# Distance from 193 to 197: 31.50 km
# Distance from 193 to 198: 24.89 km
# Distance from 193 to 199: 35.14 km
# Distance from 193 to 200: 23.18 km
# Processed: origin 193, destinations 194-200. Elements: 20079
#
# API Response for origin 194:
# Status: OK
# Distance from 194 to 195: 45.23 km
# Distance from 194 to 196: 12.16 km
# Distance from 194 to 197: 50.17 km
# Distance from 194 to 198: 19.26 km
# Distance from 194 to 199: 55.86 km
# Distance from 194 to 200: 7.73 km
# Processed: origin 194, destinations 195-200. Elements: 20085
#
# API Response for origin 195:
# Status: OK
# Distance from 195 to 196: 59.38 km
# Distance from 195 to 197: 12.98 km
# Distance from 195 to 198: 40.10 km
# Distance from 195 to 199: 30.03 km
# Distance from 195 to 200: 40.39 km
# Processed: origin 195, destinations 196-200. Elements: 20090
#
# API Response for origin 196:
# Status: OK
# Distance from 196 to 197: 65.70 km
# Distance from 196 to 198: 23.29 km
# Distance from 196 to 199: 68.01 km
# Distance from 196 to 200: 18.04 km
# Processed: origin 196, destinations 197-200. Elements: 20094
#
# API Response for origin 197:
# Status: OK
# Distance from 197 to 198: 44.93 km
# Distance from 197 to 199: 19.35 km
# Distance from 197 to 200: 45.69 km
# Processed: origin 197, destinations 198-200. Elements: 20097
#
# API Response for origin 198:
# Status: OK
# Distance from 198 to 199: 51.41 km
# Distance from 198 to 200: 16.65 km
# Processed: origin 198, destinations 199-200. Elements: 20099
#
# API Response for origin 199:
# Status: OK
# Distance from 199 to 200: 47.66 km
# Processed: origin 199, destinations 200-200. Elements: 20100
#
# Final element count: 20100
# Matrix filled: 40200 elements
# Distance matrix created and cached.
# Distance matrix shape: (201, 201)

# %%
print(len(distance_matrix), len(locations_mapping))
distance_matrix, locations_mapping
# Out:
# 201 201
# (array([[    0., 45076., 21776., ..., 26485., 35727., 19287.],
#         [45076.,     0., 47124., ..., 49945., 24416., 50699.],
#         [21776., 47124.,     0., ..., 12483., 49569.,  4659.],
#         ...,
#         [26485., 49945., 12483., ...,     0., 51411., 16649.],
#         [35727., 24416., 49569., ..., 51411.,     0., 47657.],
#         [19287., 50699.,  4659., ..., 16649., 47657.,     0.]]),
#  {'0': {'lat': 33.6424,
#    'lng': -117.8417,
#    'address': 'UCI Warehouse: 260 Aldrich Hall, Irvine, CA 92697'},
#   '1': {'lat': 33.90778897,
#    'lng': -117.93965722,
#    'address': '830 RIDE OUT WAY, FULLERTON, California 92835'},
#   '2': {'lat': 33.60823499,
#    'lng': -117.70111409,
#    'address': '24391 AVENIDA DE LA CARLOTA Unit 270, LAGUNA HILLS, California 92653'},
#   '3': {'lat': 33.84755348,
#    'lng': -118.02936402,
#    'address': '7921 VALLEY VIEW ST, LA PALMA, California 90623'},
#   '4': {'lat': 33.67498759,
#    'lng': -117.9645855,
#    'address': '19801 GLOUCESTER LN, HUNTINGTON BEACH, California 92646'},
#   '5': {'lat': 33.5836007,
#    'lng': -117.73252394,
#    'address': '2 ENTERPRISE Unit 10310 Building 10, ALISO VIEJO, California 92656'},
#   '6': {'lat': 33.7719087,
#    'lng': -117.9954217,
#    'address': '13202 HOOVER ST Unit 22, WESTMINSTER, California 92683'},
#   '7': {'lat': 33.62668621,
#    'lng': -117.70630981,
#    'address': '24296 SUNNYBROOK CIR, LAKE FOREST, California 92630'},
#   '8': {'lat': 33.70615046,
#    'lng': -117.78405834,
#    'address': '14280 CULVER DR Unit A, IRVINE, California 92604'},
#   '9': {'lat': 33.63736434,
#    'lng': -117.66959011,
#    'address': '22392 RIPPLING BRK, LAKE FOREST, California 92630'},
#   '10': {'lat': 33.78182782,
#    'lng': -117.83941669,
#    'address': '425 S CALIFORNIA ST, ORANGE, California 92866'},
#   '11': {'lat': 33.56064851,
#    'lng': -117.73659754,
#    'address': '17 GLITTERING SKY, ALISO VIEJO, California 92656'},
#   '12': {'lat': 33.6160505,
#    'lng': -117.61288853,
#    'address': '100 RABANO, RANCHO SANTA MARGARITA, California 92688'},
#   '13': {'lat': 33.68228142,
#    'lng': -117.73749038,
#    'address': '176 TERRAPIN, IRVINE, California 92618'},
#   '14': {'lat': 33.68944479,
#    'lng': -117.81366288,
#    'address': '1601 REGGIO AISLE, IRVINE, California 92606'},
#   '15': {'lat': 33.47677046,
#    'lng': -117.60526338,
#    'address': '11 CALLE AVEITUNA, SAN CLEMENTE, California 92673'},
#   '16': {'lat': 33.64610359,
#    'lng': -117.6682908,
#    'address': '21821 MONTBURY DR, LAKE FOREST, California 92630'},
#   '17': {'lat': 33.64306456,
#    'lng': -117.75118011,
#    'address': '18206 PINTADO, IRVINE, California 92618'},
#   '18': {'lat': 33.89285536,
#    'lng': -117.81586987,
#    'address': '18241 MANDARIN LN Unit B, YORBA LINDA, California 92886'},
#   '19': {'lat': 33.62878407,
#    'lng': -117.70211376,
#    'address': '24472 BLACKFOOT DR, LAKE FOREST, California 92630'},
#   '20': {'lat': 33.80956706,
#    'lng': -118.01581994,
#    'address': '6691 FOREST ST, CYPRESS, California 90630'},
#   '21': {'lat': 33.62924851,
#    'lng': -117.90493852,
#    'address': '1242 RUTLAND RD Unit 5, NEWPORT BEACH, California 92660'},
#   '22': {'lat': 33.68093614,
#    'lng': -117.83889587,
#    'address': '2801 MAIN ST Unit 234, IRVINE, California 92614'},
#   '23': {'lat': 33.72419725,
#    'lng': -117.80771008,
#    'address': '2255 CLOVER DR, TUSTIN, California 92780'},
#   '24': {'lat': 33.8474331,
#    'lng': -117.88122743,
#    'address': '2509 E LA PALMA AVE, ANAHEIM, California 92806'},
#   '25': {'lat': 33.85686208,
#    'lng': -117.93548851,
#    'address': '612 W BAKER AVE, FULLERTON, California 92832'},
#   '26': {'lat': 33.80350663,
#    'lng': -117.999653,
#    'address': '7601 KATELLA AVE Unit 6, STANTON, California 90680'},
#   '27': {'lat': 33.7371523,
#    'lng': -117.9798373,
#    'address': '8551 BERMUDA AVE, WESTMINSTER, California 92683'},
#   '28': {'lat': 33.7469123,
#    'lng': -117.83782202,
#    'address': '203 N GOLDEN CIRCLE DR Unit 300, SANTA ANA, California 92705'},
#   '29': {'lat': 33.82344743,
#    'lng': -117.87883635,
#    'address': '2540 E NORM PL, ANAHEIM, California 92806'},
#   '30': {'lat': 33.67388773,
#    'lng': -117.84384216,
#    'address': '3131 MICHELSON DR Unit 801, IRVINE, California 92612'},
#   '31': {'lat': 33.61411826,
#    'lng': -117.66769554,
#    'address': '24012 CARRILLO DR, MISSION VIEJO, California 92691'},
#   '32': {'lat': 33.7258429,
#    'lng': -118.08051191,
#    'address': '32 SURFSIDE AVE Unit B, SEAL BEACH, California 90743'},
#   '33': {'lat': 33.61713101,
#    'lng': -117.90994918,
#    'address': '520 KINGS RD, NEWPORT BEACH, California 92663'},
#   '34': {'lat': 33.80990135,
#    'lng': -118.05605715,
#    'address': '4426 CERRITOS AVE, LOS ALAMITOS, California 90720'},
#   '35': {'lat': 33.75616814,
#    'lng': -117.98560367,
#    'address': '14123 ALL AMERICAN WAY, WESTMINSTER, California 92683'},
#   '36': {'lat': 33.85413922,
#    'lng': -117.72591265,
#    'address': '1138 S COUNTRY GLEN WAY, ANAHEIM, California 92808'},
#   '37': {'lat': 33.87410414,
#    'lng': -118.00138572,
#    'address': '5941 KINGMAN AVE Unit 4, BUENA PARK, California 90621'},
#   '38': {'lat': 33.78276105,
#    'lng': -117.99313362,
#    'address': '12345 BEACH BLVD Unit 554, STANTON, California 90680'},
#   '39': {'lat': 33.6680713,
#    'lng': -117.81174622,
#    'address': '31 HEATHERGREEN, IRVINE, California 92614'},
#   '40': {'lat': 33.62628911,
#    'lng': -117.7058619,
#    'address': '23145 VISTA WAY, LAKE FOREST, California 92630'},
#   '41': {'lat': 33.8106341,
#    'lng': -117.84007689,
#    'address': '1540 E TRENTON AVE Unit 5, ORANGE, California 92867'},
#   '42': {'lat': 33.56648961,
#    'lng': -117.7066502,
#    'address': '24273 AVENIDA DE LAS FLORES, LAGUNA NIGUEL, California 92677'},
#   '43': {'lat': 33.76363452,
#    'lng': -117.92883437,
#    'address': '13732 NEWHOPE ST, GARDEN GROVE, California 92843'},
#   '44': {'lat': 33.6362996,
#    'lng': -117.92662384,
#    'address': '668 W 17TH ST, COSTA MESA, California 92627'},
#   '45': {'lat': 33.67532157,
#    'lng': -117.78502163,
#    'address': '67 SOUTHBROOK, IRVINE, California 92604'},
#   '46': {'lat': 33.73306859,
#    'lng': -117.9687325,
#    'address': '9221 LARKSPUR DR, WESTMINSTER, California 92683'},
#   '47': {'lat': 33.55308143,
#    'lng': -117.63151932,
#    'address': '70 SKLAR ST Unit 306 Building 8, Ladera Ranch, California 92694'},
#   '48': {'lat': 33.56429311,
#    'lng': -117.72907787,
#    'address': '2 LIBERTY Unit 142 Building C, ALISO VIEJO, California 92656'},
#   '49': {'lat': 33.72798175,
#    'lng': -117.87438552,
#    'address': '1425 S PARTON ST, SANTA ANA, California 92707'},
#   '50': {'lat': 33.75039521,
#    'lng': -118.00819595,
#    'address': '14591 RALPH LN, WESTMINSTER, California 92683'},
#   '51': {'lat': 33.74764957,
#    'lng': -117.93620467,
#    'address': '323 N EUCLID ST Unit 156, SANTA ANA, California 92703'},
#   '52': {'lat': 33.55279674,
#    'lng': -117.69583427,
#    'address': '28188 MOULTON PKWY Unit 715 Building 7, LAGUNA NIGUEL, California 92677'},
#   '53': {'lat': 33.89483454,
#    'lng': -117.98204482,
#    'address': '8570 BUENA TIERRA PL, BUENA PARK, California 90621'},
#   '54': {'lat': 33.54114659,
#    'lng': -117.64228038,
#    'address': '8 BEDSTRAW LOOP, Ladera Ranch, California 92694'},
#   '55': {'lat': 33.6473654,
#    'lng': -117.75983309,
#    'address': '47 BIANCO, IRVINE, California 92618'},
#   '56': {'lat': 33.61500449,
#    'lng': -117.92156142,
#    'address': '215 VIA DIJON, NEWPORT BEACH, California 92663'},
#   '57': {'lat': 33.80824608,
#    'lng': -118.01702582,
#    'address': '10648 THOMAS CIR, CYPRESS, California 90630'},
#   '58': {'lat': 33.83217226,
#    'lng': -117.75553018,
#    'address': '1041 S PINE CANYON CIR, ANAHEIM, California 92807'},
#   '59': {'lat': 33.72057892,
#    'lng': -117.76587538,
#    'address': '20 ABETO, IRVINE, California 92620'},
#   '60': {'lat': 33.73986969,
#    'lng': -117.8552372,
#    'address': '1000 E BISHOP ST Unit B2 Building B, SANTA ANA, California 92701'},
#   '61': {'lat': 33.49270314,
#    'lng': -117.73611712,
#    'address': '11 N ENCINO, LAGUNA BEACH, California 92651'},
#   '62': {'lat': 33.86973795,
#    'lng': -117.98386177,
#    'address': '8550 COMMONWEALTH AVE Unit 426, BUENA PARK, California 90621'},
#   '63': {'lat': 33.89844601,
#    'lng': -117.95328219,
#    'address': '1764 SUMMERWOOD DR, FULLERTON, California 92833'},
#   '64': {'lat': 33.63214438,
#    'lng': -117.65859365,
#    'address': '22751 VIA SANTA MARIA, MISSION VIEJO, California 92691'},
#   '65': {'lat': 33.8284864,
#    'lng': -117.99522019,
#    'address': '211 S BEACH BLVD Unit 63, ANAHEIM, California 92804'},
#   '66': {'lat': 33.74737501,
#    'lng': -117.82681775,
#    'address': '345 W 1ST ST Unit 77, TUSTIN, California 92780'},
#   '67': {'lat': 33.87398163,
#    'lng': -117.83229646,
#    'address': '1597 E CAMERON WAY, PLACENTIA, California 92870'},
#   '68': {'lat': 33.59905764,
#    'lng': -117.8499463,
#    'address': '5 SEASHELL, NEWPORT BEACH, California 92657'},
#   '69': {'lat': 33.74296269,
#    'lng': -117.77968758,
#    'address': '2605 SAINT SIMONS, TUSTIN, California 92782'},
#   '70': {'lat': 33.66261911,
#    'lng': -117.72307574,
#    'address': '652 SONIA, IRVINE, California 92618'},
#   '71': {'lat': 33.78364918,
#    'lng': -118.08283024,
#    'address': '12331 CHIANTI DR, Rossmoor, California 90720'},
#   '72': {'lat': 33.62964387,
#    'lng': -117.6792511,
#    'address': '23145 LOS ALISOS BLVD Unit 297, LAKE FOREST, California 92691'},
#   '73': {'lat': 33.69567177,
#    'lng': -117.89353591,
#    'address': '3435 TIMBER LK, COSTA MESA, California 92626'},
#   '74': {'lat': 33.69496525,
#    'lng': -117.91411967,
#    'address': '3335 SUSAN ST Unit 125, COSTA MESA, California 92626'},
#   '75': {'lat': 33.6738665,
#    'lng': -117.84313864,
#    'address': '3141 MICHELSON DR Unit 1801, IRVINE, California 92612'},
#   '76': {'lat': 33.57391898,
#    'lng': -117.58529199,
#    'address': '11 SUNNINGDALE, Coto de Caza, California 92679'},
#   '77': {'lat': 33.42193516,
#    'lng': -117.61354937,
#    'address': '245 AVENIDA MADRID Unit 8, SAN CLEMENTE, California 92672'},
#   '78': {'lat': 33.64786858,
#    'lng': -117.61063983,
#    'address': '17 AMMOLITE, RANCHO SANTA MARGARITA, California 92688'},
#   '79': {'lat': 33.75126056,
#    'lng': -117.85625853,
#    'address': '1000 E SANTA ANA BLVD Unit 103, SANTA ANA, California 92701'},
#   '80': {'lat': 33.52484838,
#    'lng': -117.58861536,
#    'address': '853 LONGHORN WAY, Rancho Mission Viejo, California 92675'},
#   '81': {'lat': 33.51554639,
#    'lng': -117.697428,
#    'address': '4 CHANTONNAY, LAGUNA NIGUEL, California 92677'},
#   '82': {'lat': 33.87086125,
#    'lng': -117.87601777,
#    'address': '514 RAMONA ST, PLACENTIA, California 92870'},
#   '83': {'lat': 33.65702249,
#    'lng': -117.99456783,
#    'address': '80 HUNTINGTON ST Unit 106, HUNTINGTON BEACH, California 92648'},
#   '84': {'lat': 33.52123598,
#    'lng': -117.63050869,
#    'address': '42 PASARELA DR Unit 304, Rancho Mission Viejo, California 92694'},
#   '85': {'lat': 33.90287374,
#    'lng': -117.83446132,
#    'address': '17172 BROOKLYN AVE, YORBA LINDA, California 92886'},
#   '86': {'lat': 33.76498182,
#    'lng': -117.82949733,
#    'address': '13642 CARROLL WAY, TUSTIN, California 92780'},
#   '87': {'lat': 33.7671682,
#    'lng': -118.00841164,
#    'address': '13421 TAHOE ST, WESTMINSTER, California 92683'},
#   '88': {'lat': 33.66245527,
#    'lng': -117.68280108,
#    'address': '147 DENALI, LAKE FOREST, California 92630'},
#   '89': {'lat': 33.68401063,
#    'lng': -117.80591336,
#    'address': '46 PINESTONE, IRVINE, California 92604'},
#   '90': {'lat': 33.69318027,
#    'lng': -117.80857828,
#    'address': '37 ALTEZZA, IRVINE, California 92606'},
#   '91': {'lat': 33.84892599,
#    'lng': -118.02074915,
#    'address': '7834 LA MIRADA CIR, BUENA PARK, California 90620'},
#   '92': {'lat': 33.86694653,
#    'lng': -117.78166426,
#    'address': '20152 WAVERLY GLEN ST, YORBA LINDA, California 92886'},
#   '93': {'lat': 33.45588805,
#    'lng': -117.65766269,
#    'address': '370 CAMINO DE ESTRELLA, SAN CLEMENTE, California 92672'},
#   '94': {'lat': 33.69441453,
#    'lng': -117.97836005,
#    'address': '18472 SANTA ISADORA ST, FOUNTAIN VALLEY, California 92708'},
#   '95': {'lat': 33.65911918,
#    'lng': -117.82846329,
#    'address': '21 RANA, IRVINE, California 92612'},
#   '96': {'lat': 33.66150624,
#    'lng': -117.85951275,
#    'address': '4201 JAMBOREE RD Unit 545, NEWPORT BEACH, California 92660'},
#   '97': {'lat': 33.52858605,
#    'lng': -117.70776605,
#    'address': '24161 RUE DE CEZANNE, LAGUNA NIGUEL, California 92677'},
#   '98': {'lat': 33.84076829,
#    'lng': -118.0231223,
#    'address': '6353 SAN MARCOS WAY, BUENA PARK, California 90620'},
#   '99': {'lat': 33.69944035,
#    'lng': -117.96574516,
#    'address': '128 SUMAC LN, FOUNTAIN VALLEY, California 92708'},
#   '100': {'lat': 33.54344419,
#    'lng': -117.67272639,
#    'address': '28892 MARGUERITE PKWY Unit 100, MISSION VIEJO, California 92692'},
#   '101': {'lat': 33.67875402,
#    'lng': -117.98353693,
#    'address': '8306 MILANO DR, HUNTINGTON BEACH, California 92646'},
#   '102': {'lat': 33.68014655,
#    'lng': -117.78885876,
#    'address': '16 ROCKWREN, IRVINE, California 92604'},
#   '103': {'lat': 33.63633294,
#    'lng': -117.83914526,
#    'address': '56 WHITMAN CT, IRVINE, California 92617'},
#   '104': {'lat': 33.83509939,
#    'lng': -118.00608458,
#    'address': '8786 PIERCE DR, BUENA PARK, California 90620'},
#   '105': {'lat': 33.73944541,
#    'lng': -117.95429459,
#    'address': '15302 BROOKHURST ST Unit 325, WESTMINSTER, California 92683'},
#   '106': {'lat': 33.69281182,
#    'lng': -117.78784295,
#    'address': '1 DRAGONFLY, IRVINE, California 92604'},
#   '107': {'lat': 33.78165643,
#    'lng': -118.08666274,
#    'address': '2711 GERTRUDE DR, Rossmoor, California 90720'},
#   '108': {'lat': 33.64150257,
#    'lng': -117.86961977,
#    'address': '900 CERCIS PL, NEWPORT BEACH, California 92660'},
#   '109': {'lat': 33.46759428,
#    'lng': -117.7043264,
#    'address': '34102 RUBY LANTERN ST Unit B, DANA POINT, California 92629'},
#   '110': {'lat': 33.68544615,
#    'lng': -117.7135955,
#    'address': '214 OAK FOREST, IRVINE, California 92618'},
#   '111': {'lat': 33.79360222,
#    'lng': -117.92448022,
#    'address': '11952 DANIEL AVE, GARDEN GROVE, California 92840'},
#   '112': {'lat': 33.64097028,
#    'lng': -117.86437258,
#    'address': '46 CORSICA DR, NEWPORT BEACH, California 92660'},
#   '113': {'lat': 33.76061615,
#    'lng': -117.932576,
#    'address': '13914 PARKWAY DR, GARDEN GROVE, California 92843'},
#   '114': {'lat': 33.90460125,
#    'lng': -117.90627906,
#    'address': '2938 BREA BLVD, FULLERTON, California 92835'},
#   '115': {'lat': 33.8156085,
#    'lng': -117.82686874,
#    'address': '1688 N FERN ST, ORANGE, California 92867'},
#   '116': {'lat': 33.42775854,
#    'lng': -117.61685086,
#    'address': '204 AVENIDA MIRAMAR Unit D, SAN CLEMENTE, California 92672'},
#   '117': {'lat': 33.85498317,
#    'lng': -117.97056895,
#    'address': '9301 PICADILLY WAY, ANAHEIM, California 92801'},
#   '118': {'lat': 33.74677592,
#    'lng': -117.82092306,
#    'address': '131 HALL CIR Unit 48, TUSTIN, California 92780'},
#   '119': {'lat': 33.78243977,
#    'lng': -117.80087322,
#    'address': '12278 ALTA PANORAMA Unit 2, North Tustin, California 92705'},
#   '120': {'lat': 33.65992414,
#    'lng': -117.70313445,
#    'address': '17 HAMMOND Unit 404, IRVINE, California 92618'},
#   '121': {'lat': 33.74786124,
#    'lng': -117.84150014,
#    'address': '1750 E 4TH ST Unit 400, SANTA ANA, California 92705'},
#   '122': {'lat': 33.74591521,
#    'lng': -117.91769311,
#    'address': '117 N BEWLEY ST, SANTA ANA, California 92703'},
#   '123': {'lat': 33.72412534,
#    'lng': -117.78532113,
#    'address': '358 LAS PALMAS DR, IRVINE, California 92602'},
#   '124': {'lat': 33.7135254,
#    'lng': -117.89618827,
#    'address': '2509 S RAITT ST, SANTA ANA, California 92704'},
#   '125': {'lat': 33.86748361,
#    'lng': -117.99411669,
#    'address': '6401 STANTON AVE, BUENA PARK, California 90621'},
#   '126': {'lat': 33.66090153,
#    'lng': -117.88883249,
#    'address': '285 MESA DR, COSTA MESA, California 92627'},
#   '127': {'lat': 33.61281966,
#    'lng': -117.61936108,
#    'address': '16 REATA, RANCHO SANTA MARGARITA, California 92688'},
#   '128': {'lat': 33.63233623,
#    'lng': -117.93286549,
#    'address': '823 W 16TH ST, NEWPORT BEACH, California 92663'},
#   '129': {'lat': 33.9018257,
#    'lng': -117.88374151,
#    'address': '2843 PARK VISTA CT, FULLERTON, California 92835'},
#   '130': {'lat': 33.74091872,
#    'lng': -117.94403559,
#    'address': '10612 BARBETTE AVE, GARDEN GROVE, California 92843'},
#   '131': {'lat': 33.68269542,
#    'lng': -117.82433453,
#    'address': '90 MURICA AISLE, IRVINE, California 92614'},
#   '132': {'lat': 33.72428663,
#    'lng': -117.81636147,
#    'address': '1861 HAMPSHIRE RD, TUSTIN, California 92780'},
#   '133': {'lat': 33.63375193,
#    'lng': -117.56564992,
#    'address': '20 PROMONTORY, RANCHO SANTA MARGARITA, California 92679'},
#   '134': {'lat': 33.49595222,
#    'lng': -117.73769106,
#    'address': '32156 VIRGINIA WAY, LAGUNA BEACH, California 92651'},
#   '135': {'lat': 33.7644176,
#    'lng': -118.01292875,
#    'address': '13612 WILLAMETTE DR, WESTMINSTER, California 92683'},
#   '136': {'lat': 33.719154,
#    'lng': -117.78393248,
#    'address': '1448 WYCLIFFE Building 8, IRVINE, California 92602'},
#   '137': {'lat': 33.90179578,
#    'lng': -117.85564847,
#    'address': '537 HAIBER CIR, PLACENTIA, California 92870'},
#   '138': {'lat': 33.88817726,
#    'lng': -117.86844975,
#    'address': '3240 YORBA LINDA BLVD, FULLERTON, California 92831'},
#   '139': {'lat': 33.63853606,
#    'lng': -117.94088772,
#    'address': '1000 BRIOSO DR Unit B, COSTA MESA, California 92627'},
#   '140': {'lat': 33.69004095,
#    'lng': -117.78842306,
#    'address': '9 DEER CRK, IRVINE, California 92604'},
#   '141': {'lat': 33.7174894,
#    'lng': -117.77806953,
#    'address': '6 IDYLLWILD, IRVINE, California 92602'},
#   '142': {'lat': 33.55295692,
#    'lng': -117.64138717,
#    'address': '11 SAINT GILES CT, Ladera Ranch, California 92694'},
#   '143': {'lat': 33.57368532,
#    'lng': -117.64750036,
#    'address': '26781 BRIDGETON, MISSION VIEJO, California 92692'},
#   '144': {'lat': 33.66866404,
#    'lng': -117.79745344,
#    'address': '452 FALLINGSTAR, IRVINE, California 92614'},
#   '145': {'lat': 33.90953509,
#    'lng': -117.86908408,
#    'address': '2957 ARBORIDGE CT, FULLERTON, California 92835'},
#   '146': {'lat': 33.83124526,
#    'lng': -118.01073196,
#    'address': '3442 W LINCOLN AVE, ANAHEIM, California 92801'},
#   '147': {'lat': 33.85755784,
#    'lng': -117.91471079,
#    'address': '400 E ORANGETHORPE AVE, ANAHEIM, California 92801'},
#   '148': {'lat': 33.65282426,
#    'lng': -117.77213613,
#    'address': '489 QUAIL MEADOW, IRVINE, California 92603'},
#   '149': {'lat': 33.61773948,
#    'lng': -117.63355715,
#    'address': '23875 VILLENA, MISSION VIEJO, California 92692'},
#   '150': {'lat': 33.7307533,
#    'lng': -117.96614417,
#    'address': '9342 PARLIAMENT AVE, WESTMINSTER, California 92683'},
#   '151': {'lat': 33.79748311,
#    'lng': -118.02139718,
#    'address': '6416 SAN ANDRES AVE, CYPRESS, California 90630'},
#   '152': {'lat': 33.92476648,
#    'lng': -117.96632886,
#    'address': '1675 W LAMBERT RD Unit 20, LA HABRA, California 90631'},
#   '153': {'lat': 33.76366041,
#    'lng': -117.84932408,
#    'address': '1343 E 21ST ST, SANTA ANA, California 92705'},
#   '154': {'lat': 33.59193341,
#    'lng': -117.64424938,
#    'address': '1 TESORO, MISSION VIEJO, California 92692'},
#   '155': {'lat': 33.87685997,
#    'lng': -117.88750508,
#    'address': '2450 NUTWOOD AVE Unit 12, FULLERTON, California 92831'},
#   '156': {'lat': 33.76578624,
#    'lng': -117.83228761,
#    'address': '2401 E AVALON AVE, SANTA ANA, California 92705'},
#   '157': {'lat': 33.75765191,
#    'lng': -117.86419058,
#    'address': '1428 N FRENCH ST Unit 1, SANTA ANA, California 92701'},
#   '158': {'lat': 33.73558302,
#    'lng': -117.83545882,
#    'address': '15660 TUSTIN VILLAGE WAY Unit 49, TUSTIN, California 92780'},
#   '159': {'lat': 33.83729305,
#    'lng': -118.03823705,
#    'address': '8607 WALKER ST Unit 8, CYPRESS, California 90630'},
#   '160': {'lat': 33.55979279,
#    'lng': -117.72182565,
#    'address': '145 MATISSE CIR, ALISO VIEJO, California 92656'},
#   '161': {'lat': 33.86053445,
#    'lng': -117.92721291,
#    'address': '1200 S HIGHLAND AVE Unit 93, FULLERTON, California 92832'},
#   '162': {'lat': 33.74234573,
#    'lng': -117.84451005,
#    'address': '400 ZOO LN Unit 33D Building D, SANTA ANA, California 92701'},
#   '163': {'lat': 33.63474378,
#    'lng': -117.62336893,
#    'address': '10 SANTA TERESA, RANCHO SANTA MARGARITA, California 92688'},
#   '164': {'lat': 33.66271294,
#    'lng': -117.99512281,
#    'address': '613 HUNTINGTON ST, HUNTINGTON BEACH, California 92648'},
#   '165': {'lat': 33.75820582,
#    'lng': -118.00899155,
#    'address': '14061 RONDEAU ST Unit 3, WESTMINSTER, California 92683'},
#   '166': {'lat': 33.6948626,
#    'lng': -117.82920202,
#    'address': '1209 GATES AVE, IRVINE, California 92606'},
#   '167': {'lat': 33.64472735,
#    'lng': -117.8254112,
#    'address': '30804 ARROYO DR Building 308, IRVINE, California 92617'},
#   '168': {'lat': 33.69807135,
#    'lng': -117.98626251,
#    'address': '8141 KINER AVE, HUNTINGTON BEACH, California 92646'},
#   '169': {'lat': 33.66638888,
#    'lng': -117.98970047,
#    'address': '1015 GEORGIA ST, HUNTINGTON BEACH, California 92648'},
#   '170': {'lat': 33.7418854,
#    'lng': -117.97079484,
#    'address': '15200 MAGNOLIA ST Unit 43, WESTMINSTER, California 92683'},
#   '171': {'lat': 33.74945854,
#    'lng': -117.92694434,
#    'address': '4318 W SILVER DR, SANTA ANA, California 92703'},
#   '172': {'lat': 33.64418436,
#    'lng': -117.62644243,
#    'address': '28902 GREYSTONE, MISSION VIEJO, California 92692'},
#   '173': {'lat': 33.87567345,
#    'lng': -117.97730568,
#    'address': '2 WOODLAKE DR, BUENA PARK, California 90621'},
#   '174': {'lat': 33.7685091,
#    'lng': -118.01512707,
#    'address': '6551 BESTEL AVE, WESTMINSTER, California 92683'},
#   '175': {'lat': 33.64533888,
#    'lng': -117.81412238,
#    'address': '64 CANYON RDG, IRVINE, California 92603'},
#   '176': {'lat': 33.66498528,
#    'lng': -117.85124588,
#    'address': '2352 WATERMARKE PL, IRVINE, California 92612'},
#   '177': {'lat': 33.69533055,
#    'lng': -117.90688237,
#    'address': '1180 KINGSTON ST, COSTA MESA, California 92626'},
#   '178': {'lat': 33.71685603,
#    'lng': -117.8987202,
#    'address': '2230 S CENTER ST Unit C, SANTA ANA, California 92704'},
#   '179': {'lat': 33.71233853,
#    'lng': -117.90976599,
#    'address': '2950 W CENTRAL AVE Unit 20, SANTA ANA, California 92704'},
#   '180': {'lat': 33.75506598,
#    'lng': -117.98556991,
#    'address': '8190 13TH ST Unit 210, WESTMINSTER, California 92683'},
#   '181': {'lat': 33.67569469,
#    'lng': -117.92475947,
#    'address': '1621 MINORCA DR, COSTA MESA, California 92626'},
#   '182': {'lat': 33.8389765,
#    'lng': -117.98348091,
#    'address': '527 N COLGATE ST, ANAHEIM, California 92801'},
#   '183': {'lat': 33.63990568,
#    'lng': -117.5981933,
#    'address': '10 EL CORAZON, RANCHO SANTA MARGARITA, California 92688'},
#   '184': {'lat': 33.64909102,
#    'lng': -117.83280175,
#    'address': '145 CORNELL, IRVINE, California 92612'},
#   '185': {'lat': 33.70170241,
#    'lng': -117.93588088,
#    'address': '11060 TALBERT AVE, FOUNTAIN VALLEY, California 92708'},
#   '186': {'lat': 33.92659881,
#    'lng': -117.84205299,
#    'address': '3850 GRANDVIEW DR, BREA, California 92823'},
#   '187': {'lat': 33.81006309,
#    'lng': -117.95484996,
#    'address': '1510 S WHITEGATE RD, ANAHEIM, California 92804'},
#   '188': {'lat': 33.562253,
#    'lng': -117.59423318,
#    'address': '118 VELA CT, Coto de Caza, California 92679'},
#   '189': {'lat': 33.89541373,
#    'lng': -117.8273507,
#    'address': '4521 DELANCY DR, YORBA LINDA, California 92886'},
#   '190': {'lat': 33.69275111,
#    'lng': -117.85983202,
#    'address': '17780 FITCH Unit 180, IRVINE, California 92614'},
#   '191': {'lat': 33.88256988,
#    'lng': -117.78966025,
#    'address': '5401 FAIRMONT BLVD, YORBA LINDA, California 92886'},
#   '192': {'lat': 33.65827005,
#    'lng': -117.64012766,
#    'address': '170 CALIFORNIA CT, MISSION VIEJO, California 92692'},
#   '193': {'lat': 33.69153974,
#    'lng': -117.83925135,
#    'address': '1135 SYNERGY AVE, IRVINE, California 92614'},
#   '194': {'lat': 33.59205581,
#    'lng': -117.65424363,
#    'address': '25531 ARIA DR, MISSION VIEJO, California 92692'},
#   '195': {'lat': 33.86968878,
#    'lng': -117.82651744,
#    'address': '1779 HOOVER PL, PLACENTIA, California 92870'},
#   '196': {'lat': 33.53988177,
#    'lng': -117.59873661,
#    'address': '197 GARCILLA DR, Rancho Mission Viejo, California 92675'},
#   '197': {'lat': 33.87611592,
#    'lng': -117.95888508,
#    'address': '648 BRIDGEPORT CIR, FULLERTON, California 92833'},
#   '198': {'lat': 33.66871303,
#    'lng': -117.68123011,
#    'address': '40 SAGE, LAKE FOREST, California 92630'},
#   '199': {'lat': 33.8008781,
#    'lng': -118.05487266,
#    'address': '4463 HOWARD AVE Unit 5, LOS ALAMITOS, California 90720'},
#   '200': {'lat': 33.58440451,
#    'lng': -117.71015863,
#    'address': '26035 MOULTON PKWY Unit 53 Building D, LAGUNA HILLS, California 92653'}})
